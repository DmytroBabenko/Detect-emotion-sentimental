# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
from gensim.models import KeyedVectors

# %%
embeddings_file = "./embeddings/ubercorpus.cased.tokenized.word2vec.300d"

# %%
word2vec = KeyedVectors.load_word2vec_format(embeddings_file)

# %%
class ClusterNgram:
    def __init__(self, word2vec):
        self.word2vec = word2vec
        
        
    
    def cluster_n_grams(self, ngrams, num_cluster):
        X = self.__convert_ngrams_to_vectors(ngrams)
        kclusterer = KMeansClusterer(num_cluster, distance=nltk.cluster.util.cosine_distance, repeats=100)
        y = kclusterer.cluster(X, assign_clusters=True)
        
        top_indices = self.__find_top_n_gram_indices(X, y, kclusterer.means())
        
        return np.array(ngrams)[top_indices]
        
        
    
    def __find_top_n_gram_indices(self, X, y, centroids):
        min_dis = len(centroids)*[100]
        top_indices = len(centroids)*[-1]
        for i in range(0, len(centroids)):
            for j in range(0, len(X)):
                if y[j] != i:
                    continue
                
                dis = nltk.cluster.util.cosine_distance(X[j], centroids[i])
                if min_dis[i] > dis:
                    min_dis[i] = dis
                    top_indices[i] = j
        
        return top_indices
                    
    
    def __convert_ngrams_to_vectors(self, ngrams):
        X = []
        for ngram in ngrams:
            words = tokenize_uk.tokenize_words(ngram)
            x = word2vec[words[0]]
            for i in range(1, len(words)):
                x = x + word2vec[words[i]]
            X.append(x)
        return X

# %%
cluster_ngram = ClusterNgram(word2vec)

# %%
from IPython.display import display, HTML

CSS = """
.output {
'dd'
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
# 'dd'
#     flex-direction: row;
# }
# </style>

# %%
phrases
# Out:
# ['ввічливий персонал', 'чиста кімната', 'привітний персонал', 'свіже повітря']

# %%
bigrams = [
    'ввічливий персонал',
    'чудовий готель',
    'привітний персонал',
    'дуже чисто',
    'чиста кімната',
    'чудовий персонал'
]

# %%
display(bigrams)
display(cluster_ngram.cluster_n_grams(bigrams, 2).tolist())
# Out:
# ['ввічливий персонал',
#  'чудовий готель',
#  'привітний персонал',
#  'дуже чисто',
#  'чиста кімната',
#  'чудовий персонал']
# ['дуже чисто', 'чудовий персонал']

# %%
print("\n===Bi-grams===")
print(bigrams)
print("\n===Clustered bi-grams===")
cluster_ngram.cluster_n_grams(bigrams, 2).tolist()
# Out:
# ===Bi-grams===
# ['ввічливий персонал', 'чудовий готель', 'привітний персонал', 'дуже чисто', 'чиста кімната', 'чудовий персонал']
#
# ===Clustered bi-grams===
# ['дуже чисто', 'чудовий персонал']

# %%
cluster_ngram.cluster_n_grams(bigrams, 2).tolist()
# Out:
# ['чисте повітря', 'чудовий персонал']

# %%
# !ls data
# Out:
# bigram-pmi-negative-scores.csv  ukrainian-stopwords.txt
# bigram-pmi-positive-scores.csv  unigram-pmi-negative-scores.csv
# trigram-pmi-negative-scores.csv unigram-pmi-positive-scores.csv
# trigram-pmi-positive-scores.csv

# %%
import pandas as pd

# %%
positive_bigram_dict_df = pd.read_csv('./data/bigram-pmi-positive-scores.csv')

# %%
positive_bigram_dict_df
# Out:
#                          ngram     score
# 0             чудовий сніданок  0.255065
# 1         розташування хороший  0.255065
# 2              чистота затишок  0.255065
# 3                  тепло чисто  0.255065
# 4              усім необхідним  0.255065
# 5             персонал смачний  0.254037
# 6             номері необхідне  0.253878
# 7             просторий чистий  0.253786
# 8               торговий центр  0.253465
# 9        розташування приємний  0.253423
# 10             чисто необхідне  0.253296
# 11           привітний уважний  0.253104
# 12               затишно тепло  0.253031
# 13       відмінне розташування  0.253006
# 14             персонал чистий  0.252941
# 15          відмінний сніданок  0.252628
# 16             затишний чистий  0.252567
# 17             персонал смачні  0.252533
# 18         чудове розташування  0.252359
# 19          розташування чисто  0.252302
# 20          гарне розташування  0.252264
# 21   місцезнаходження відмінне  0.252245
# 22             чисто привітний  0.252242
# 23      розташування привітний  0.252179
# 24                 вище всяких  0.252121
# 25               чисті затишні  0.252049
# 26             хороші сніданки  0.252006
# 27             комфортно чисто  0.251883
# 28           чистий комфортний  0.251685
# 29                 тихий район  0.251659
# ..                         ...       ...
# 470             душової кабіни -0.796964
# 471               важко знайти -0.797085
# 472           сусідніх номерів -0.824116
# 473             складно знайти -0.842672
# 474              чутно сусідів -0.928679
# 475               запах номері -0.968609
# 476             бажати кращого -0.970066
# 477            душовій кабінці -0.988927
# 478             залишає бажати -1.008520
# 479             номері холодно -1.020314
# 480               вхідні двері -1.044152
# 481         чутно відбувається -1.109558
# 482          туалетного паперу -1.114460
# 483             холодно номері -1.116489
# 484             душовій кабіні -1.146336
# 485          відсутність ліфта -1.175060
# 486              запах сигарет -1.186237
# 487           сусідніх номерах -1.189264
# 488          сусідньому номері -1.260515
# 489           потребує ремонту -1.281854
# 490          чути відбувається -1.307228
# 491                тонкі стіни -1.336618
# 492            погано працював -1.378404
# 493           неприємний запах -1.379590
# 494            спати неможливо -1.399524
# 495          запах каналізації -1.419546
# 496      відбувається коридорі -1.454205
# 497   відсутність кондиціонера -1.590033
# 498        погана шумоізоляція -1.685286
# 499       погана звукоізоляція -1.936316
#
# [500 rows x 2 columns]
