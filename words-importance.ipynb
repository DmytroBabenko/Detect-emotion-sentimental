# %%
import math
import numpy as np
import pandas as pd
from sklearn.metrics import mutual_info_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS

# %%
def read_stop_words(file):
    with open(file) as f:
        stop_words = f.read().split('\n')

    return stop_words

# %%
# !ls dataset/booking
# Out:
# analyze.ipynb
# booking-rating-for-one-hot-test.csv
# booking-rating-for-one-hot-train.csv
# booking-rating-for-one-hot-val.csv
# booking-rating-test.csv
# booking-rating-train.csv
# booking-rating-val.csv
# booking-sentences-test.csv
# booking-sentences-train.csv
# booking-sentences-val.csv
# booking-test.csv
# booking-train.csv
# booking-val.csv
# create-dataset-for-rating-classification.ipynb
# create-sentence-classification-dataset.ipynb
# dnipro-reviews.csv
# ivano-frankivsk-reviews.csv
# kharkiv-reviews.csv
# kyiv-reviews.csv
# lviv-reviews.csv
# odesa-reviews.csv
# translated
# uzhgorod-reviews.csv

# %%
def read_all_frames(files):
    frames= []
    for file in files:
        df = pd.read_csv(file)
        frames.append(df)
    
    return pd.concat(frames)

# %%
def is_review_valid(review):
    if type(review) is not str:
        return False
    try:
        if len(review) == 0:
            return False
        if review == 'Nan':
            return False
        return True
    except:
        return False

# %%
reviews
# Out:
# ['Лише дівчата на рецепції - три рази мені міняли кімнату. Дякую їм.',
#  'Все. Одного досвіду вистарчило, щоб більше сюди не повертатися. Готель лише для гостей, яким байдуже умови , чистота і комфорт.',
#  'Оформлення кімнати хороше, досить приємне, на одну-дві ночі - чудовий варіант, особливо якщо врахувати ціну. Такі номери у конкурентів в два рази дорожчі.',
#  'Nan',
#  "Усе відмінно, завдяки якісному сервісу ми завжди тут зупиняємося. Цього разу ресторан було заброньовано, нам люб'язно запропонували вечерю в номер, це дуже зручно. Надзвичайно люб'язний персонал. Є територія що замикається, для мешканців з авто.",
#  'Рекомендую людям котрі подорожують власним транспортом.',
#  'Ціна/якість в принципі',
#  'душова, трохи старий ремонт, але за 500 грн за щастя . Особливо не сподобалась басовито музика, як в 16 прибув, так і до 23 ї рубала.',
#  'Приїхали з сином біля сьомої ранку, сонні та втомлені, нас заселили відразу ж . Дуже вдячна . Все чисто, гарно, свіжий ремонт, подушечки . З вікна ялиночки, ніби в Карпатах живеш) )',
#  'Nan',
#  'зупиняюсь в цьому готелі не перший раз, нажаль розчарована.',
#  'чомусь тапочки вже не дають, чайник є - а пакетик чаю забули покласти, номер на 8 поверсі під кришкою а ні жалюзі ні штор чомусь не має, цілу ніч червоний пожежний маячок блискав в очі ......',
#  'Достатня кількість побутової техніки для зручностей,великий плюс яким ми скористались мікрохвильова піч.В номері залишили сумку,все повернули в повному обсязі)',
#  'Фото номеру не відповідають дійсності,оплату знімають наперед,і по факту отримуєш номер кардинально інший.В номері брудно,на постільній білизні волосся,капці відсутні,хоча ні підігріву підлоги,ні килимів не має...поламане ліжко,на якому навіть звичайного покривала,яке б прикривало постільну білизну не було.',
#  'Чистота , тепло та відносно комфортно в номері.',
#  'Зламані гачки на вішалці для одягу . Відносно малий підсумував для полотен . Розбитий стаканчик для води коштує 100 грн . Неможливість завжди розраховуватися карткою . А можливо вам ще прийдеться бігти до іншого корпусу . щоб заплатити.',
#  'Готель дуже класний у співвідношенні ціна-якість. 2 та 5 корпуси просто бомба, перевищують всі очікування!',
#  'У 3 корпусі давно не робили ремонт та налагодили крани, стіни, опалення . Прохання не просто надсилати підтвердження бронювання, а ще й зазначати, в яких корпусах будуть номери, щоб була можливість перебронювати завчасно, а не стикатися з претензіями групи вже на місці . бо одні жили в розкішних умовах, а інші, нажаль були навіть без опалення',
#  'В цілому, все було добре. Зручне ліжко, вся техніка в номері працює, з 5 діб, що мі були прибирали 4 рази, тому в цілому було чисто. Номер відповідає фото. Двічі подовжували проживання у готелі без будь яких проблем.',
#  'В день заїзду на вулиці трошки потеплішало і адміністрація встановила опалення на мінімум . Холодно для дорослих не було, але ми були з маленькою дитиною і на прийшлось купити тепловізор, що правда адміністрація не заперечувала, щоб ми його використовували.',
#  'Nan',
#  'Холодна кахельні підлога . Не було хоча б дешевих кімнатних тапочок . Холодно та не працював кондиціонер на обігрів . Довго чекати гарячої води в душі . душових " куток " є причиною калюж у ванній кімнаті . На території не завадив би інформативний стовп з напрямками корпусів, або стенд - мапа',
#  'Зручне розташування,  привітний персонал на рецепції',
#  'Зупинялись  з друзями в 3-му корпусі. Бронювали  5 номерів. Кому як повезло. Одні номери більш охайні, інші дуже "втомлені " ,  конкретно 210 номер ще й з неприємним запахом. Сніданки не сподобались.',
#  'Нічого!!! Коли немає води, то ніщо не може сподобатись!!!',
#  'Зовсім не було ні гарячої, а ні холодної води . Персонал сказав, що зараз включать . З ранку води теж не було . Був би нормальний персонал та керівництво, то запропонували б якусь воду в пляшках, або знижку!!! Нічого не зробили!!! Неприємний день! Планував зупинитися на три ночі, але як без води? Також не було опалення . вселився та поїхав в готель " Нивки ", де все є та гарне розташування!',
#  'В номері чисто і тихо, досить комфортно',
#  'Персонал не дуже привітний, в ванні нормально не стікає вода через що підлога постійно мокра, прожектори з вулиці світять в вікна кімнати',
#  'Зручний та затишний номер із чудовим ліжком та телевізором. Привітний персонал, який вчасно виконує свою роботу та готовий вирішити будь-які запитання))',
#  "Мало розеток у номері, чайник доводилося кип'ятити на підлозі поруч із ліжком. Інколи було чути, що відбувається в коридорі, але цей шум не заважав сну чи відпочинку)",
#  'Дуже привітний персонал, ідеальна чистота, доступні ціни. З бронюванням і заселенням проблем не було. Заселилися на годину швидше, ніж було домовлено, що безсумнівно є великим плюсом.',
#  'Nan',
#  'Ресепшн працює на відмінно. Ще сподобалася охайна та велика територія.',
#  'У літку 2019 року я проживав у 5 корпусі, у номерах, було дуже жарко, кондиціонер не працював, а тільки шумів, температура в кімнаті сягала 30 град. Подумав, що це тимчасові незручності. Однак, коли я приїхав у вересні цього ж року  то вияснив, що кондиціонери не працюють навіть на нагрівання.',
#  'Сніданок був смачним і ціна була відповідна, але ціна на каву просто космічна і смак кави не відповідає ціні. Сподобалося, що не погана шумоізоляція і розташування самого готелю.',
#  'Не сподобалося, що було накурено і в правилах написано, що курити в номерах не можна, але попільничка в номері була! Не уважний персонал . Немає одноразових тапочки та щітки із пастою в номері.',
#  'Nan',
#  '1 . Холодно . Номер не опалюють . В пульті від кондиціонера немає батарейок . 2 . В номері не було гарячої води . При ввімкнені гарячої води з крану витікала вода з Ржавчик . 3 . Персонал з першого погляду привітний . Коли я звернувся на ресепшені, щоб мені допомогли з одноразовими шапочками, менеджер зреагувала миттєво, відправивши мене в інший корпус на ресепшені, наголошуючи що в них немає - закінчились, та продовжила дивитись серіал . Хочу попросити власників готелю, щоб вони звернули увагу і попрацювали з персоналом та усунули недоліки, тому що людині яка у відрядженні насправді потрібно не так і багато: WiFi, зручний Матра, гаряча вода для того щоб прийняти душ.',
#  'Nan',
#  'Дуже погана шумоізоляція відрегулювати температуру не можна, не працює пристрій який відповідає за цю функцію душова не зовсім чиста, є грибок Не відомо чи ідентифікований був туалет до того коли люди заїхали Багато волося на підлозі, і на Коврига Думаю там ще ведуться ремонти тому, що щось дуже шуміло з ранку Персонал на рецепції привітний',
#  'Nan',
#  'Не рекомендую відрядженим з державних установ дуже паршива система оформлення документів за проживання суму за проживання броньованому через буквені номері не можливо на декілька чоловік',
#  'безкоштовна парковка на території, дуже великий номер, у номері є все необхідне (фен, праска), співвідношення ціна/якість на висоті, спочатку навіть здивувався але номер був кращим ніж я очікував, був в готелі вперше і буду надалі зупинятися в ньому!',
#  'у номері був слабкий неприємний запах',
#  'Nan',
#  'ресепшені не відповідає в телефонному режимі...Холод . Кондиціонери немає кому налаштувати покривала на ліжку засмальцьовані .... яжуть прокурений весь номер, запах тухлих в номері 101, корпус 2 В напівлюкс навіть ножів немає і мінімального набору посуду...Про бані халати мовчу...Ціни підвищили, а якість закладу понизилася! Гарне спостереження, яке має завжди певні наслідки!',
#  'Nan',
#  'Дуже поганий сервіс на рецепції . Ні доброго дня, ні " на все добре, приїжджайте ще " . Чомусь співробітниці не привітні і непрактичні, не люблять коли щось намагаєшся дізнатись . Чому так? Другий раз те саме . Третього, певно, не треба ...',
#  'Доволі просторий номер з усім необхідним',
#  'Брав номер на 2 доби . В перший день в номері було доволі холодно . матрац " побитий " життям, нерівний . На другий день, прийшовши в номер і відкривши вхідні двері, там смерділо, наче там відкрили громадську вбиральню . Звернулися на ресепшн, на що нам без жодних емоцій сказали, що таке може бути, оскільки ремонтували каналізацію . Після такого вселилися не ночував другу добу!!!',
#  'готель с тав найкраще! Реєстрація зайняла близько 2-х хвилин . вже не потрібно надавати банківську картку, котрою було оплачено готель, на столах вже немає роздрукованих аркушів з даними кредитних карток . на парковці завжди є місця для авто',
#  'Nan',
#  'Оптимальне співвідношення ціна-якість. Зупиняюся тут вже вдруге і зупинюся ще не раз) як для Києва, то тут дуже приємні ціни та гарні умови за невисоку плату.',
#  'Nan',
#  '10 хвилин на уберіг від станції метро Житомирська , 55 грн . Досить непоганий та дешевий варіант добратись до готелю якщо ви без свого автомобілю',
#  "На рецепції готелю адміністратор дала ключ не від того номеру який я забронював, кімната була на вулиці ніби підсобку для сторожа чи для якихось гастарбайтерів, на рецепції сказали шо могло номерів не стати, шо могла бути якась помилка в системі, але через якихось 3 хвилини дали ключ від того номера якого я забронював . Напевне це зв'язано з тим що в мене на аккаунті в Букін 0 (нуль) репутації та відгуків так як аккаунт новий і вирішили шо мене можна обдурити",
#  'Все сподобалося. Зручний комфортний номер з усіма необхідними зручностями. Співвідношення з ціною супер.  Не один раз ще буду зупинятися в цьому готелі. Усім рекомендую. Будете задоволені.',
#  'Nan',
#  'Брали сімейний номер. Дуже задоволенні! Номер чистий і просторий. На прохання безкоштовно доставили дитяче ліжечко.',
#  'Неприємний запах в ванній кімнаті.',
#  'Nan',
#  'Персонал адекватний, но на питання цьому я в телевізорі небожу вставити USB флешку хоть вона є в меню телевізора відповіли що неможна так як кронштейн не рухається і підключити ви труду нічого зможете . За такі гроші це адекватний варіант але не очікуйте більше . І саме головне!!!!!!!!!!!! ДВА лежачих поліцейських З металу І високих!!!!!!!!! В мене низька машина, якщо я проїхавши рівно то все і мені кожний ранок і вечір потрібно « гратись » спочатку одним колесом по діагоналі і другим!!!!!!!!!!!!',
#  'Розумне співвідношення ціни та якості',
#  'Ремонтні роботи, які проводили перфоратором вранці - без попередження...на моє зауваження мені запропонували номер в іншому корпусі, але МО плани на ранішній відпочинок були зруйновані ...',
#  'Nan',
#  'Я замовила номер підвищеного комфорту, але не було навіть найменшого . Номер розташований над банкетний залом . Два дні гриміла музика, а після 12 ночі меблі сховали по полу з страшенним гуркотом . Співробітники говорили, що вони не можуть ні на що впливати . У ванній кімнаті душ відділений самою шторкою, після купання вся підлога у воді, це середньовіччя, а не підвищений комфорт!!!',
#  'Величезним плюсом стало те, що нас заселили швидше (ми приїхали о 9, а заселення відбувається о 14) Величезне ліжко з комфортним матросом.',
#  'Проживали у номері у новій будівлі ,тому була трохи брудна підлога .\nОдноразові тапочки потрібно купляти окремо :(',
#  'Nan',
#  'Телевізор не працював, Матра ліжка був пошкоджений, та не дав нормально виспатись . Поскаржився адміністратору, але нічого не було зроблено!!! Номер не відповідає заявленій категорії!',
#  'Ціна дуже дешева, але готель страшенно гидкий.',
#  'Цей готель має рейтинг 7,9 але така оцінка далеко не відповідає дійсності, він на рівні 5,5: на коридорі смердить сигаретним димом і якоюсь затхле побутовою хімією . В номері дуже поношені меблі, плитка на підлозі і в ванній дуже брудна, заляпані попередніми мешканцями . Там не варто розвиватись . На весь номер гудить старий брудний холодильник, на тумбочці є електрочайник, який не працює взагалі . прибиральники, невідомо чого, на унітаз чіпляють позначку " продезинфікувати ", але насправді там навіть вода добре не злита після попередніх мешканців, постіль вимощена стольним кремом, під столом скручені дроти і стирчить зі стіни дороблена розетка . Словом не знаю хто лишає тут добрі відгуки, готель знадвору виглядає ніби новим, але всередині він дуже гидкий.',
#  'Їхали з грудною дитиною . В номері нам поставили краватку для малята . За що ДУЖЕ Дякуємо!',
#  'Ну як, може бути в номері 1 розетка!?!????\nОсобливо в номері з кухнею. Витяжка та чайник, а на кухні - ЖОДНОЇ РОЗЕТКИ!',
#  'Гарний готель, в номері « полу - люкс » був свіжий ремонт . За розмірами великий близько 50 квадратів . Чисто . Білі рушники і постіль приємно ахнули . Дуже виручив кондиціонер, бо день був дуже жаркий . На території є ресторан, де смачно можна поснідати . Найбільш сподобалося скрізь пахне сосновим лісом.',
#  'В душевній були проблеми зі стоком, вода не збігала . Подзвонив на рецепцію, прислали молоденьку дівчину, яка просто вимовила воду (але вела себе достойно), сказала що сьогодні проблему не вирішать (було 17 : 00) і до мене незабаром передзвонить...Дзвінка нажаль так і дочекався ...',
#  'Чисто, затишно. Співвідношення ціна-якість добра.',
#  'Відношення персоналу. Чому ніде немає інформації, що для людей, які знаходяться у відрядженні потрібно мати на руках наказ про відрядження???',
#  '1) дуже чисто\n2) зручні ліжка \n3) дуже чиста постіль та рушники \n4) хороша шумоізоляція\n5) великий та смачний сніданок \n6) безкоштовна парковка',
#  'непривітний персонал . Будь ласка, зверніть увагу на навчання працівників . готельний дуже хороший і чистий . А хамство дівчини, яка зустрічає на ресепшені, залишає дуже негативне враження . На просте питання: « Де можна припаркувати машину? », отримали: « Ви водій, ідіть і шукайте »',
#  'Номер зі всіма зручностями за ціною хостела . Наявність фену те праски . Для подорожуючих у справах на автівці, розташування на Кільцевій дорозі — це зручно.',
#  'Не вистачало в номері письмового чи журнального столика . Але наявність двох комоді врятувало ситуацію . розеток могло бути більше, заряджати ґаджети доводилося по черзі . Але враховуючи ціну й інші зручності — це не так критично.',
#  'Nan',
#  'Поганий заїзд на територію готелю, людині, незнайомій з місцевістю складно не пропустити поворот, ми заїхали з іншого боку заправки до недіючої брами. Зробіть, будь ласка, нормальний вказівник до заїзду',
#  'кожний день прибирання, шампунь і мило, за 17 днів три рази зміна пострілі, кожний день свіжі рушники, цілком пристойно у співвідношенні ціна якість . Рекомендую.',
#  'Nan',
#  'Звичайний « бюджетний готель » нічого особливого',
#  "Готель знаходиться в незручному місці, корпуси розкидані по всій території, можна переплутати готель і якусь компанію . Рецепція та оформлення готелю в старому стилі, тобто без ремонту . Кімната . Двері скриплять, пустий міні-бар (як що він не передбачений як сказали на рецепції, то вказуйте на сайті). Коли відкрив шафу на мене посипалася пилюка, ковдра вся в пилюці (їх там було дві) і з неприємним запахом . Також була присутня недільна дошка яка була вся в плямах та розводами . В душі чисто, рушники чисті, постільна білизна була в волоссі, подушка в плямах з неприємним запахом . Вигляд з вікна - в під'їзд який будується.",
#  'Чисто і затишно',
#  'Не знав як розпізнати напівлюкс, думав що про це десь має бути написано, при виселені виявилось що ми проживали в стандартному . Якщо такі стандартні номери, то напівлюкс напевно ще кращі.',
#  'Знання того що я сюди більше ніколи не повернуся',
#  'Замовили номер на 4 х осіб з 2 ма кімнатами, в результаті коли ми приїхали в 1 й годині ночі ми дізнаємося що в нас номер на 3 х, в результаті довелося знімати ще 1 номер . Піднявшись в номер я бачу якісь кімнати з незакінченим ремонтом, підлогу не витерли від цементу, чи що то там було, стоїть сильний запах шпаклівки і сирості, і бачимо картину що в одній кімнаті просто забрали 1 ліжко, а от в ванній кімнаті залишилося 4 набори для душу (тут вони прокололися як ми бачимо, просто нас вирішили кинути). Одна кімната з без розеток і з них тільки стирчать оголені дроти, вікна у фарбі, повезло що нам не дали робу і не змусили нас продовжувати ремонт там.',
#  'На другий день відпочинку покоївка запропонувала прибрати.',
#  'На ресепшені до нас зверталися російською . Не було капців, чомусь вони були платні...Не вистачало магнітної сітку на вікні.',
#  'Було тихо, спокійно, чисто . Все працювало . Навіть намагались прибрати в номері . У черговий раз порадував ресторан, ціни для Києва досить ліберальні, зручно, що є де перекусити . Територія велика можна вийти, посидіти на лавці, під тую.',
#  'Розташування за межами міста, важко добиратись, прогулятись за межами готелю ніде, треба їхати в центр. У бронюванні необхідно вказувати номер корпуса, а то при реєстрації заїзду потрібно бігати від корпусу до корпусу, з торбами. Холодильник гудів цілу ніч, довелось його вимкнути.',
#  'Розташування просто чудове, зупинка відразу біля готелю,сніданками не користувався,тому не можу розповісти',
#  'Ручка в дверях та кришка унітазу були поламані',
#  'Дуже зручна постіль! Тихо, безкоштовна парковка, ресторан на територiї.',
#  'адмін i житло в рiзних корпусах, треба ходити туди сюди, дуже багато людей, бо там 4 корпуса багатоповерхових не дуже затишно, душ був зламаний . телевiзор висiв збоку вiд лiжка, не зручно дивитись.',
#  'Кімната доволі простора . Є балкончик і світло біля ліжка . Доволі чисто.',
#  'Таргани у ванній. З коридору чутно все і всіх. (дуже погана звукоізоляція) Ліхтарі на вулиці світять прямо у вікно.',
#  "Усе нове - номер одразу після ремонту, нові меблі і т . д ., хороший швидкий ліфт, є тепла вода, хороший напір води, непоганий інтер'єр, є балкон, два телевізори в номері (хоча ми їх не включали).",
#  "Не працював кондиціонер (при тому, що номер на сонячній стороні), хоча кондиціонер був заявлений у пропозиції, тому щодо робочого кондиціонера треба обов'язково уточнювати . Не було штор / жалюзі - лише тюль, тому в номері дуже світло навіть вночі (ззовні яскраве вуличне освітлення). А найбільше розчарував персонал - недостатньо ввічливий (місцями нахабний), не всі розуміють, як потрібно ставитись і спілкуватись з клієнтами . Ще з дрібниць - оскільки номер щойно після ремонту, то підлога недостатньо вимита - якщо провести пальцем, то на ньому залишається злегка помітний білий слід . Ну і дуже шумно з відкритими вікнами - кільцева дорога . А з закритими - спекотно (непрацюючий кондиціонер). Номер здавався зі знижкою (нібито по акції), і лише після поселення стало зрозуміло, чому зі знижкою.",
#  "Ми жили 4 ночі . Змінили 4 номери . 2 були хороші і 2 не дуже . Перший був дуже гарний з балконом і вид з балкону був в ліс . Другий номер був непоганий, але балкон був суміжний з цегляною будівлею на в проти . Тобто там є недобудований корпус і сильно накурено, доступу до свіжого повітря не було абсолютно . Третій номер був без балкону, але гарний . Четвертий номер був гарний і балкон нормальний, виходив на подвір'я готелю . Зато гаряча вода чомусь текла з іржею і поганий напору . Дивно що всі балкони були на два номер, тобто навіть перегородки ніякої не було і сусід міг ходити просто під перед нашими вікнами і залишити щось на балконі також було страшно . Співвідношення ціна якість хороша, але питання в який корпус і який номер ви пропадете",
#  'Nan',
#  'Непогані матраци на ліжках та гарно показував телевізор',
#  'Стара шафа, ніякого виду з вікна, старий ремонт, відносно не дуже чисто та попільнички у номерах!',
#  'Гарний номер з видом на ліс . теріторіях шикарно! до метро Академмістечко . 8 км . дуже все зручно . персонал приватний . для такої ціни супер . ресторан на території дорогий!! але є в 100 м наліво гарний ресторан . та кафе',
#  'Nan',
#  "Територія готелю чудова, дуже затишно. Номер просто прекрасний. Такий просторий, багато світла. Ліжко велике, нереально зручне. Вразила своїми розмірами та інтер'єром ванна кімната. Персонал готелю привітний.",
#  "1 . Розташування . Трохи далеко від метро . 2 . Були недоліки в номері . Біля дверей у ванну, збоку біля вимикачів були трошки здерти шпалери . Вода з душової кабіни протікала на підлогу, я не могла нічого знайти щоб витерти воду, а білих рушників було трохи шкода . Не було капців у номері . У взутті ходити якось не хотілось у такому гарному номері, а підлога все ж трохи прохолодна відносно, та і босими ногами, наприклад після душу, теж не хочеться ходити . Тому було набагато краще якби в номері все ж були б якісь капці . 3 . Ресторан, точніше офіціанти . Ввечері, коли ми замовили 2 бокали пива, офіціанти не могли розібратись хто ж має їх наповнити . Хоч і сніданок не входив у вартість нашого номеру, ми вирішили просто спуститись в ресторан, і щось замовити . Замовили американський сніданок . З гарячих напоїв ми обрали каву . Зазвичай каву я п'ю після того як поїм . Офіціант не уточнив порядок подачі, і приніс каву одразу, в той час як ми ще чекали основні страви . Прийшлось пити каву холодною . Коли ж нам принесли основну страву, то забули подати булочки . І тільки тоді коли ми запитали для чого масло у сніданку і на що його наказувати, уже інший офіціант згадав що щось таки нам не донесли )",
#  'На стільки жахливо, що зо ціна і не висока, готель не вартує того!',
#  'Адміністратор грубий, задавали запитання при поселенні - вона зиркала, брудно, шумно, вікна взагалі не ізолюють, а готель над трасою, спати нереально, подушки не зручні',
#  'Сподобалось, що можна було заселитися до 00 : 00.',
#  "Чистота відсутня абсолютно, відсутність ремонту в номері (ванна кімната - було страшнувато), розташування телевізора вразило наповал :) покоївки, які їздять ліфтом - це візитна картка цього закладу . Гості - ходять пішки, у зв'язку з відсутністю вільного місця у ліфті :) Загалом - не вразило, повертатись не будемо.",
#  'Чисто, затишно, недорого. Непоганий ремонт.',
#  'корпус 1 номер 102 . У номері не було капців, розетки зайняті холодильником, телевізором і кондиціонером, лише одна на весь номер вільна і та біля підлоги і далеко від ліжка . Біля ліжка ні розеток, ні окремого освітлення . Не дали можливості роздрукувати документи з електронної пошти, напевно ця опція доступна у дорожчих готелях.',
#  'Ми зупинилися на дві ночі у двокімнатному сімейному  номері в 5 корпусі. В номері дуже чисто, є праска з дошкою, в кожній кімнаті телевізор та кондиціонер,чайник. Рестораном не користувалися,тому про їжу для туристів нічого сказати не можу. Територія комплексу простора, дуже затишна. Поруч знаходиться сосновий ліс.\nПроживанням у цьому готелі дуже задоволена і раджу всім!',
#  '-',
#  'Розташування відмінне. До станції метро Академмістечко 5хв. до станції метро Житомирська також 5хв. Дуже зручна стоянка для автомобілів. Привітний персонал. В номерах затишно, чисто. Гарна звукоізоляція. Велика та чиста територія навколо будинків. Обов"язково буду рекомендувати друзям зупинятись тільки в цьому готелі. Та й сама, думаю, ще не раз тут буду зупинятись та відпочивати. Приємно була вражена сервісом.',
#  'Гадаю, що в номерах люкс та напівлюкс повинні бути тапочки, мінеральна вода.',
#  'Місце розташування дуже зручне, приємний персонал. Нова постільна білизна та рушники.',
#  'санвузол доволі старий, не можу сказати що чисто . Погано вмивався унітаз, погане освітлення, жодного гачка для рушників . Погано зачинялися двері у санвузол . Не зручне розташування електричних розеток.',
#  'Вартість проживання, зручне для нас розташування.',
#  'Номер був розташований на першому поверсі, вікна виходили на центральний вхід корпусу і розорити їх було неможливо . Старі, місцями подерті меблі . Кондиціонер встановлений був так, що дуло на ліжко і його можна було використовувати лише поки не лягли відпочивати . Номер не відповідає фото, заявленому під час бронювання.',
#  'За таку ціну, все новеньке, більш менш сучасне! Головне комфортне!  Поселили за 3 хв о 12 ночі))(',
#  'постільну було трошки чи запили чи шо) ) а так все гуд) )',
#  'хороша ціна, чиста постіль',
#  'оплату потрібно проводити в іншому корпусі, який не зрозуміло де знаходиться, що дуже незручно з речами бігати по всій території',
#  'Тихий номер, ніхто не заважав.Дякую.',
#  'Не сподобалось лише те, що прибиральниця достала мої продукти з холодильника і залишила на столі....що вона з ними робила не зрозуміло, але ввечорі, коли я прийшла в номер вони були теплі та зіпсовані...',
#  'Nan',
#  'Був замовлений номер в новому корпусі, що було підтверджено бронюванням . Фактично дали номер з старим ремонтом, брудною білизною і поламаними меблями . Поміняти відкладалися, сказали, що вільних номерів немає',
#  'Чисто досить',
#  'В номері 5091 станом на сьогодні не працює телевізор, хитається унітаз, лійка душа бризкає в різні боки, розетка RJ -45 без кришки, на ліжку біля вікна нема всіх ламелей ...',
#  'Зручне ліжко і балкон в номері. Чистота і дуже привітний персонал. Територія, як завжди чудова і доглянута',
#  'Санітарний вузол це проблема цього готелю, при тому в усіх номерах . Дуже разючий контраст на шикарній подачі номеру, навіть в стандартах і санвузлів . Можливо варто задуматись про капремонт санвузлів.',
#  'Гарне співвідношення ціни та якості. В номері було все необхідне: фен, праска та дошка для прасування, холодильник та чайник.',
#  'Не достатньо щільні штори, тому зранку яскраво світило сонце та приходилося рано прокидатися.',
#  'Гарний готель в межах досить великого комплексу. Професійний персонал. Вдалий вибір для працівників у відрядженні, для груп туристів. Для сімейного проживання - хіба переночувати і їхати далі. Ціни - поза всякою конкуренцією.',
#  'Nan',
#  'Nan',
#  'На рецепції з мене, громадянина України, зняли туристичний збір, як з іноземця, а так як я не взяв квитанцію по оплату номера, то довести нічого не зміг. Висновок - працівник на рецепції просто обманює клієнтів.',
#  'Просторе приміщення, якісний ремонт, всі послуги заявлені на сайті були, в номері все, що потрібно для якісного відпочинку. Прекрасні краєвиди з вікна 6-го поверху. Можна відпочити від суєти великого міста.',
#  'Звукоізоляція не дуже, було чути, як стукають двері в сусідів. Та це не дуже заважає, головне, що все зручно і в номері. Все було на високому рівні.',
#  'Чудове розташування . Зупинка " в двох кроках " від готелю . Кілька зупинок - і ти на метро станції Житомирська . Дуже чисто в номері . привітний персонал . Дякую!!!',
#  'Не сподобалося, що при заселенні гості самі повинні шукати по території свої номери в тій чи іншій будівлі . На території багато будівель і коли ти втомлений з дороги - тяжко зорієнтуватись в якому саме напрямку на ресепшені персонал вказує руками " Вам сюди, а потім зверніть Он туди " . Щодо номера...(в моєму випадку напівлюкс) В загальному був гарним і чистим . Не сподобалося, що у вітальні пошкоджена розетка (скоро можна буде вирвати її зі стіни) і весь час доводилося її смикати, щоб ввімкнути праску, потім чайник, потім холодильник . В цьому плані не зручно і небезпечно . Можливо, треба подумати про з\'єднувач . І у душовій кімнаті не працює лампочка над дзеркалом (дрібниця - але вважаю, що можна поміняти). Ще хотілося б, аби готель виділив кошти на одноразове взуття для своїх гостей Маю бажання декілька слів залишити і про ресторан, що знаходиться на території готелю . В загальному - ресторан Хороший . Але не сподобалося, що деякі офіціанти не уважні (особливо до відвідувачів на терасі): не приносять меню - доводилося довго чекати або йти брати самому, а потім ще й дивуються " чого це сам прийшов по меню? "; один офіціант переплутала замовлення + забула принести каву; ще в меню не описана подача певних страв (потрібно офіціанту про це розповідати при замовленні, або ж переробити меню з описом подачі )',
#  'Співвідношення ціни та якості, персонал достатньо стриманий та ввічливий, відповідь на будь-яке питання у них була завжди готова',
#  'Слабка звукоізоляція, номер без вікна(тобто сама рама була, але це не вікно, а виходило воно схоже на службове приміщення), варто, мабуть, про таке попереджати',
#  'Сподобалось все, крім деяких моментів . У 8 годин вечора, робітники почали свердлити стіни і було дуже некомфортно знаходитись в номері, ми перебували на першому поверсі . Зранку коли вирішили попрасувати речі праскою, яка стоїть в шафі, вона виявилась не зовсім робочою, вся вода, яка була в Парасці налита вона витекла просто на речі, при чому з усіх вирок, які в ньому були, праска взагалі не нагрівається до тієї температури, якою можна попрасувати, незадовільні дуже цим моментом, тому що речі залишились не пораховані та ще й мокрі . А так, все дуже сподобалось, те що є кондиціонер в номері, це взагалі перевершило сподівання . Спати було комфортно, туалет та душ були чисті . Повернемось до вас ще раз!',
#  'Nan',
#  "Інтер'єр,кондиціонер,все необхідне для перебування на кілька днів. Зручно коли є машина.  Білосніжна постіль",
#  'Перед бронюванням подзвонила в готель, щоб дізнатись чи можна (за умови бронювання) у них залишити багаж та використати розетку, щоб зробити накрутку волосся дитині . З Радміну відповіли - Бронте, але на рахунок розетки не знаємо чи є в холі',
#  'Розташування прямо біля зупинки, від метро недалеко! У номері чисто і зручно, персонал привітний, вода гаряча є, праска, дошках в номері, кондиціонер! Клас!',
#  'Nan',
#  'Nan',
#  'Не компетентний персонал. Чекала на поселення 1,5 год (з 14.15 год - 15.30 год), причому був готовий лише один номер, на інший чекала довше. Постільна "білизна" була волога, такі ж рушники. Не рекомендую!!!',
#  'Єдиний плюс який був це коли кожного дня нам прибирали номер і з воювали рушники',
#  'Дуже багато мінусів в готелі! Подушки жахливі, « ошальовані », якійсь обрані, всі в плямах . На таких бридко спати!!! В перший день при заселенні на нас випали двері з шафи . Добре що нікого не прибило . Фото доручаємо цієї шафи і ошальовані х подушок . Персонал обіцяв на наступний день прислати когось щоб з ремонтували шафу . Протягом 4-ох днів проживання шафу так і не полагодили . Двері стояли просто збоку Перті на стінку . шафою ми так і не користувались . Тримали речі у валізі . Також в номері була фірмова книга готелю в якій був вказаний перелік безкоштовних послуг який надають проживаючи, в цьому переліку був вай Фай, безкоштовний сніданок . Коли ми прийшли на рецепцію то нас повідомили що ми забронювали через Букін і сніданок в нас не включений! Але чого ж тоді не забрати з номеру ту книгу з переліком безкоштовних послуг в яких був прописаний безкоштовний сніданок? Також в цьому готелі є кілька корпусів і коли ми ввечері заселялись то двічі ходили на рецепцію, яка знаходиться в 3 корпусі щоб нам пояснили як дойти до нашого корпусу . супроводу в них нема! Ходиш ввечері гуляєш по території в пошуках того корпусу куди тобі видали ключі . Також в нашому корпусі не було світла на поверсі . Уявіть собі приїжджаєш пізно ввечері коли темно і йдеш світи телефоном щоб знайти свій номер, ну це вже після пошуків корпусу в який тебе заселили . Одноразові тапочки які мали б бути в 3 зірковому готелі відсутні . Їх продають на рецепції . халатів в номері теж не було',
#  "Якщо не рахувати наведені недоліки, які у більшості пов'язані із не надто сприятливим місцерозташування, то можна сказати, що номер був доволі комфортний, є фен, санвузол, мікрохвильова піч, електрочайник, телевізор, зеркало, тумбочки, холодильник . Все працювало . І нарешті був працюючий кондиціонер . Хоча якщо є мікрохвильова піч то чому не було ложки, ножа та виделки, проте стакани були . Приємно вразив ресторан, ціни досить, як для Києва, ліберальні.",
#  'Це комплекс, як наслідок є літні тераси, де надто голосно грає музика, причому десь до дванадцятої години ночі, далі я все ж таки заснув . Для чогось зробили дуже великі щілини унизу вхідних дверей до номера, через які чути, наприклад які проблеми у прибиральниці чи то розмову пізнього не надто тверезого гостя . Мабуть це можна усунути . Дуже далеко від житлових масивів та інших закладів . Таке враження, що якщо не рахувати сам комплекс то це промисловий та торгівельний район . По великому рахунку для туриста не підходить . Це більше для людей, які їдуть у Київ у справах . Хоча номери виправдали себе, за винятком електрочайник, у якому була цвіль . Немає поруч, або на території комплексу, аптеки із елементарним набором медикаментів, наприклад від похмільного голови . Навколо кільцева дорога, де таксисти не завжди безпечно її перетинають . Не має якогось більш - менш нормального транспортного сполучення . Та власне комплекс вже за межами міста . Доцільно було б писати при бронюванні номер корпуса, а то бігаєш від одного до іншого і питаєш де це було здійснено бронювання.',
#  'Мало яка Гостинний пропонує і праску з дошкою і чайник в номері . Цим приємно вразили . Чисто, спокійно, затишно . привітно.',
#  'На дві ночі перебування в ванній був тільки 1 пакетик шампуню (тільки шампунь без кондиціонер / бальзаму). То ж, їдучи в гостиницю, потрібно брати із собою і шампунь і кондиціонер / бальзам для волосся . А так решта, все добре.',
#  "Дуже привітний персонал. Цікавий інтер'єр. Наявність на території комплексу послуг перукарні. Затишна атмосфера",
#  'Не зручно в душі . Низькі бортики і вода зі шторки розтікається на підлогу . З вулиці на територію комплексу ведуть сходи . Вони круті і небезпечні . На підборах можна легко відвернути ногу',
#  'Сніданок досить смачний. Номер затишний, траси не чутно. Близько зупинка громадського транспорту.',
#  "1 . Офіціантка на сніданку . Не зрозуміло, навіщо взагалі взялася за обслуговування . З таким невдоволеним обличчям працювати треба в іншому місці . Не спитала, коли принести каву . Принесла відразу, цукор забула . Коли принесла млинці, забула сметану . З рахунком винен був йти до барної стійки, бо ніхто не йшов за коштами . 2 . Холодильник у номері не працює . Температура в ньому вища за кімнатну . 3 . У душі страшно стояти . кахель ось - ось відважиться і підіб'є пальці на ногах.",
#  'Дівчата на ресепшені ввічливі і якісно виконують свою роботу . Номери, рушники і постіль - все чисте . Хороші зручні матраци.',
#  'Дуже гудить витяжка в ванній кімнаті та ще й приклеєна скотчем.',
#  'Атмосфера на вулиці . можливість паркування',
#  'Поламані замки, погано закриваються двері в номер та ванну, прокурений номер (попільниці в номері є - напевно дозволяють) нечутно, неприємно ходити по голому кабелю в номері, користування душком неудобно - заливає підлогу, неудобно розташування унітазу, витяжка решітка віддалена.',
#  'Співвідношення ціни та якості. Уважність та ввічливість персоналу. Парковка поблизу номеру, наявність там вільних місць',
#  'Не дуже чисто в номері. В душі в системі каналізації залишки людського волосся',
#  'Гарно, зручно й комфортно',
#  "Не повідомляють про обов'язковість додаткової сплати туристичного збору Незважаючи на те, що за декілька кілометрів є піцерії та заклади харчування, доставляти відмовляються, так як вважається, що це вже не Київ",
#  'Завжди вибираю цей готель, бо тільки тут знаходжу холодильник, чайник, праску, фен, телевізор, душ в одному номері . Не треба ходити в кімнату для прасування.',
#  'Дуже чутливість висока і шпарини під дверима в коридор',
#  'Розташування.',
#  'Номер просто Жахливий . В номері валялися чужий труси . Раковина протікала у ванній по повно води!!!!. босими ногами не можна ступити .... Номер в який мене поселили не відповідав тому який я забронював . Довелось піднімати всіх на ноги . Поміняли...На шафах зверху, навіть на світильниках і ванній — - на сірник!!!!!! пилу!!!!!! Чесно!!! Мені соромно було за них...Ресторан жахливий...совдепії - кухня!!!!!!!!!!',
#  'Приваблива ціна. Досить комфортні номери.',
#  'Відсутність трансферу хоча б до метро: можна було б зробити навіть платний . Нажаль, таксі - не ідеальний варіант, бо один з таких глухарів ледве не вбив гостя перетинаючи 4 смуги просто майже поперек траси! У 5 корпусі кімната сонячної сторони не мала занавіски або жалюзі, тому зі сходом сонця, воно просто било в обличчя і не можливо було спати . Вже декілька разів обирав цей готель для своїх гостей, завжди все було супер, а от цього разу якось не склалося . Персонал не завжди навіть показував хоча б " чергову " натягнуту посмішку до нашого гостя з Португалії, в ресторані на сніданок замість масла (яке і так мало бути) дали булочку, за яку порахували окрему плату . Молоко також, виявляється, не входить в сніданок . Не знаю, чи оберу цей готель в черговий раз, нажаль ...',
#  'Зручне розташування та привітний персонал',
#  'В номері дуже брудно було . Пилюка була на всьому де було її помітно, здавалось ніби її не витирали там місяць, притомна що номер без балкону . Посуд в плямах, і на вінця побитий . Пити воду було неможливо із за ймовірності травмування себе',
#  "Beautiful place good services everything It's hotel is clean good people in Reception thank you for everything and hope Comeback soon",
#  'Нічого все класний',
#  "Дуже сподобалося в Верховині . Зручно, комфортно, чисто . Територія гарна, красива, приємний персонал . В номері чистота, кожного дня прибирали та клали нові шампунь та мило . В ресторані смачний обід . Обов'язково ще приїдемо.",
#  'Хотілося б щоб таксисти міста хоч трошки орієнтувалися де знаходиться Верховина, але це звичайно не проблема гостиниці, а звичайно таксистів) )',
#  'Nan',
#  'не сподобалась підлога з плитки, від неї було неймовірно холодно в туалеті побиті дзеркала і звичайно місце розташування . нас (як туристів) відвезли спочатку на одну адресу, потім виявилось шо нам взагалі за КИЇВ (',
#  'Приємне обслуговування персоналу, в корпусі 3.',
#  'Заселення в готель . В корпусі 1 прийшлося довго чекати адміністратора . Потім, дівчина з дуже великим незадоволенням відправила провести оплату картотекою в корпус 3 . Бо тільки в корпусі 3 можна оплатити, якщо ти забронював через Букін . сом . Все це відбувалося під грозою, і процес заселення тривав 30-40 хв . Після 700 км дороги, до Києва, Було ДУЖЕ радісно! ходити між корпусами під грозою, ...',
#  'Надзвичайно чисті номери, наявний кондиціонер. Приємна місцевість навколо',
#  'Необхідно до опису додати як дістатися до місця, адже готель знаходиться всередині комплексу будинків і в‘їзд лише 1. Плюс вкажіть скільки становить туристичний збір',
#  'Чистота! Сніданок! Зручності! Дуже гарний Готель!',
#  'Все сподобалось. Номер дуже гарний. Замало телеканалів, але телевізор надоїв удома :-) Не для цього я приїздив у Київ.',
#  'Привітний персонал, чистий та просторий номер, зручний. Є можливість роздрукувати чи відсканувати документи. Природа поруч із готелем дуже гарні краєвиди, невеличкий ліс.',
#  'На території важко знайти де саме знаходиться рецепція. Прибувши пізно ввечері ми блукали територією шукаючи вхід хоч в один із корпусів, щоб дізнатися куди нам потрібно йти, щоб заселитися. \nЗ цією проблемою нам допомогли іноземні жителі готелю.',
#  'Готель знаходиться далеко від центру, але якщо ви на машині, то зручно. Затишний,тихий двір. Номери просторі. Розетки коло ліжка. Є холодильник. Чисті постіль та рушники.',
#  'Відсутність лампи біля ліжка ( тільки верхнє освітлення ),що не дуже зручно. По кутках лишився мусор.',
#  'Гарний, привітний, чемний персонал. Співвідношення ціни-якості. Достатньо комфортні умови проживання. Миттєве заселення. Невимушена атмосфера. ДУЖЕ ГАРНИЙ ландшафтний дизайн. Чистота.',
#  'Непрацюючий холодильник, відсутність мікрохвильової печі у номері - при бронюванні готель заявляв наявність даного обладнання. Одноразові капці у номері відсутні, продаються по 20 гривень.',
#  'Новий корпус, блок вентиляції-кондиціювання, стиль номеру. Без проблем замінили зіпсований номер на справний.',
#  'В першому номері (потім ми попросили його змінити, й наше прохання задовільними) були поламані: злив санвузла, забитий душових злив і протікаючи шланг для душу . Раковина дуже вузенька і над нею виступає поличка дзеркала - вмитися ще той квест), на щастя у другому номері було все ОК! Додатковий збір комісії про який не попередили тут на сайті...І найголовніше це розташування, оскільки, через бюрократичні моменти, де - юре готель знаходиться не в Києві - ми годину його шукали по вулиці зазначеній тут на сайті і тільки з другого разу людина з готелю по телефону повідомила нас про розташування у селі (насправді, де - факто це все ще Київ, але зі своєю маленькою громадою) Раджу телефонувати й запитувати розташування в деталях, щоб не поїхати на однойменну вулицю у м . Києві, що за 10 км . від реального розташування готелю . А власникам чи скоріше керівникам змінити адресу тут на сайті - booking . com!',
#  'Сподобалася чистота в номері, і наявність гарячої води. Ще більше сподобався красивий сосновий лісок навколо і тиша.  За сніданок та Wi-Fi -- лише зараз дізнаюся про їх наявність з цього сайту. Відповідно чи були вони в готелі і на якому рівні -- мені не відомо.',
#  'Номер доволі холодний, бо абсолютно всюди в якості підлоги там викладена керамічна плитка, лиш навколо ліжка є 2 малесенькі клаптики ковролін.',
#  'Хороші великі й просторі номери. Гарне співвідношення ціна/якість.',
#  'Далеко розміщено, практично на кінцевій станції метро + пішки/автобусі. але для власників авто буде зручно, бо багато паркомісць і легше добиратись.',
#  'Дуже чисто, ліжко зручне',
#  'санвузол з не цілісними меблями та не зручним душем, вода в душі не гаряча, в номері холодно, сусідів, які опівночі повертаються " под Шафер " чутно і заважає спати.',
#  '+ хороша ціна\n+ просторо і зручно',
#  '- персонал не привітний\n- дуже холодно в номері, бо перед заселенням відкрили вікно на довгий час. Опалення виключене.',
#  "Незважаючи на те, що готель знаходиться біля автостради - на диво шуму машин зовсім не було, Нащо великий плюс . Гарне розташування корпусів . Гарний вид з вікна і приємний інтер'єр в номері, номер напівлюкс дуже просторий, великі вікна: )",
#  "Дуже довго заселялись, приїхали ввечері близько 10 ої і були досить змучені...+ попросили паспорт, хоча не попереджало про його обов'язкову наявність Я б не радила людям при бронюванні вказувати всі данні своєї картки, бо, на жаль, всі данні є відкритими для працівників готелю ...",
#  'ціна якість на висоті, я би навіть сказав би, що якість перевищує ціну .. в номері була зручне ліжко, чиста свіжа постіль, балкон, телевізор з плоским екраном, душ, чиста ванна кімната .. короче за такий номер в Києві треба платить 1000-1200 грн, тут же коштує 450-500, помножимо на дві ночі і отримаємо значну суму .. Я для себе вирішив, що цей готель на сьогодні для мене є в пріорітети ..',
#  'холодно було, але Кондор мав функцію підігріву, тому вийшов з положення і нагрів номер ..',
#  'Приємне обслуговування.',
#  'Дуже близько розташовані 2 ліжка і до того ж біля голови холодильник стоїть (гуде)... ті хто любить спати в тиші, це не варіант . полотен потрібно брати з собою свої, вони є і чисті але вже старі.',
#  'Чистий та акуратний номер зі всіма зручностями . Здивували наявність чайнику, мікрохвильової, холодильника та навіть поразки з дошкою!!!! Залишились дуже задоволеними . Всім рекомендую.',
#  'Nan',
#  'Ціна і якість. Загалом все дуже добре.',
#  'Не було капців . Адміністратор готелю пояснила, що капці видаються в номерах Люкс . Різниця між " Простим " номером і номером Люкс у капцях . Якщо Ви забронювали простий номер, то Вам прийдеться докупити капці за 20 грн . І Ви вже в номері " Люкс " . От такі неприємні монашества з\'явилися в готелі . Здається, що це просто персонал деякий вирішив підзаробити окремо для себе.',
#  'Сподобалось розташування, велика площа номера, чистота',
#  'Довгий процес заселення, відсутність гарячої води (вода була ледь тепла на протязі всього періоду проживання )',
#  'Просторий чистий номер з балконом. Звідти було добре видно авто. Зручно було з дитиною. Супер, що є фен і електрочайник. Дуже приємно, що пізно ввечері заселяють.',
#  'Все сподобалося. Могли би бути капці в номері. Думаю, це потрібна річ.',
#  'недалеко від Житомирської, їздять маршрутки, хороший на вигляд комплекс, чиста ванна і всі гігієнічні засоби є, телевізор і мінімальний посуд та холодильник',
#  'погана звукоізоляція, було чути що відбувається за стінкою. нас поселили на першому поверсі - повз вікна постійно ходили люди, і не було приватності, довелось закривати штори цілодобово',
#  'Nan',
#  'Щоразу як в різних готелях, але чомусь (за ту саму ціну) все гірше і гірше . Цього разу світло на вході не горіло, кран у душі протікав, опалення не регулювалося, пластикове вікно не прилягало (зламане кріплення). На прохання надати лампочку, мені запропонували звернутися на ресепшн сусіднього корпусу.',
#  'Nan',
#  'Все сподобалося. Номер комфортний, в номері чисто, постіль білосніжна, ліжка зручні. Ми дуже задоволені. Велике дякуємо персоналу та керівникам за належний рівень.',
#  'В готелі є ліфт, номер досить просторий',
#  'Прибирання..( під ліжком слой пилюки, штори брудні...( Після прийому душу вода розливається по всій ванній кімнаті , потрібно кожного разу протирати підлогу',
#  'Nan',
#  'Відсутній сервіс ресторану . Номери телефонів ресторану, які дали на ресепшені не відповідали . Ввечері за водою а зранку за кавою довелося йти на заправку',
#  "Номер затишний, постіль м'яка і чиста, рушники, мило, шампунь, капці - все як треба. Розташування біля соснового лісу додає плюс до вражень",
#  'Загалом все було добре, але ванна кімната напрошується на ремонт',
#  'Ввічливий, привітний персонал. Гарні, чисті, комфортні номери. В номерах тепло. Велике дякуємо за комфортно проведений час у Вашому готелі.',
#  'Такого немає. Сподобалося все.',
#  'Nan',
#  'неспівпадіння кімнат з показаними на фото по сайту, шумоізоляція відсутня, чути все що робиться на поверсі, номера потребують ремонта, меблі обшарпані, в сан вузлі меблі взагалі потребують заміни, плитка на підлозі затерти.',
#  "Новий корпус, просторий номер, вишуканий інтер'єр, привітний персонал.",
#  'Іржавий наліт від води в унітазі варто забрати, бо псує загальне приємне враження від номера.',
#  'Тепло і чисто в номері, чайник, праска, дошка для прасування,  холодильник, всі зручності.',
#  'Далеко від центру, та у доступності є зупинка автобуса і доступне Хубер таксі.',
#  'Без сніданку. Розташування - комфортне і зручне, до метро не далеко, а головне - що у "зеленій" зоні Києва.',
#  'Не порадувала ванна кімната, дуже брудно, санвузол не виправдав очікування. У переліку наявних речей в номері, не було знайдено телефон, шукали повсюди, проте......мабуть забули принести.',
#  '1) Для тих, хто у відрядженні, надається повний пакет документів . 2) Зручне розташування . Зупинка міського транспорту в 2-3 хвилинах пішої ходи . 3) Доступна ціна, як для кордону з Києвом . 4) Поруч заправка, магазин . Ресторан є на території готельного комплексу . 5) В принципі, швидка реєстрація . 6) При заселенні проживаючи надається набір міні - косметики, капці, одноразовий засіб для чистки взуття . 7) В номері є телевізор, холодильник, чайник, склянки, чашки, відкривача, попільничка, а також дошка для прасування та праска . 8) Постіль і рушники чисті, білосніжні . 9) В номері є балкон . 10) Номер просторий, місця вдосталь.',
#  '1) Є певні недоліки в плані чистоти . 2) щоденного прибирання немає, проте готель про це попереджає . 3) В номері прохолодно, радіатор ледь працює . 4) Не вистачає розеток . Ті, що є, заставлені меблями . 5) Виникають незручності при заселенні . Щоб знайти місце реєстрації, що відбувається у 3-у корпусі, знадобилось 20 хвилин . 6) При бронюванні через Букін, автоматично списують вартість проживання за одну добу в якості передоплати та підтвердження бронювання . Якщо грошей на карті не вистачає, бронювання знімають не попереджаючи, як сталось і зі мною . 7) шумоізоляція дверей жахлива . Чутно все...і навіть більше.',
#  'Великий, світлий, чистий номер. Є все необхідне (халати, тапочки, чайник, маленький холодильник, праска, миючі, щітка для одягу...',
#  'пропадало світло, правда не на довго . В ванній кімнаті були проблеми з світлом, на наше зауваження, сказали, що вже визвали електрика, але він приїде тільки після того як ми виселить Було дуже темно, приходилось завжди присвячувати телефоном . Біля одного ліжка відсутня розетка, хоча нічний стояв на тумбочці.',
# ...
#  'Nan',
#  'Холодно',
#  'Сніданок не оцінюю, бо виселятися до сніданку',
#  'Nan',
#  'Nan',
#  'Відсутній сніданок',
#  'сніданок міг бути кращим',
#  'ванна кімната',
#  'Дуже гарний та просторий номер',
#  'Було дуже жарко',
#  'Готель новий, чистий.Номер дуже комфортним, персонал приємний. Все чудово!',
#  'Nan',
#  'Чудово на ті гроші',
#  'В номері хотілось би бачити питну воду',
#  'Бронювання проводилось на три номери одночасно, але чомусь всі були розміщені в різних корпусах.',
#  'Сніданок  міг би бути кращим.',
#  'Nan',
#  'За одні і ті ж гроші можна отримати кардинально різні номери, а 3 зіркам відповідає тільки один корпус',
#  'Місце розпорошення, великий, чистий, комфортний номер, привітний і ввічливий персонал )',
#  '-',
#  'Зелена зона навколо . просторі Нумер.',
#  'Дуже шумно, коли водночас проходить декілька весільних заходів.',
#  'Все було добре!',
#  'Nan',
#  'Nan',
#  'Будо дуже шумно, через те що на вихідних там зазвичай святкують весілля',
#  'Nan',
#  'за такі гроші (950 грн) є на багато інваріанти ...',
#  'Nan',
#  'Дуже Грязнов',
#  'Nan',
#  'Було дуже холодно, ставлення персоналу було не саме краще',
#  "інтер'єр, чистота.",
#  'Відсутність посуду',
#  'Nan',
#  'Таргани!!!',
#  'Доброзичливість персоналу',
#  'Погане розташування електричних розеток біля ліжка',
#  'Комфортні номери по ціні і по якості. Всім рекомендую',
#  'Nan',
#  'Nan',
#  'сміття біля ліжок, під ліжками',
#  'В номері було чисто, номер великий',
#  'Поламані деталі меблів.\nВода або каналізація мала запах',
#  'Знаю цей готель кілька років! Приємно що те що добре не змінюється!',
#  'Потрібна більш ретельна підтримка Интерьер.',
#  'Чистий хороший готель,ціна приємна,рекомендую',
#  'Все добре',
#  'Умови проживання',
#  "Два лежачих поліцейських при в'їзді на територію, - прямий шлях на сто.\nПросто жах.",
#  'Розміри номера',
#  'Таракан В номері!!! телевізора замалий дл такого номера, його дивитися нереально!',
#  'Новісінький номер',
#  'Відсутність штор і дзеркала у номері',
#  'Зручне',
#  'Nan',
#  'Все сподобалось)',
#  'На жаль не було ні ножа, ні виделок, взагалі нічого.',
#  'Хороше розташування,доволі приємний персонал і чистота на 4/5.',
#  'Відсутність кімнатні лапок . Відсутність питної води.',
#  'Nan',
#  'білизна була мокра, ковдра у плямах',
#  'ні, занадто дорого',
#  'Ціна на харчування',
#  'Ціна-якість',
#  'На сайті було вказано, що в ціну входить сніданок, а по факту - ні!!!',
#  'Красива територія,приємний персонал.Номер чистий.Рекомендую',
#  'Nan',
#  'Ввічливий персонал.',
#  'Біля ліжок в номерах явна недостатність розеток.',
#  'Готель дуже сподобався! Чисто, доглянуто, все, що було заявлено, в наявності, працює. Ми залишились задоволеними!',
#  'Nan',
#  'персонал',
#  'Nan',
#  'Nan',
#  'Грибок в душе, рваною Бельке, не рекомендую',
#  'Nan',
#  'ресепшені ужалений, прийшов і вже шось должен, насмішки і помилки, якби не проплатив завчасно розвернувся і поїхавши звідти',
#  'Nan',
#  'Персонал не привітний, відношення хамське',
#  'Все було чудово. За таку ціну - навіть більше ніж достатньо',
#  'Все було чудово!',
#  'Гарний сніданок! Чисто, затишно, тихо! Наступного разу також зупинюсь у Верховині!',
#  'Nan',
#  'Чистота та спокій на території готелю',
#  'Відсутність ванної у номері (присутня частина ванної кімнати, котра загороджена ширмою з тканини, із душем)',
#  'Дешево',
#  'Зламаний бачок унітаза/ шум від дороги при відкритих вікнах, непривітний персонал.',
#  'Вартість- супер. Чисто, біла постіль і рушники, зручні ліжка, гарна територія, є парковка',
#  'Розетки - мало, а до деяких не дістати',
#  'Чисто, тихо, в лісі, за свою ціну дуже гарно.',
#  'Щоб поселитись потрібно бігати по корпусах . Оплата замучена.',
#  'Затишно, все, що треба наявне',
#  'Доставка з Києва сюди не приїде\nОкремий туристичний збір, який можна було б закласти у вартість',
#  'Дуже чисто!!! Гарний просторий номер,',
#  'Розміщення - таких вулиць є дві, і ми спочатку поїхали. Не туди',
#  'Все крім харчування',
#  'Ціни на харчування',
#  'Сподобалось все, крім сніданків та вечері, ціни зашкалюють',
#  'Ціни на харчування',
#  'Все добре, сподобалось.',
#  'Nan',
#  'Дуже невдовзі ліжка, о 19.00 зламався унітаз, полагодили лише наступного дня о 14.00',
#  'Nan',
#  'Добрий сніданок, місто розташування задовільне. Для мене все було зручно.',
#  'Витікає вода з душовій кабінки та слабка система вентиляції.',
#  'Досить гарний та просторий номер.',
#  "Було б набагато краще, якби були якісь вказівники біля в'їзду на територію готелю.",
#  'Все',
#  'Нічого',
#  'Напевно нічого!',
#  'Брудно, білизна не свіжого запаху, мебель пошкоджена та поламана.',
#  'Чисто та просторо',
#  'Персонал',
#  'Nan',
#  'Немиті залозі та подушка з пір,я.',
#  'Nan',
#  'Не вистачало кімнатних капців, підлога була липка.',
#  'район где гостиниці',
#  'нормально',
#  'Красивий вигляд, чистота',
#  'Nan',
#  'Комфортний номер, приємний персонал))',
#  'Nan',
#  'Все. Чистий і комфортний номер',
#  'Мені сподобалося все',
#  'Відношення ціни та якості',
#  'В душі пліснява і під час прийняття душу вода у всій ванні кімнаті',
#  'огромный номер, добрі меблі і декор',
#  'Nan',
#  'Стильний та чистий номер',
#  'Халати та тапочки не включені у вартість.',
#  'Чисто і акуратно',
#  'Здивувала відсутність лапок',
#  'Приємний персонал, допомогли і підказали як краще оформити оренду',
#  'не влаштовує шумоізоляція і прибирання в кімнаті, стан сантехніки',
#  'Сподобалось усе все було дійсно на висоті за ті гроші .',
#  'Розташування якщо збираєтесь у цей готель краще за усе їхати машиною далеко метро',
#  'Ціна',
#  'Таргани, старий ремонт, заблокували гроші на картці',
#  'Nan',
#  'цвіль у душі',
#  'Простір та чистота.',
#  'Nan',
#  'Nan',
#  'Кондиціонер працював погано і було дуже душно в номері',
#  'Nan',
#  'Номери вже давно потребують ремонту. Особливо душова... Застаріла постіль',
#  'Чудове співвідношення ціни та якості',
#  'Nan',
#  'Nan',
#  'Не працював кондиціонер при температурі +32',
#  'Чистота в номері та новий ремонт',
#  'Nan',
#  'Дуже просторий номер',
#  'Нема витяжки в душі. Жарко трішки',
#  'Чисто, затишно, зручно, доступне житло',
#  'В першому корпусі подушки потребують прання. Білизна чиста , а подушки мають запах поту .',
#  'Nan',
#  'Не підготували номер і не працював кондиціонер',
#  'достойна якість обслуговування та вирішення питань',
#  'здерти трохи шпалери, але істотно помітно ((',
#  'Гарна територія, спокійно. Чудовий ресторан',
#  'Nan',
#  'Прекрасна природа соснового лісу навкруги, гарний ландшафтний дизайн на території комплексу, що органічно вписується у довкілля.',
#  'Nan',
#  'Ліжко',
#  'Не працює кондиціонер. \nПоганий злив в душі.',
#  'Як завжди - добре співвідношення ціни та якості!',
#  'Nan',
#  'Nan',
#  'Не було питної води. Душ можна сказати відсутній',
#  'Комфорт проживання, привітний персонал на рецепції, облаштування внутрішньої території',
#  'Nan',
#  'Чистота, затишок, сніданок,',
#  'Nan',
#  'Гарне співвідношення ціни та якості!',
#  'Далеко від центра',
#  'Привітний персонал, тиша та спокій.',
#  'деякі моменти вказують що досить тяжко підтримувати номери в належному стані, особливо коли щось псується...',
#  'Місцеположення',
#  'Не було пульта від телевізора, не працював електрочайник.',
#  'Гарне співвідношення якості та ціни. Завжди є місце парковки. Великі номери.',
#  'Nan',
#  'добре',
#  'пліснява у ванній кімнаті, відсутність одноразових лапок.',
#  'Персонал кваліфікований,  дуже чисто в номерах',
#  'Душ в номерах не зручний',
#  'Хороші умови за низьку ціну. Гарна природа навколо. Добре сполучення від метро',
#  'Відсутність нормальних кафе і магазинів поблизу',
#  'Чисто, тихо, велика територія',
#  'Хороший готель за адекватну вартість',
#  'Дуже чисте повітря, тиша та пташки будили з ранку.',
#  'Nan',
#  'Наповнене світлом, вікна на трьох стінах',
#  'Душова, вода витікає на підлогу ванної кімнати',
#  'Відповідність ціні',
#  'Душова непродумана, вода виливається на підлогу ванної кімнати.',
#  'Все відповідало опису.',
#  'Nan',
#  'Зупиняюсь не вперше, як і в попередні рази, все було добре і без "сюрпризів"!',
#  'Відсутність одноразових капців. В попередні рази вони були(((',
#  'Хороший персонал, дуже чисто в номерах і на поверсі. Все нове',
#  'Розташування зручно тільки якщо на власному авто.',
#  'Співвідношення ціна-якість, просто ідеальне!)',
#  'Раніше бронювали номер в 3 корпусі, там сподобалось більше, ніж в 1 корпусі, але цілком задоволена! )',
#  'Nan',
#  'Шумно від окружної, але при зачинених вікнах все норм.',
#  'нормальний сімейний номер за гарною ціною',
#  'двері у душову кімнату не зачиняються . підсвітка у душовій напрацює',
#  'Подушкін не комфортні',
#  'Nan',
#  'Великі кімнати. Чисто. Ціна відмінна',
#  'Nan',
#  'все, персонал, розташування,',
#  'нічого, все чудово, нема спортивного каналу, не дивився футбол',
#  'Прекрасний номер і ще краща ціна)))) Зручні матраци. Чисто та охайно.',
#  'Nan',
#  'співвідношення ціна-якість. Приємні ціни як для столиці',
#  'Nan',
#  'Загальний вигляд номеру, чистота, свіжість, наявність кондиціонер.',
#  'Розташування далеко від метро. Холодильник ледь-ледь працює.',
#  'Великі чисті номери',
#  'Nan',
#  'Nan',
#  'Відсутнє одноразове взуття',
#  'Персонал привітний, уважний. Номер чистий, комфортний.',
#  'Nan',
#  'Е',
#  'Не розумію, чому готель заздалегідь не попереджає про туристичний збір  у розмірі 44 грн за день, хоча я не турист, власне....',
#  "Комфортно для сім'ї. Є ліфт.",
#  'Nan',
#  'Великий номер. Чисто',
#  'Nan',
#  'Великий номер. Чисто',
#  'Nan',
#  'Вартість та умови проживання',
#  'Довга черга при реєстрації',
#  'Надзвичайно комфортне ліжко.',
#  'Nan',
#  'Все сподобалося',
#  'Nan',
#  'Номер великий. Тихо',
#  'Nan',
#  'Елмер великий . Тихо',
#  'Nan',
#  'великий і чистий номер',
#  'не працював холодильник, замінити відмовились, капці і халат теж відсутні',
#  'Nan',
#  'Недостатньо чисто, відсутність одноразового взуття',
#  'Дуже гарний готель! Сподобалось все!!!',
#  'Nan',
#  'Зручне розташування для подорожуючих.',
#  'Відсутність холодильника',
#  'Сніданок був не смачним',
#  'чистота бажає кращого',
#  'Дуже просторі і чисті апартаменти за низьку ціну.',
#  'В душі була ледь тепла вода.',
#  'Новий корпус повністю відповідає співвідношенню ціна/якість',
#  'Nan',
#  'Співвідношення ціни та комфорту❤️',
#  'Nan',
#  'Супер',
#  'Nan',
#  'Чудове співвідношення ціна - якість! Радує око стиль, чистота і комфорт.',
#  'Зверніть увагу на сходи які ведуть до зупинки громадського транспорту',
#  'Nan',
#  'Брудно, на жаль',
#  'Номер , та персонал',
#  'Висока сутність',
#  'Сосновий ліс біля готелю, було приємно і спокійно',
#  'Nan',
#  'Швидке заселення в номер',
#  '1.Сморід сигарет в номері',
#  'Nan',
#  'Не сподобалось, що прийшовши о 14:40(заселення о 14:00) не були готові номери для заселення, довелось чекати.',
#  'Ціна цілком адекватна . Номер великий , просторий , чистий та тихий ! Однозначно рекомендую!',
#  'Nan',
#  'Nan',
#  'ресторан',
#  'Все,що нам необхідно було,це чисто і всі зручності! Так що,супер!',
#  'Нас все влаштувало!',
#  'привітний персонал, незважаючи на пізнє заселення . Дякую.',
#  'Nan',
#  'Чудовий варіант! Співвідношення ціни та якості. Відмінне розташування.',
#  'Nan',
#  'Nan',
#  'дверний замок в дуже поганому стані, неможливо вставати ключ . шумоізоляції немає, всю ніч слухав звук машин їду по по дорозі',
#  'Дуже затишний, сучасний номер. В номері є все необхідне. Зупиняюсь не перший раз і всім рекомендую!',
#  'Nan',
#  'Зручне місцерозташування. Велика площа номерів, холодильник, чайник, капці, халати. Дитячий майданчик, велика парковка',
#  'Немає рідкого мила',
#  'Готель цілком шикарний',
#  'душова кабінка, коли купається, то вода по всій ванні',
#  'Очікування і реальність співпали, це саме головне, Тому-то вибирала по картинці',
#  'Все чудово',
#  'Гарний готель враховуючи вартість.',
#  'Nan',
#  'Гарне співвідношення ціни і якості, гарна тереторії',
#  'Nan',
#  'Уважний, ввічливий персонал. Чисто та комфортно. Гарний вигляд з вікна.',
#  'Nan',
#  'Сподобалось все!!!! Дякую.',
#  'Nan',
#  'дуже хороший готель із багатьма корпусами!',
#  'Nan',
#  'Гарні умови, за невеликі гроші. Зручно для подорожуючих на автомобілі.',
#  'Метод резервування.',
#  'НОМЕРА ШИКАРНІ  ЦІНА ДОСТУПНА В ВЕРЕСНІ НАС БУДИ 30 ГОСТЕЙ У ВАС',
#  'Такого небуло за 4 дні, щоб щось сподобалось',
#  'Цього разу, забронювали на 5 днів, все як завжди супер.',
#  'Nan',
#  'Зручно, затишно, чисто',
#  'Nan',
#  'Nan',
#  'Жахливий запах у номері . Хоч номер - для не курячих, проте запах був як у курилці нічного клубу.',
#  'Загалом, все добре.',
#  'В номері не було ні чайника, ні мікрохвильовки. Як для відвідувачів, що у відрядженні - не зручно.',
#  'Nan',
#  'відсутні полички в душовій для мила та шампуню',
#  'Nan',
#  'Тримач для душа треба опустити нижче бо вода тече мимо тебе а відрегулювати неможливо.',
#  'паперовий величезний готель, привітний персонал.',
#  'Nan',
#  'розташування',
#  'багато що зламано',
#  'Nan',
#  'обладнання',
#  'Номер чистий, є все необхідне.',
#  'Не суттєво, але були зламані полички в тумбі і шафі.',
#  'Nan',
#  'Фотографії помешкання на сайті, не відповідають фактичному вигляду номера.',
#  'Зручне розташування, приємне обслуговування, затишний  та великий номер.',
#  'Немає зауважень',
#  'хороше поєднання ціна/якість',
#  'важкувато від метро',
#  'Гарний готель в співвідношенні ціни-якості.',
#  'Nan',
#  'Nan',
#  'В номері не було холодильника',
#  'Nan',
#  'Жахлива шумоізоляція номера...чути все, що відбувається в коридорі, особливо ранкове прибирання номерів на поверсі.',
#  'Недорого',
#  'Брудно, поламане ліжко',
#  'Гарний, затишний, теплий номер . А ліжко просто мрія - широке, матрац виміру жорсткий, спати на ньому саме задоволення!',
#  'Nan',
#  'Nan',
#  'Довго добитися\nКухня співвідношення ціна і якість не дуже.',
#  'Розташування, чиста постіль, чистий номер.',
#  'Дуже холодно, батарея була ледь теплою, в ванній було як в холодильнику',
#  'Сподобалось розміщення готелю . Чистий та комфортний  номер .',
#  'Nan',
#  'Все',
#  'Нічого',
#  'Мене тішить дуже ціна!',
#  'Nan',
#  'Ціна - якість . Все просто і зручно.',
#  'Холодна ванна кімната, в номері прохолодно.',
#  'Великий , просторий номер з трьома великими вікнами . Тишина.',
#  'Було трохи холоднувато. Тоненькі літні ковдри. А за вікном майже весна...',
#  'Nan',
#  'Виникли проблеми з заселенням, номер не був підготований вчасно, доволі прохолодно, старі брудні меблі',
#  'Чистота, міфі, мікроклімат.',
#  'Першого вечора не було шампунь, гаряча вода ледь тепла.',
#  'Все',
#  'Погано працював кондиціонер на тепло',
#  'За такі гроші кращого не має',
#  'Nan',
#  'Смачна їжа в ресторані, затишний номер',
#  'В номері було дуже холодно, батареї не достатньо, а кондиціонер не працював',
#  'Чисто але ремонт старий. Персонал привітний',
#  'Ванна ну дуже стара',
#  'Все дуже добре',
#  'Nan',
#  'великі просторі номери,навколо ліс',
#  'у ціну номера не входив сніданок (у всякому разі, якщо бронює на банкінгу), що не дуже зручно!',
#  'Все прекрасно. Чудовий персонал, зручні номери. Є абсолютно все необхідне.',
#  'Було прохолодно в номері',
#  'Ціна відповідає якості) Персонал уважний.  На рецепції привітні дівчата)',
#  'В 4 - му  корпусі потрібен ремонт.',
#  'Приємний і комфортний номер, а за таку ціну взагалі подарунок',
#  'прохолодно в у ванній кімнаті і я забув шарфик: ((',
#  'Nan',
#  'Не працював Змієвих в душі Не працював холодильник',
#  'Тихо, спокійно.',
#  'Nan',
#  'Дивлячись на вартість номеру - все просто супер!',
#  'Було трошки прохолодно',
#  'Лише дівчинка на ресепшені знає своє діло . небайдужа та приваблива!',
#  'Номер хоч і великий  але брудний .',
#  'Чисто, просторо, топ за такі гроші)',
#  'Nan',
#  'Гарні номера. Чисто зручно, є кондиціонер, холодильник, телевізор, чайник і навіть праска.',
#  'Не працює термінал . Не було Геля для душа.',
#  'Все',
#  'Все',
#  'Все гарно.',
#  'Сподобалось все, окрім душу',
#  'На жаль в багатьох номерах не включені сніданки',
#  'Nan',
#  'Тепло, затишно, недорого.',
#  'Nan',
#  'Дуже сподобалося розташування , чистота, сервіс!',
#  'Nan',
#  'Влаштувало все',
#  'З ранку була не достатньо гаряча вода',
#  'Nan',
#  'ужас гадючник',
#  'Ідеальне співвідношення ціна/якість , наявність фену',
#  'Мало розеток',
#  'Гарне співвідношення ціни і якості. Шикарне широке ліжко.',
#  'Nan',
#  'Співвідношення ціна/якість - супер.',
#  'Розташування. Хоча транспортне сполучення непогане.',
#  'Nan',
#  'Бракує душової кабінки.',
#  'Чудовий готель! Зручне розташування. Дуже чисто! Проживання було дуже комфортним. Велике ліжко! Холодильник!',
#  'Nan',
#  ...]

# %% [raw]
# files = [
#     'dataset/booking/booking-train.csv',
#     'dataset/booking/booking-test.csv',
#     'dataset/booking/booking-val.csv'
# ]

# %%
full_df = read_all_frames(files)

# %%
len(full_df['pos_text'].values)
# Out:
# 134083

# %%
def get_pos_neg_review(df):
    pos_texts = df['pos_text'].values
    neg_texts = df['neg_text'].values
    
    gt_score, reviews = [], []
    for i in range(0, len(df)):
        if is_review_valid(pos_texts[i]):
            reviews.append(pos_texts[i])
            gt_score.append(1)
            
        if is_review_valid(neg_texts[i]):
            reviews.append(neg_texts[i])
            gt_score.append(0)
            
    return reviews, gt_score

# %%
reviews, gt_score = get_pos_neg_review(full_df)

# %%
uk_stop_words = read_stop_words('./data/ukrainian-stopwords.txt')

# %% [markdown]
# ### 1. Word frequency

# %%
def get_topk_ngram(df, ngram_range=(1,1), k=None, stopwords=True, with_count=False):
    '''
    Extract the most frequently occurred words in countvector
    '''
    if stopwords:
        temp = []
        for name in hotelDf.hotelName.unique():
            for token in name.split():
                if len(token) > 1:
                    temp.append(token)
        my_stop_words = ENGLISH_STOP_WORDS.union(temp)
        vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words=my_stop_words, max_features=500)
        
    else:
        vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words=None, max_features=k)
        
    countvector = vectorizer.fit_transform(df['review'])

    # Get topk occurred ngrams
    topk_words = []
    sortedindices = countvector.toarray().sum(axis=0).argsort()[::-1][:k]
    counts = countvector.toarray().sum(axis=0)
    
    for i in sortedindices:
        word = vectorizer.get_feature_names()[i]
        
        if with_count:
            count = counts[i]
            topk_words.append((word, count))
        else:
            topk_words.append(word)
            
    return topk_words

# %%
topkTotal = get_topk_ngram(hotelDf, k=500)

# %% [markdown]
# ### 2. Mutual information

# %% [markdown]
# **Mutual information tells you how much you learn about X from knowing the value of Y (on average over the choice of Y).**
#
#
#
# Since we found the word frequency is not a good indicator for the sentiment analysis, we will examine *mutual information*  for an alternative metric.
#
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mutual_info_score.html

# %%
# let's calculate Mutual Information for unigrams and bigrams
vectorizer = CountVectorizer(ngram_range=(1,1), stop_words=uk_stop_words, max_features=500)
countvector = vectorizer.fit_transform(reviews)
densevector = np.array(countvector.todense())
    
# miScore_unigram = pd.DataFrame(data = {'word': vectorizer.get_feature_names(),
#              'MI Score': [mutual_info_score(gtScore, densevector[:,i].squeeze()) for i in range(500)]})

miScore_unigram = pd.DataFrame(data =
                               {'MI Score': [mutual_info_score(gt_score, densevector[:,i].squeeze()) for i in range(500)]}
                              , index = vectorizer.get_feature_names())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
# Bigram version
vectorizer = CountVectorizer(ngram_range=(2,2), stop_words=uk_stop_words, max_features=500)
countvector = vectorizer.fit_transform(reviews)
densevector = np.array(countvector.todense())
miScore_bigram = pd.DataFrame(data =
                    {'MI Score': [mutual_info_score(gt_score, densevector[:,i].squeeze()) for i in range(500)]},
                    index = vectorizer.get_feature_names())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
miScore_unigram.sort_values('MI Score', inplace=True, ascending=False)
print('Mutual Information - Unigram')
miScore_unigram.head(10)
# Out:
# Mutual Information - Unigram
#               MI Score
# персонал      0.067876
# розташування  0.062621
# чисто         0.040511
# привітний     0.031284
# nan           0.027092
# зручне        0.019928
# хороший       0.018283
# місце         0.018195
# чистий        0.017932
# затишно       0.016047

# %%
miScore_bigram.sort_values('MI Score', inplace=True, ascending=False)
print('Mutual Information - Bigram')
miScore_bigram.head(10)
# Out:
# Mutual Information - Bigram
#                       MI Score
# привітний персонал    0.033663
# зручне розташування   0.017697
# місце розташування    0.009666
# приємний персонал     0.009136
# погана звукоізоляція  0.007070
# чудове розташування   0.006828
# інтер єр              0.006487
# центрі міста          0.006430
# персонал привітний    0.006034
# ванній кімнаті        0.005576

# %% [markdown]
# ###  3. Pointwise Mutual Information

# %%
def getPMI_ngram(reviews, gt_score, gt, ngram_range=(1,1), max_features=500):
    vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words=uk_stop_words, max_features=max_features)
    countvector = vectorizer.fit_transform(reviews)
    densevector = np.array(countvector.todense())
    
    px = sum(gt_score == gt) / len(reviews)
    pmis = []
    
    for i in range(max_features):
        py = sum(densevector[:,i] == 1) / len(reviews)
        pxy = sum((gt_score== gt) & (densevector[:,i] == 1)) / len(reviews)
        
        if pxy == 0:
            pmi = math.log10((pxy + 0.0001) / (px * py))
        else:
            pmi = math.log10(pxy / (px * py))
            
        pmis.append(pmi)
        
    gt_name = 'positive' if gt == 1 else 'negative'
    pmis = pd.DataFrame(data = {'pmi' + gt_name: pmis}, index = vectorizer.get_feature_names())
    return pmis.sort_values('pmi' + gt_name, ascending=False)

# %%
gt_score = np.array(gt_score)

# %%
pmiPos_unigram = getPMI_ngram(reviews, gt_score,  1, max_features=2000)
pmiNeg_unigram = getPMI_ngram(reviews, gt_score,  0, max_features=2000)
pmiPos_bigram = getPMI_ngram(reviews, gt_score,  1, ngram_range=(2,2), max_features=2000)
pmiNeg_bigram = getPMI_ngram(reviews, gt_score,  0, ngram_range=(2,2), max_features=2000)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# ### Let's see what PMI values tell us about the reviews

# %%
print('PMI for positive reviews - Unigram')
pmiPos_unigram.head(10)
# Out:
# PMI for positive reviews - Unigram
#             pmipositive
# торговий       0.251974
# стильний       0.251648
# просторо       0.250339
# шикарне        0.249222
# відмінне       0.249179
# похвал         0.248875
# необхідним     0.247499
# чудове         0.247456
# просторий      0.246833
# швидке         0.246613

# %%
pmiPos_trigram[900:1000]
# Out:
# Empty DataFrame
# Columns: [score]
# Index: []

# %%
print('PMI for positive reviews - Bigram')
pmiPos_bigram.head(10)
# Out:
# PMI for positive reviews - Bigram
#                        pmipositive
# чудовий сніданок          0.255065
# розташування хороший      0.255065
# чистота затишок           0.255065
# тепло чисто               0.255065
# усім необхідним           0.255065
# персонал смачний          0.254037
# номері необхідне          0.253878
# просторий чистий          0.253786
# торговий центр            0.253465
# розташування приємний     0.253423

# %%
print('PMI for negative reviews - Unigram')
pmiNeg_unigram.head(10)
# Out:
# PMI for negative reviews - Unigram
#             pminegative
# погана         0.342608
# відсутня       0.339392
# неприємний     0.339246
# брудні         0.338132
# брудно         0.337215
# тонкі          0.334506
# брудний        0.334448
# неможливо      0.332829
# незручно       0.331634
# жахливий       0.330902

# %%
print('PMI for negative reviews - Bigram')
pmiNeg_bigram.head(10)
# Out:
# PMI for negative reviews - Bigram
#                           pminegative
# погана звукоізоляція         0.349638
# погана шумоізоляція          0.347431
# відсутність кондиціонера     0.346193
# відбувається коридорі        0.343876
# запах каналізації            0.343157
# спати неможливо              0.342714
# неприємний запах             0.342251
# погано працював              0.342223
# тонкі стіни                  0.341177
# чути відбувається            0.340378

# %%
pmiPos_trigram = getPMI_ngram(reviews, gt_score, 1, ngram_range=(3,3), max_features=2000)
pmiNeg_trigram = getPMI_ngram(reviews, gt_score, 0, ngram_range=(3,3), max_features=2000)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
pmiPos_trigram
# Out:
#                                  pmipositive
# персонал ввічливий готовий          0.255065
# приємний персонал смачні            0.255065
# приємний персонал хороший           0.255065
# приємний персонал чистий            0.255065
# персонал смачні ситні               0.255065
# чисто тепло комфортно               0.255065
# кухня усім необхідним               0.255065
# чисто тихо комфортно                0.255065
# приємний персонал чистота           0.255065
# кімната зручне ліжко                0.255065
# чисто тихо спокійно                 0.255065
# персонал розташування центрі        0.255065
# персонал розташування готелю        0.255065
# готель відмінний персонал           0.255065
# готель відмінне розташування        0.255065
# персонал просторий номер            0.255065
# персонал приємний ввічливий         0.255065
# готель березі моря                  0.255065
# персонал привітний чисто            0.255065
# хороший сніданок чисто              0.255065
# персонал привітний сніданки         0.255065
# чисто хороші сніданки               0.255065
# персонал привітний розташування     0.255065
# персонал привітний рекомендую       0.255065
# персонал привітний дружелюбний      0.255065
# ліжко привітний персонал            0.255065
# просторий номер хороший             0.255065
# просторий номер чисто               0.255065
# ліжко хороший сніданок              0.255065
# приємний персонал сніданок          0.255065
# ...                                      ...
# чутно сусідньому номері            -1.263449
# вранці гарячої води                -1.276414
# стіни чути сусідів                 -1.276414
# москітну сіток вікнах              -1.282754
# відбувається сусідньому номері     -1.282754
# жодного разу прибирали             -1.301238
# відсутність гарячої води           -1.303644
# номері питної води                 -1.313137
# відсутність холодильника номері    -1.313137
# маленька ванна кімната             -1.318966
# чутно відбувається сусідньому      -1.324719
# неприємний запах номері            -1.346995
# шумоізоляція чутно відбувається    -1.346995
# вікнах москітну сіток              -1.368184
# номер потребує ремонту             -1.368184
# погана шумоізоляція чутно          -1.371618
# міні бар порожній                  -1.378404
# номері неприємний запах            -1.378404
# каналізації ванній кімнаті         -1.378404
# поганий wi fi                      -1.417033
# стіни тонкі чутно                  -1.426176
# відсутність чайника номері         -1.469211
# тонкі стіни чути                   -1.474640
# біля вхідних дверей                -1.477329
# слабкий напір води                 -1.500810
# перебої гарячою водою              -1.544276
# слабкий wi fi                      -1.544276
# чути відбувається коридорі         -1.669214
# погана звукоізоляція чутно         -1.674354
# чутно відбувається коридорі        -1.761968
#
# [2000 rows x 1 columns]

# %%
pmiNeg_trigram
# Out:
#                                  pminegative
# запах ванній кімнаті                0.352442
# неприємний запах ванній             0.352442
# слабкий натиск води                 0.352442
# погана звукоізоляція чути           0.352442
# запах каналізації номері            0.352442
# погана шумоізоляція чути            0.352442
# чутно відбувається коридорі         0.348246
# погана звукоізоляція чутно          0.347303
# чути відбувається коридорі          0.347241
# слабкий wi fi                       0.345493
# перебої гарячою водою               0.345493
# слабкий напір води                  0.344755
# тонкі стіни чути                    0.344273
# погана шумоізоляція чутно           0.342060
# неприємний запах номері             0.341447
# маленька ванна кімната              0.340704
# відсутність холодильника номері     0.340543
# відсутність гарячої води            0.340276
# москітну сіток вікнах               0.339668
# відбувається сусідньому номері      0.339668
# тонкі стіни чутно                   0.332847
# розеток біля ліжка                  0.332239
# неприємний запах каналізації        0.331920
# відбувається сусідніх номерах       0.331508
# залишає бажати кращого              0.330559
# 39 яко кажучи                       0.330166
# важко знайти готель                 0.330166
# проблеми гарячою водою              0.327038
# розетки біля ліжка                  0.308976
# номер двоспальне ліжком             0.307364
# ...                                      ...
# привітний персонал чисто           -1.706995
# перевершив всі очікування          -1.715744
# сніданки привітний персонал        -1.723105
# чистий номер привітний             -1.737463
# привітний персонал чистота         -1.739225
# чисто персонал привітний           -1.751362
# привітний персонал смачні          -1.758148
# смачний ситний сніданок            -1.761501
# розташування привітний персонал    -1.766153
# персонал смачні сніданки           -1.773039
# місце розташування привітний       -1.773039
# персонал хороший сніданок          -1.774663
# 39 язково зупинимося               -1.777892
# привітний ввічливий персонал       -1.790573
# розташування самий центр           -1.793686
# номер смачний сніданок             -1.793686
# чисті затишні номери               -1.799846
# просторий чистий номер             -1.799846
# смачний різноманітний сніданок     -1.805920
# вище всяких похвал                 -1.811911
# персонал місце розташування        -1.820744
# відмінне місце розташування        -1.824701
# чистота привітний персонал         -1.840682
# місце розташування чисто           -1.843457
# персонал номері чисто              -1.867666
# номери привітний персонал          -1.883086
# привітний персонал смачний         -1.895531
# розташування приємний персонал     -1.902830
# чисто привітний персонал           -1.982012
# персонал смачний сніданок          -2.181584
#
# [500 rows x 1 columns]

# %%
df['pos_text'][137]
# Out:
# 'Всі фотографії відповідають реальності. Шторка, робоча розетка, лампа. Зручне ліжко, новий посуд і чисті ванні кімнати.Ремонт новий. Адміністратори дуже приємні і виконують свою роботу швидко та якісно. Враження най-найкращі.'

# %% [markdown]
# ## Save pmi results to file

# %%
pmiPos_bigram.index.name = 'ngram'
pmiPos_bigram = pmiPos_bigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_bigram.to_csv('./data/bigram-pmi-positive-scores.csv')

# %%
pmiPos_unigram.index.name = 'ngram'
pmiPos_unigram = pmiPos_unigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_unigram.to_csv('./data/unigram-pmi-positive-scores.csv')

# %%
pmiNeg_unigram.index.name = 'ngram'
pmiNeg_unigram = pmiNeg_unigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_unigram.to_csv('./data/unigram-pmi-negative-scores.csv')

# %%
pmiNeg_bigram.index.name = 'ngram'
pmiNeg_bigram = pmiNeg_bigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_bigram.to_csv('./data/bigram-pmi-negative-scores.csv')

# %%
pmiPos_trigram.index.name = 'ngram'
pmiPos_trigram = pmiPos_trigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_trigram.to_csv('./data/trigram-pmi-positive-scores.csv')

# %%
pmiNeg_trigram.index.name = 'ngram'
pmiNeg_trigram = pmiNeg_trigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_trigram.to_csv('./data/trigram-pmi-negative-scores.csv')

# %%
pmiNeg_trigram
# Out:
#                                     score
# ngram
# відсутність питної води          0.352442
# запах ванній кімнаті             0.352442
# звукоізоляція залишає бажати     0.352442
# порожній міні бар                0.352442
# слабкий сигнал wi                0.352442
# погана звукоізоляція номерів     0.352442
# чути відбувається сусідніх       0.352442
# відсутність одноразових капців   0.352442
# відсутність міні бару            0.352442
# звукоізоляція чутно сусідів      0.352442
# чистота залишає бажати           0.352442
# холодно ванній кімнаті           0.352442
# номері міні бару                 0.352442
# погана шумоізоляція номері       0.352442
# номері чутно відбувається        0.352442
# номері холодно кондиціонер       0.352442
# звукоізоляція чути відбувається  0.352442
# погана шумоізоляція чути         0.352442
# номер одним великим              0.352442
# готель потребує ремонту          0.352442
# погана звукоізоляція чути        0.352442
# відбувається коридорі сусідніх   0.352442
# відсутність wi fi                0.352442
# стіну сусіднього будинку         0.352442
# вхідні двері номер               0.352442
# погана звукоізоляція номері      0.352442
# погана звукоізоляція номерах     0.352442
# запах каналізації ванній         0.352442
# запах каналізації номері         0.352442
# запах сигаретного диму           0.352442
# ...                                   ...
# привітний персонал чисто        -1.706995
# перевершив всі очікування       -1.715744
# сніданки привітний персонал     -1.723105
# чистий номер привітний          -1.737463
# привітний персонал чистота      -1.739225
# чисто персонал привітний        -1.751362
# привітний персонал смачні       -1.758148
# смачний ситний сніданок         -1.761501
# розташування привітний персонал -1.766153
# персонал смачні сніданки        -1.773039
# місце розташування привітний    -1.773039
# персонал хороший сніданок       -1.774663
# 39 язково зупинимося            -1.777892
# привітний ввічливий персонал    -1.790573
# номер смачний сніданок          -1.793686
# розташування самий центр        -1.793686
# просторий чистий номер          -1.799846
# чисті затишні номери            -1.799846
# смачний різноманітний сніданок  -1.805920
# вище всяких похвал              -1.811911
# персонал місце розташування     -1.820744
# відмінне місце розташування     -1.824701
# чистота привітний персонал      -1.840682
# місце розташування чисто        -1.843457
# персонал номері чисто           -1.867666
# номери привітний персонал       -1.883086
# привітний персонал смачний      -1.895531
# розташування приємний персонал  -1.902830
# чисто привітний персонал        -1.982012
# персонал смачний сніданок       -2.181584
#
# [2000 rows x 1 columns]

# %%
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
display(pmiPos_unigram.head(5))
display(pmiPos_bigram.head(5))
display(pmiPos_trigram.head(5))
# Out:
#              score
# ngram
# торговий  0.251974
# стильний  0.251648
# просторо  0.250339
# шикарне   0.249222
# відмінне  0.249179
#                            score
# ngram
# місцезнаходження супер  0.255065
# привітна господиня      0.255065
# чудове співвідношення   0.255065
# просторі кімнати        0.255065
# хороші номери           0.255065
#                                score
# ngram
# персонал ввічливий готовий  0.255065
# приємний персонал смачні    0.255065
# приємний персонал хороший   0.255065
# приємний персонал чистий    0.255065
# персонал смачні ситні       0.255065

# %%
pmiPos_bigram = pmiPos_bigram.drop(pmiPos_bigram.index[2])

# %%
pmiPos_unigram.columns
# Out:
# Index(['score'], dtype='object')

# %%
pmiPos_unigram.rename(columns={'ngram': 'unigram'})
# Out:
#                   score
# ngram
# торговий       0.251974
# стильний       0.251648
# просторо       0.250339
# шикарне        0.249222
# відмінне       0.249179
# похвал         0.248875
# необхідним     0.247499
# чудове         0.247456
# просторий      0.246833
# швидке         0.246613
# гарне          0.246317
# турботливий    0.246291
# ввічливий      0.246267
# милий          0.246224
# подяка         0.246201
# доброзичливий  0.246008
# необхідне      0.245939
# затишна        0.245769
# перевершив     0.245360
# послужливо     0.245349
# прекрасне      0.245161
# стильно        0.245138
# чуйні          0.244935
# білосніжна     0.244742
# визначні       0.244724
# ідеальне       0.244576
# затишні        0.244078
# тихе           0.243964
# чуйний         0.243760
# крокової       0.243554
# ...                 ...
# цвіль         -1.148368
# унітазу       -1.193384
# брудно        -1.207698
# каналізацією  -1.212297
# жахливі       -1.224680
# брудні        -1.234216
# брудна        -1.240698
# плямах        -1.252020
# розмови       -1.257872
# неприємний    -1.268861
# каналізації   -1.273362
# відсутня      -1.273601
# зламана       -1.280229
# злив          -1.293632
# незручна      -1.302743
# умивальнику   -1.307228
# грибок        -1.315478
# слабкий       -1.324117
# неприємно     -1.328983
# пружини       -1.374345
# жахлива       -1.391665
# погана        -1.394871
# шторка        -1.404534
# незручні      -1.442818
# раковині      -1.450371
# павутина      -1.479335
# дверцята      -1.487267
# слабка        -1.652346
# плямами       -1.655204
# зламаний      -1.677409
#
# [2000 rows x 1 columns]
