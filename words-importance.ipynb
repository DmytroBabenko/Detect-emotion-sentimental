# %%
import math
import numpy as np
import pandas as pd
from sklearn.metrics import mutual_info_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS

# %%
def read_stop_words(file):
    with open(file) as f:
        stop_words = f.read().split('\n')

    return stop_words

# %%
df = pd.read_csv("./data/reviews.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                      Ідеально для ділової поїздки!
# 1           1        Затишний, чистий номер з усіма зручностями.
# 2           2                        Все сподобалося. Рекомендую
# 3           3  Зручне розташування,чудовий вигляд з вікна,в н...
# 4           4                             Все чудово: 9,9 балів!
#
#                                             pos_text  \
# 0  Ідеально для ділової поїздки! Господар зустрів...
# 1  Затишний, чистий номер з усіма зручностями. Чу...
# 2  Чисто, тихо, комфортно. Зустрів і провів приєм...
# 3  Зручне розташування,чудовий вигляд з вікна,в н...
# 4  Нові апартаменти на останньому поверсі ЖК, біл...
#
#                                             neg_text  ratingValue  bestRating
# 0                                                NaN         10.0        10.0
# 1  При бронюванні вказала час прибуття о 7 ранку,...          9.2        10.0
# 2  На барі кава тільки 3 в 1. Хотілося звичайної ...          9.6        10.0
# 3                                                NaN         10.0        10.0
# 4  Немає терміналу для оплати кредиткою, тільки г...         10.0        10.0

# %%
df['pos_text'][1]
# Out:
# 'Затишний, чистий номер з усіма зручностями. Чудовий краєвид з вікна. Є можливість підігріти їжу та зробити чай/каву.'

# %%
uk_stop_words = read_stop_words('./data/ukrainian-stopwords.txt')

# %%
uk_stop_words
# Out:
# ['a',
#  'б',
#  'в',
#  'г',
#  'е',
#  'ж',
#  'з',
#  'м',
#  'т',
#  'у',
#  'я',
#  'є',
#  'і',
#  'аж',
#  'ви',
#  'де',
#  'до',
#  'за',
#  'зі',
#  'ми',
#  'на',
#  'не',
#  'ну',
#  'нх',
#  'ні',
#  'по',
#  'та',
#  'ти',
#  'то',
#  'ту',
#  'ті',
#  'це',
#  'цю',
#  'ця',
#  'ці',
#  'чи',
#  'ще',
#  'що',
#  'як',
#  'їй',
#  'їм',
#  'їх',
#  'її',
#  'або',
#  'але',
#  'ало',
#  'без',
#  'був',
#  'вам',
#  'вас',
#  'ваш',
#  'вже',
#  'все',
#  'всю',
#  'вся',
#  'від',
#  'він',
#  'два',
#  'дві',
#  'для',
#  'ким',
#  'мож',
#  'моя',
#  'моє',
#  'мої',
#  'міг',
#  'між',
#  'мій',
#  'над',
#  'нам',
#  'нас',
#  'наш',
#  'нею',
#  'неї',
#  'них',
#  'ніж',
#  'ній',
#  'ось',
#  'при',
#  'про',
#  'під',
#  'пір',
#  'раз',
#  'рік',
#  'сам',
#  'сих',
#  'сім',
#  'так',
#  'там',
#  'теж',
#  'тим',
#  'тих',
#  'той',
#  'тою',
#  'три',
#  'тут',
#  'хоч',
#  'хто',
#  'цей',
#  'цим',
#  'цих',
#  'час',
#  'щоб',
#  'яка',
#  'які',
#  'адже',
#  'буде',
#  'буду',
#  'будь',
#  'була',
#  'були',
#  'було',
#  'бути',
#  'вами',
#  'ваша',
#  'ваше',
#  'ваші',
#  'весь',
#  'вниз',
#  'вона',
#  'вони',
#  'воно',
#  'всею',
#  'всім',
#  'всіх',
#  'втім',
#  'геть',
#  'далі',
#  'двох',
#  'день',
#  'дуже',
#  'зате',
#  'його',
#  'йому',
#  'каже',
#  'кого',
#  'коли',
#  'кому',
#  'крім',
#  'куди',
#  'лише',
#  'люди',
#  'мало',
#  'мати',
#  'мене',
#  'мені',
#  'миру',
#  'мною',
#  'може',
#  'нами',
#  'наша',
#  'наше',
#  'наші',
#  'ними',
#  'ніби',
#  'один',
#  'поки',
#  'пора',
#  'рано',
#  'року',
#  'році',
#  'сама',
#  'саме',
#  'саму',
#  'самі',
#  'свою',
#  'своє',
#  'свої',
#  'себе',
#  'собі',
#  'став',
#  'суть',
#  'така',
#  'таке',
#  'такі',
#  'твоя',
#  'твоє',
#  'твій',
#  'тебе',
#  'тими',
#  'тобі',
#  'того',
#  'тоді',
#  'тому',
#  'туди',
#  'хоча',
#  'хіба',
#  'цими',
#  'цієї',
#  'часу',
#  'чого',
#  'чому',
#  'який',
#  'яких',
#  'якої',
#  'якщо',
#  "ім'я",
#  'інша',
#  'інше',
#  'інші',
#  'буває',
#  'будеш',
#  'більш',
#  'вгору',
#  'вміти',
#  'внизу',
#  'вісім',
#  'давно',
#  'даром',
#  'добре',
#  'довго',
#  'друго',
#  'дякую',
#  'життя',
#  'зараз',
#  'знову',
#  'какая',
#  'кожен',
#  'кожна',
#  'кожне',
#  'кожні',
#  'краще',
#  'ледве',
#  'майже',
#  'менше',
#  'могти',
#  'можна',
#  'назад',
#  'немає',
#  'нижче',
#  'нього',
#  'однак',
#  "п'ять",
#  'перед',
#  'поруч',
#  'потім',
#  'проти',
#  'після',
#  'років',
#  'самим',
#  'самих',
#  'самій',
#  'свого',
#  'своєї',
#  'своїх',
#  'собою',
#  'справ',
#  'такий',
#  'також',
#  'тепер',
#  'тисяч',
#  'тобою',
#  'треба',
#  'трохи',
#  'усюди',
#  'усіма',
#  'хочеш',
#  'цього',
#  'цьому',
#  'часто',
#  'через',
#  'шість',
#  'якого',
#  'іноді',
#  'інший',
#  'інших',
#  'багато',
#  'будемо',
#  'будете',
#  'будуть',
#  'більше',
#  'всього',
#  'всьому',
#  'далеко',
#  'десять',
#  'досить',
#  'другий',
#  'дійсно',
#  'завжди',
#  'звідси',
#  'зовсім',
#  'кругом',
#  'кілька',
#  'людина',
#  'можуть',
#  'навіть',
#  'навіщо',
#  'нагорі',
#  'небудь',
#  'низько',
#  'ніколи',
#  'нікуди',
#  'нічого',
#  'обидва',
#  'одного',
#  'однієї',
#  "п'ятий",
#  'перший',
#  'просто',
#  'раніше',
#  'раптом',
#  'самими',
#  'самого',
#  'самому',
#  'сказав',
#  'скрізь',
#  'сьомий',
#  'третій',
#  'тільки',
#  'хотіти',
#  'чотири',
#  'чудово',
#  'шостий',
#  'близько',
#  'важлива',
#  'важливе',
#  'важливі',
#  'вдалині',
#  'восьмий',
#  'говорив',
#  "дев'ять",
#  'десятий',
#  'зайнята',
#  'зайнято',
#  'зайняті',
#  'занадто',
#  'значить',
#  'навколо',
#  'нарешті',
#  'нерідко',
#  'повинно',
#  'посеред',
#  'початку',
#  'пізніше',
#  'сказала',
#  'сказати',
#  'скільки',
#  'спасибі',
#  'частіше',
#  'важливий',
#  'двадцять',
#  "дев'ятий",
#  'зазвичай',
#  'зайнятий',
#  'звичайно',
#  'здається',
#  'найбільш',
#  'не можна',
#  'недалеко',
#  'особливо',
#  'потрібно',
#  'спочатку',
#  'сьогодні',
#  'численна',
#  'численне',
#  'численні',
#  'відсотків',
#  'двадцятий',
#  'звідусіль',
#  'мільйонів',
#  'нещодавно',
#  'прекрасно',
#  'четвертий',
#  'численний',
#  'будь ласка',
#  'дванадцять',
#  'одинадцять',
#  'сімнадцять',
#  'тринадцять',
#  'безперервно',
#  'дванадцятий',
#  'одинадцятий',
#  'одного разу',
#  "п'ятнадцять",
#  'сімнадцятий',
#  'тринадцятий',
#  'шістнадцять',
#  'вісімнадцять',
#  "п'ятнадцятий",
#  'чотирнадцять',
#  'шістнадцятий',
#  'вісімнадцятий',
#  "дев'ятнадцять",
#  'чотирнадцятий',
#  "дев'ятнадцятий"]

# %%
'над' in uk_stop_words
# Out:
# True

# %% [markdown]
# ### 2. Mutual information

# %% [markdown]
# **Mutual information tells you how much you learn about X from knowing the value of Y (on average over the choice of Y).**
#
#
# Since we found the word frequency is not a good indicator for the sentiment analysis, we will examine *mutual information*  for an alternative metric.
#
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mutual_info_score.html

# %%
math.isnan(df['neg_text'].values[0])
# Out:
# True

# %%
def is_review_valid(review):
    try:
        if len(review) == 0:
            return False
        return True
    except:
        return False

# %%
def get_pos_neg_review(df):
    gt_score, reviews = [], []
    for i in range(0, len(df)):
        if is_review_valid(df['pos_text'][i]):
            reviews.append(df['pos_text'][i])
            gt_score.append(1)
            
        if is_review_valid(df['neg_text'][i]):
            reviews.append(df['neg_text'][i])
            gt_score.append(0)
            
    return reviews, gt_score

# %%
reviews, gt_score = get_pos_neg_review(df)

# %%
# let's calculate Mutual Information for unigrams and bigrams
vectorizer = CountVectorizer(ngram_range=(1,1), stop_words=uk_stop_words, max_features=500)
countvector = vectorizer.fit_transform(reviews)
densevector = np.array(countvector.todense())
    
# miScore_unigram = pd.DataFrame(data = {'word': vectorizer.get_feature_names(),
#              'MI Score': [mutual_info_score(gtScore, densevector[:,i].squeeze()) for i in range(500)]})

miScore_unigram = pd.DataFrame(data =
                               {'MI Score': [mutual_info_score(gt_score, densevector[:,i].squeeze()) for i in range(500)]}
                              , index = vectorizer.get_feature_names())

# Bigram version
vectorizer = CountVectorizer(ngram_range=(2,2), stop_words=uk_stop_words, max_features=500)
countvector = vectorizer.fit_transform(reviews)
densevector = np.array(countvector.todense())
miScore_bigram = pd.DataFrame(data =
                    {'MI Score': [mutual_info_score(gt_score, densevector[:,i].squeeze()) for i in range(500)]},
                    index = vectorizer.get_feature_names())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
miScore_unigram.sort_values('MI Score', inplace=True, ascending=False)
print('Mutual Information - Unigram')
miScore_unigram.head(10)
# Out:
# Mutual Information - Unigram
#               MI Score
# персонал      0.077176
# розташування  0.076582
# привітний     0.046049
# чисто         0.042327
# зручне        0.030128
# відсутність   0.016802
# чудове        0.014197
# центрі        0.013936
# гарний        0.013700
# погана        0.013699

# %%
miScore_bigram.sort_values('MI Score', inplace=True, ascending=False)
print('Mutual Information - Bigram')
miScore_bigram.head(10)
# Out:
# Mutual Information - Bigram
#                       MI Score
# привітний персонал    0.033663
# зручне розташування   0.017697
# місце розташування    0.009666
# приємний персонал     0.009136
# погана звукоізоляція  0.007070
# чудове розташування   0.006828
# інтер єр              0.006487
# центрі міста          0.006430
# персонал привітний    0.006034
# ванній кімнаті        0.005576

# %% [markdown]
# ###  3. Pointwise Mutual Information

# %%
def getPMI_ngram(reviews, gt_score, gt, ngram_range=(1,1), max_features=500):
    vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words=uk_stop_words, max_features=max_features)
    countvector = vectorizer.fit_transform(reviews)
    densevector = np.array(countvector.todense())
    
    px = sum(gt_score == gt) / len(reviews)
    pmis = []
    
    for i in range(max_features):
        py = sum(densevector[:,i] == 1) / len(reviews)
        pxy = sum((gt_score== gt) & (densevector[:,i] == 1)) / len(reviews)
        
        if pxy == 0:
            pmi = math.log10((pxy + 0.0001) / (px * py))
        else:
            pmi = math.log10(pxy / (px * py))
            
        pmis.append(pmi)
        
    gt_name = 'positive' if gt == 1 else 'negative'
    pmis = pd.DataFrame(data = {'pmi' + gt_name: pmis}, index = vectorizer.get_feature_names())
    return pmis.sort_values('pmi' + gt_name, ascending=False)

# %%
gt_score = np.array(gt_score)

# %%
pmiPos_unigram = getPMI_ngram(reviews, gt_score,  1)
pmiNeg_unigram = getPMI_ngram(reviews, gt_score,  0)
pmiPos_bigram = getPMI_ngram(reviews, gt_score,  1, ngram_range=(2,2))
pmiNeg_bigram = getPMI_ngram(reviews, gt_score,  0, ngram_range=(2,2))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# ### Let's see what PMI values tell us about the reviews

# %%
print('PMI for positive reviews - Unigram')
pmiPos_unigram.head(10)
# Out:
# PMI for positive reviews - Unigram
#                pmipositive
# класний           0.241606
# відмінне          0.241606
# прекрасне         0.241606
# простора          0.238721
# доброзичливий     0.238471
# просторий         0.237894
# чудове            0.237260
# вічливий          0.237241
# уважний           0.236556
# затишна           0.236074

# %%
print('PMI for positive reviews - Bigram')
pmiPos_bigram.head(10)
# Out:
# PMI for positive reviews - Bigram
#                    pmipositive
# великий вибір         0.241606
# чистота привітний     0.241606
# простора кімната      0.241606
# чистота комфорт       0.241606
# чисто приємний        0.241606
# зручний номер         0.241606
# номер зручне          0.241606
# зручна кухня          0.241606
# гарний чистий         0.241606
# персонал уважний      0.241606

# %%
print('PMI for negative reviews - Unigram')
pmiNeg_unigram.head(10)
# Out:
# PMI for negative reviews - Unigram
#                pminegative
# неприємний        0.366348
# погана            0.363971
# брудна            0.361851
# звукоізоляції     0.361119
# відсутня          0.358464
# відсутній         0.357119
# неможливо         0.355653
# брудно            0.355335
# погано            0.354805
# незручно          0.354099

# %%
print('PMI for negative reviews - Bigram')
pmiNeg_bigram.head(20)
# Out:
# PMI for negative reviews - Bigram
#                           pminegative
# відбувається коридорі        0.369893
# відсутність парковки         0.369893
# звукоізоляція чути           0.369893
# погана шумоізоляція          0.369893
# відсутність кондиціонера     0.369893
# чути сусідів                 0.369893
# відсутність ліфта            0.369893
# погана звукоізоляція         0.366016
# неприємний запах             0.365697
# запах каналізації            0.362469
# стіни чути                   0.360348
# чути відбувається            0.360133
# сусідніх номерах             0.359428
# тонкі стіни                  0.358804
# потребує ремонту             0.357994
# спати неможливо              0.356928
# чутно відбувається           0.356105
# звукоізоляція відсутня       0.354653
# сусідньому номері            0.353188
# номері чути                  0.352860

# %%
pmiNeg_bigram.tail(10)
# Out:
#                         pminegative
# просторий номер           -1.607830
# чисто затишно             -1.620010
# персонал зручне           -1.634428
# хороше розташування       -1.663531
# приємний персонал         -1.684145
# чиста постіль             -1.709288
# зручне розташування       -1.721522
# розташування привітний    -1.811950
# чистий номер              -1.950253
# чудове розташування       -2.139309

# %%
pmiPos_bigram.tail(10)
# Out:
#                       pmipositive
# спати неможливо         -1.289873
# потребує ремонту        -1.326595
# тонкі стіни             -1.356819
# сусідніх номерах        -1.381643
# чути відбувається       -1.411606
# стіни чути              -1.421152
# погана шумоізоляція     -1.454161
# запах каналізації       -1.529246
# неприємний запах        -1.775427
# погана звукоізоляція    -1.809546

# %%
df['pos_text'][137]
# Out:
# 'Всі фотографії відповідають реальності. Шторка, робоча розетка, лампа. Зручне ліжко, новий посуд і чисті ванні кімнати.Ремонт новий. Адміністратори дуже приємні і виконують свою роботу швидко та якісно. Враження най-найкращі.'

# %% [markdown]
# ## Save pmi results to file

# %%
pmiPos_bigram.index.name = 'ngram'
pmiPos_bigram = pmiPos_bigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_bigram.to_csv('./data/bigram-pmi-positive-scores.csv')

# %%
pmiPos_unigram.index.name = 'ngram'
pmiPos_unigram = pmiPos_unigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_unigram.to_csv('./data/unigram-pmi-positive-scores.csv')

# %%
pmiNeg_unigram.index.name = 'ngram'
pmiNeg_unigram = pmiNeg_unigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_unigram.to_csv('./data/unigram-pmi-negative-scores.csv')

# %%
pmiNeg_bigram.index.name = 'ngram'
pmiNeg_bigram = pmiNeg_bigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_bigram.to_csv('./data/bigram-pmi-negative-scores.csv')

# %%
pmiPos_trigram = getPMI_ngram(reviews, gt_score, 1, ngram_range=(3,3))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
pmiPos_trigram.index.name = 'ngram'
pmiPos_trigram = pmiPos_trigram.rename(columns={"pmipositive" : "score"})

# %%
pmiPos_trigram
# Out:
#                                      score
# ngram
# історичного центру міста          0.241606
# привітний персонал смачний        0.241606
# наступного разу обов              0.241606
# привітний персонал хороший        0.241606
# привітний персонал хороше         0.241606
# привітний персонал сподобалось    0.241606
# чисто ввічливий персонал          0.241606
# надзвичайно зручне розташування   0.241606
# зручне ліжко чисто                0.241606
# привітний персонал чисті          0.241606
# привітний персонал смачна         0.241606
# персонал чисті номери             0.241606
# зручне розташування біля          0.241606
# привітний персонал рецепції       0.241606
# тепло привітний персонал          0.241606
# зручне розташування наявність     0.241606
# персонал чисто охайно             0.241606
# персонал чисто комфортно          0.241606
# привітний персонал парковка       0.241606
# приємний персонал зручне          0.241606
# приємний інтер єр                 0.241606
# приємний персонал чистота         0.241606
# приємний персонал чисто           0.241606
# дозволили залишити речі           0.241606
# приємний персонал смачний         0.241606
# необхідне приготування їжі        0.241606
# необхідне комфортного проживання  0.241606
# привітний турботливий персонал    0.241606
# чисто зручні ліжка                0.241606
# приємна дівчина рецепції          0.241606
# ...                                    ...
# шумоізоляція чутно відбувається  -0.253447
# чутно відбувається сусідніх      -0.253447
# запах каналізації ванній         -0.253447
# брудно ванній кімнаті            -0.253447
# відсутність вікна номері         -0.253447
# вікна номеру виходили            -0.302462
# працює wi fi                     -0.302462
# погана звукоізоляція номері      -0.304600
# звукоізоляція могла кращою       -0.304600
# тонкі стіни чутно                -0.350357
# погана шумоізоляція чути         -0.350357
# заселення 14 00                  -0.360454
# номер двоспальним ліжком         -0.360454
# проблеми гарячою водою           -0.391750
# погана шумоізоляція чутно        -0.391750
# запах ванній кімнаті             -0.391750
# сніданок включений вартість      -0.411606
# двері ванну кімнату              -0.411606
# сигнал wi fi                     -0.427401
# відбувається сусідніх номерах    -0.429539
# відсутність гарячої води         -0.526449
# чути відбувається коридорі       -0.554477
# погана звукоізоляція чутно       -0.605630
# погана звукоізоляція чути        -0.605630
# залишає бажати кращого           -0.692780
# розеток біля ліжка               -0.712636
# шампуню гелю душу                -0.758394
# важко знайти готель              -0.799786
# потребує косметичного ремонту    -1.013666
# тонкі стіни чути                 -1.349458
#
# [500 rows x 1 columns]

# %%
pmiPos_trigram.to_csv('./data/trigram-pmi-positive-scores.csv')

# %%
pmiNeg_trigram = getPMI_ngram(reviews, gt_score, 0, ngram_range=(3,3))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
pmiNeg_trigram.index.name = 'ngram'
pmiNeg_trigram = pmiNeg_trigram.rename(columns={"pminegative" : "score"})

# %%
pmiNeg_trigram.to_csv('./data/trigram-pmi-negative-scores.csv')

# %%
pmiNeg_trigram
# Out:
#                                     score
# ngram
# погана звукоізоляція номері      0.369893
# брудно ванній кімнаті            0.369893
# залишає бажати кращого           0.369893
# звукоізоляція могла кращою       0.369893
# каналізації ванній кімнаті       0.369893
# погана звукоізоляція чути        0.369893
# погана звукоізоляція чутно       0.369893
# погана шумоізоляція чути         0.369893
# погана шумоізоляція чутно        0.369893
# відсутність вікна номері         0.369893
# запах ванній кімнаті             0.369893
# відбувається сусідніх номерах    0.369893
# відбувається сусідньому номері   0.369893
# проблеми гарячою водою           0.369893
# тонкі стіни чутно                0.369893
# відсутня гаряча вода             0.369893
# запах каналізації ванній         0.369893
# хостел знаходиться поверсі       0.369893
# чути відбувається коридорі       0.369893
# шумоізоляція чутно відбувається  0.369893
# чутно відбувається сусідніх      0.369893
# чутно відбувається коридорі      0.369893
# відсутність гарячої води         0.369893
# тонкі стіни чути                 0.358612
# потребує косметичного ремонту    0.345070
# важко знайти готель              0.328501
# шампуню гелю душу                0.324136
# розеток біля ліжка               0.318741
# сигнал wi fi                     0.265158
# двері ванну кімнату              0.260749
# ...                                   ...
# біля кожного ліжка              -0.908860
# велике зручне ліжко             -0.908860
# сніданок привітний персонал     -0.908860
# розташування центрі львова      -0.931137
# речі камері схову               -0.931137
# привітний персонал чудове       -0.931137
# готель розташований центрі      -0.931137
# транспортна розв язка           -0.952326
# чудовий інтер єр                -0.952326
# гарний інтер єр                 -0.970258
# місце розташування готелю       -0.972529
# розташування центру міста       -0.972529
# залишити речі виселення         -0.991835
# чисто персонал привітний        -0.991835
# 10 хв пішки                     -0.991835
# зручне розташування привітний   -0.992922
# привітний персонал зручне       -1.021411
# номери привітний персонал       -1.028047
# готель привітний персонал       -1.077265
# привітний персонал чисто        -1.135257
# співвідношення ціни якості      -1.155152
# гарне місце розташування        -1.263575
# розташування привітний персонал -1.352404
# привітний персонал чистота      -1.370469
# зручне місце розташування       -1.374400
# зручне розташування центрі      -1.378295
# чудове місце розташування       -1.436287
# персонал зручне розташування    -1.443020
# чисто привітний персонал        -1.510920
# розташування центрі міста       -1.730477
#
# [500 rows x 1 columns]
