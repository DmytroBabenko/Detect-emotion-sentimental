# %%
import torch
import pandas as pd
from ngram_manager import NgramManager
from gensim.models import KeyedVectors
import numpy as np
from nltk.cluster import KMeansClusterer
import nltk
from sklearn.feature_extraction.text import CountVectorizer

# %%
class SentenceClassification:
    # 0 - negative
    # 1 - neutral
    # 2 - positive
    def __init__(model):
        self.model = model
        
    
    
    def classify(sentece):
        #TODO:
        return 1

# %%
class ClusterNgram:
    def __init__(self, word2vec):
        self.word2vec = word2vec
        
        
    
    def cluster_n_grams(self, ngrams, num_cluster):
        X = self.__convert_ngrams_to_vectors(ngrams)
        kclusterer = KMeansClusterer(num_cluster, 
                                     distance=nltk.cluster.util.cosine_distance, 
                                     repeats=100,
                                     avoid_empty_clusters=True)
        y = kclusterer.cluster(X, assign_clusters=True)
        
        top_indices = self.__find_top_n_gram_indices(X, y, kclusterer.means())
        
        return np.array(ngrams)[top_indices]
        
        
    
    def __find_top_n_gram_indices(self, X, y, centroids):
        min_dis = len(centroids)*[100]
        top_indices = len(centroids)*[-1]
        for i in range(0, len(centroids)):
            for j in range(0, len(X)):
                if y[j] != i:
                    continue
                
                dis = nltk.cluster.util.cosine_distance(X[j], centroids[i])
                if min_dis[i] > dis:
                    min_dis[i] = dis
                    top_indices[i] = j
        
        return top_indices
                    
    
    def __convert_ngrams_to_vectors(self, ngrams):
        X = []
        for ngram in ngrams:
            try:
                words = tokenize_uk.tokenize_words(ngram)
                x = word2vec[words[0]]
                for i in range(1, len(words)):
                    x = x + word2vec[words[i]]
                X.append(x)
            except:
                X.append(np.zeros(300))
        return X

# %%
def read_stop_words(file):
    with open(file) as f:
        stop_words = f.read().split('\n')

    return stop_words

# %%
embeddings_file = "./embeddings/ubercorpus.cased.tokenized.word2vec.300d"

# %%
word2vec = KeyedVectors.load_word2vec_format(embeddings_file)

# %%
cluster_ngram = ClusterNgram(word2vec)

# %%
pos_unigram_scores = pd.read_csv('./data/unigram-pmi-positive-scores.csv')
pos_bigram_scores = pd.read_csv('./data/bigram-pmi-positive-scores.csv')
pos_trigram_scores = pd.read_csv('./data/trigram-pmi-positive-scores.csv')

# %%
neg_unigram_scores = pd.read_csv('./data/unigram-pmi-negative-scores.csv')
neg_bigram_scores = pd.read_csv('./data/bigram-pmi-negative-scores.csv')
neg_trigram_scores = pd.read_csv('./data/trigram-pmi-negative-scores.csv')

# %%
uk_stop_words = read_stop_words('./data/ukrainian-stopwords.txt')

# %%
pos_ngram_mng = NgramManager(unigram_scores=pos_unigram_scores, 
                             bigram_scores=pos_bigram_scores, 
                             trigram_scores=pos_trigram_scores,
                            stop_words=uk_stop_words,
                            threshold=0.1)

# %%
neg_ngram_mng = NgramManager(unigram_scores=neg_unigram_scores, 
                             bigram_scores=neg_bigram_scores, 
                             trigram_scores=neg_trigram_scores,
                            stop_words=uk_stop_words, 
                            threshold=0.1)

# %%
sentence1 = "Гарний стильний готель, свіжий ремонт, нові меблі (були в номері на 1 поверсі), всього достатньо."

# %%
sentecne2 = "Сніданки дійсно смачні."

# %%
sentecne3 = "Є бажання повернутися в готель, якщо будемо в Львові"

# %%
text = sentence1 + sentecne2 + sentecne3

# %%
get_all_ngrams_for_text(text, (2, 2), uk_stop_words)
# Out:
# ['бажання повернутися',
#  'гарний стильний',
#  'готель львові',
#  'готель свіжий',
#  'достатньо сніданки',
#  'меблі номері',
#  'нові меблі',
#  'номері поверсі',
#  'повернутися готель',
#  'поверсі достатньо',
#  'ремонт нові',
#  'свіжий ремонт',
#  'смачні бажання',
#  'сніданки смачні',
#  'стильний готель']

# %%
sen1 = "З мінусів: дуже тягло з каналізації неприємний запах."

# %%
get_all_ngrams_for_text(sen1, (2, 2), uk_stop_words)
# Out:
# ['каналізації неприємний',
#  'мінусів тягло',
#  'неприємний запах',
#  'тягло каналізації']

# %%
neg_ngram_mng.find_important_bigrams(sen1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# [('неприємний запах', 0.34)]

# %%
def get_all_ngrams_for_text(text: str, ngram_range, stop_words):
    try:
        vectorizer = CountVectorizer(ngram_range=ngram_range, stop_words=stop_words)
        countvector = vectorizer.fit_transform([text])
        ngrams = vectorizer.get_feature_names()
        return ngrams
    except Exception as e:
        print(e)
        return []

# %%
get_all_ngrams_for_text(sentence1, (2, 2), uk_stop_words)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# ['гарний стильний',
#  'готель свіжий',
#  'достатньо сніданки',
#  'меблі номері',
#  'нові меблі',
#  'номері поверсі',
#  'поверсі достатньо',
#  'ремонт нові',
#  'свіжий ремонт',
#  'сніданки смачні',
#  'стильний готель']

# %%
pos_ngram_mng.find_important_bigrams(sentence1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# [('нові меблі', 0.25), ('свіжий ремонт', 0.24), ('сніданки смачні', 0.22)]

# %%
import tokenize_uk

# %%
class ReviewAnalyzer:
    def __init__(self, sent_cclassifier, pos_ngram_mng, neg_ngram_mng):
        self.pos_ngram_mng = pos_ngram_mng
        self.neg_ngram_mng = neg_ngram_mng
        self.sent_classifier = sent_classifier
        
    
    def analyze_review(text: str):
        
        pos_unigrams, pos_bigrams, pos_trigrams = [], [], []
        neg_unigrams, neg_bigrams, neg_trigrams = [], [], []

        sentences = tokenize_uk.tokenize_sents(text)
        for sent in sentences:
            label = self.sent_classifier(sentences)
            if label == 2:#pos
                pos_unigrams += pos_ngram_mng.find_important_unigrams(sent)
                pos_bigrams += pos_ngram_mng.find_important_bigrams(sent)
                pos_trigrams += pos_ngram_mng.find_important_trigrams(sent)
            elif label == 0: #neg
                neg_unigrams += neg_ngram_mng.find_important_unigrams(sent)
                neg_bigrams += neg_ngram_mng.find_important_bigrams(sent)
                neg_trigrams += neg_ngram_mng.find_important_trigrams(sent)
                
        
        return {
            'pos_unigrams' : pos_unigrams,
            'pos_bigrams' : pos_bigrams,
            'pos_trigrams' : pos_trigrams,
            'neg_unigrams' : neg_unigrams,
            'neg_bigrams' : neg_bigrams,
            'neg_trigrams' : neg_trigrams,
        }

# %%
# !ls dataset/booking
# Out:
# analyze.ipynb
# booking-rating-for-one-hot-test.csv
# booking-rating-for-one-hot-train.csv
# booking-rating-for-one-hot-val.csv
# booking-rating-test.csv
# booking-rating-train.csv
# booking-rating-val.csv
# booking-sentences-test.csv
# booking-sentences-train.csv
# booking-sentences-val.csv
# booking-test.csv
# booking-train.csv
# booking-val.csv
# create-dataset-for-rating-classification.ipynb
# create-detect-ngram-dataset.ipynb
# create-sentence-classification-dataset.ipynb
# dnipro-reviews.csv
# ivano-frankivsk-reviews.csv
# kharkiv-reviews.csv
# kyiv-reviews.csv
# lviv-reviews.csv
# odesa-reviews.csv
# translated
# uzhgorod-reviews.csv

# %%
booking_df = pd.read_csv('dataset/booking/booking-test.csv')

# %%
blum_df = booking_df.loc[booking_df['hotel'] == 'blum.uk.html']

# %%
blum_df
# Out:
#                                                    title  \
# 12696                                       Розташування
# 12697    Персонал привітний, швидко вирішує усі питання.
# 12698  Розташування, співвідношення ціни та якості, с...
# 12699                              Все супер. Рекомендую
# 12700  Хороший готель, схований від шумного центру, т...
# 12701                           Сніданок неперевершений.
# 12702             Чудове місце для короткочасних поїздок
# 12703                    Затишний готель у серці Львова;
# 12704  наступної мандрівки до Львова оберемо цей готель.
# 12705                  Сніданок - великі порції, смачно!
# 12706  Все чудово! За нагоди, обов'язково знову завіт...
# 12707  Отель знаходиться у центрі міста, але при цьом...
# 12708  класне розташування, такий собі острівець тиші...
# 12709  Гарне місце для туристів або відрядження, але ...
# 12710  Дуже душно, номер з вікном на стелі, дотягнути...
# 12711  - Чудове розташування у тихій вуличці у самому...
# 12712  Зручне розташування, в номері чисто, є все нео...
# 12713  Дуже приємний персонал, тиша навкруги і дуже б...
# 12714                                    Дуже задоволена
# 12715  Рекомендую для зупинки по справам у Львові, ві...
# 12716  Співвідношення ціни, якості та розташування - ...
# 12717         Яскраво, витримано, чисто та доброзичливо)
# 12718                                       Розташування
# 12719     Місцезнаходження, дизайн, затишок, кава і чай.
# 12720                         Рекомендую для проживання!
# 12721  Чистенько, для дитини окреме ліжко, непогане р...
# 12722  Мені з чоловіком там дуже сподобалось, впевнен...
# 12723           Гарний, затишний готель в центрі Львова.
# 12724  Тільки позитивні враження: привабливий персона...
# 12725                                         Рекомендую
# ...                                                  ...
# 14784  Чистота, щоденне прибирання номера, привітний ...
# 14785                       У центрі Львова, є парковка.
# 14786                                         Все супер!
# 14787  Чистий Готель, відмінний матрац, приємний перс...
# 14788                   Гарна, затишний готель в центрі.
# 14789                  Дуже приємний і уважний персонал.
# 14790                                              Тиша.
# 14791                                Розташування готелю
# 14792                                 Приємний персонал!
# 14793                           Персонал, чистота, район
# 14794                     Був неприємний запах у ванній.
# 14795                                  Відмінний готель!
# 14796  Відмінне місце розташування, ввічливий і чуйни...
# 14797                                   Чуйний персонал.
# 14798           Чисто, ввічливий персонал, розташування.
# 14799  Все добре, розміщення відмінне, персонал уважний.
# 14800  В цілому приємний, чистий готель, вітальний пе...
# 14801  Готель новий і чистий, в номері не було «харак...
# 14802              Небезпечний для життя стелю в номері.
# 14803                                       Нові номери.
# 14804  У номері було сиро до такої міри, що навіть вз...
# 14805                             Розташування відмінне.
# 14806                                     Готель, новий.
# 14807                    Чисто, тихо і головне не дорого
# 14808                                прилетіли персонал.
# 14809  Будівля потребує просушування і було б непоган...
# 14810  Зручне розташування) круто коли заходиш і відч...
# 14811  Дуже доброзичливий і чуйний персонал - завжди ...
# 14812  Чистенько, затишно, ввічливий і добродушний пе...
# 14813                                      новий готель.
#
#                                                 pos_text  \
# 12696                                       Розташування
# 12697  Персонал привітний, швидко вирішує усі питання...
# 12698  Розташування, співвідношення ціни та якості, с...
# 12699  Знаходиться не далеко від центру, близько всі ...
# 12700  Хороший готель, схований від шумного центру, т...
# 12701  Сніданок неперевершений. Необмежена кількість ...
# 12702  Гарний дизайн готелю, чудове розташування, при...
# 12703  Затишний готель у серці Львова; привітний нена...
# 12704  Відмінне розташування готелю! Дуже близько до ...
# 12705  Сніданок - великі порції, смачно! 1 страва без...
# 12706  Дуже чудовий і затишний отель! Дуже зручне роз...
# 12707  Отель знаходиться у центрі міста, але при цьом...
# 12708  класне розташування, такий собі острівець тиші...
# 12709  Ідеальний номер, як для тризіркового готелю - ...
# 12710                                                Nan
# 12711  - Чудове розташування у тихій вуличці у самому...
# 12712  Зручне розташування, в номері чисто, є все нео...
# 12713  Дуже приємний персонал, тиша навкруги і дуже б...
# 12714  Все дуже чисто і гарно . За 3 ночі перебування...
# 12715  Відмінне розташування готелю... в самому центр...
# 12716  Хороше розташування, тихе місце. Коли сусіди п...
# 12717  Зручно, компактно . Простий дизайн, але ярка ч...
# 12718                                       Розташування
# 12719     Місцезнаходження, дизайн, затишок, кава і чай.
# 12720  Зручно, в центрі міста, нескладно було знайти ...
# 12721  Чистенько, для дитини окреме ліжко, непогане р...
# 12722  Розташування готелю дуже зручне, поруч є все н...
# 12723  Гарний, затишний готель в центрі Львова . Перс...
# 12724  Тільки позитивні враження: привабливий персона...
# 12725  Майже центр міста, тихі номери, чисто, свіжий ...
# ...                                                  ...
# 14784  Чистота, щоденне прибирання номера, привітний ...
# 14785  У центрі Львова, є парковка. У номері є все не...
# 14786                                       Все супер!!!
# 14787  Чистий Готель, відмінний матрац, приємний перс...
# 14788  Гарна, затишний готель в центрі. Чисто комфорт...
# 14789  Дуже приємний і уважний персонал. Відмінні чис...
# 14790                                     Тиша. Комфорт.
# 14791  Розташування готелю доброзичливий персонал Чис...
# 14792                                 Приємний персонал!
# 14793                           Персонал, чистота, район
# 14794                                                Nan
# 14795  Зручне місце розташування, чистий, симпатичний...
# 14796  Відмінне місце розташування, ввічливий і чуйни...
# 14797               Чуйний персонал. Зручне розташування
# 14798           Чисто, ввічливий персонал, розташування.
# 14799  Все добре, розміщення відмінне, персонал уважн...
# 14800                               Все було добре, крім
# 14801  Готель новий і чистий, в номері не було «харак...
# 14802                                                Nan
# 14803             Нові номери. Чисто, гарне розташування
# 14804                                                Nan
# 14805                             Розташування відмінне.
# 14806  Готель, новий . Приємний персонал . Чисто . Є ...
# 14807                    Чисто, тихо і головне не дорого
# 14808             прилетіли персонал . Чистота . комфорт
# 14809  Новий готель, сучасний дизайн, привітний персо...
# 14810  Зручне розташування) круто коли заходиш і відч...
# 14811  Дуже доброзичливий і чуйний персонал - завжди ...
# 14812  Чистенько, затишно, ввічливий і добродушний пе...
# 14813           новий готель. місце розташування - гарне
#
#                                                 neg_text  ratingValue  \
# 12696  Брудні і обшарпані стіни номеру Дуже жарко в н...          5.0
# 12697  Одну з ночей хтось постійно ходив по коридору ...          8.8
# 12698  Було б непогано мати чайник в номері, чай та к...         10.0
# 12699  Запах в номері, якійсь був солодкий, напевно в...          9.2
# 12700  шумоізоляція, та досить велика щілина внизу дв...          9.6
# 12701  звукоізоляція могла б бути і кращою . Не зайви...          9.2
# 12702  Сніданок в ціні номеру міг бути більшим, до ка...          8.3
# 12703  Сніданок: хотілося б шведський стіл, а не кіль...          8.8
# 12704  один маленький мінус, але нам це не завдало не...         10.0
# 12705  Сам готель усередині нагадує гуртожиток чи хос...          6.3
# 12706  сантехніку (труби, стоки) необхідно перевірити...          9.6
# 12707                                                Nan         10.0
# 12708  начебто новий ремонт - а велика тріщина над дв...          7.5
# 12709  Дуже круті сходи. Складно знайти поруч місце д...          9.2
# 12710  Дуже душно, номер з вікном на стелі, дотягнути...          4.6
# 12711  - Дуже круті сходи між поверхами і відсутність...          7.1
# 12712                                                Nan          9.2
# 12713  Не було полиці в ванній кімнаті. Цього дуже не...         10.0
# 12714  Тонкі стіни, чути, що робить персонал . Але це...         10.0
# 12715                                                Nan         10.0
# 12716  Тонкі стіни, дуже чути сусідів, особливо шум з...          7.1
# 12717  Двері у душ погано закриваються і трохи відтік...         10.0
# 12718  На першому поверсі неможливо спати через відсу...          6.7
# 12719  Нема сніданків. Душова кабінка щільно не закри...          8.5
# 12720                                                Nan         10.0
# 12721  звукоізоляція просто жах, ще гіршої я не бачил...          5.4
# 12722                                                Nan          9.2
# 12723                                                Nan          9.6
# 12724                     Так чисто, що аж око ріже 🙃!!!         10.0
# 12725  Відсутність ліфту (в готелі 4 поверхи), для ти...         10.0
# ...                                                  ...          ...
# 14784                                                Nan          7.9
# 14785                                                Nan          8.8
# 14786                                                Nan         10.0
# 14787  Єдине що було б не зайвим зробити безшумні две...          8.8
# 14788  У дощовий дні хотілося снідати в готелі. Але р...          9.6
# 14789                                                Nan         10.0
# 14790                               відсутність сніданку          9.6
# 14791  Погано ловив wi-fi в номері (потрібно гуляти, ...         10.0
# 14792                                                Nan         10.0
# 14793  Відсутність ліфта, паркування, завищена вартіс...          8.3
# 14794                     Був неприємний запах у ванній.          8.3
# 14795                                                Nan         10.0
# 14796                                   Сподобалось все!         10.0
# 14797               Сиро в номері. Запах нового ремонту.          6.3
# 14798                                                Nan         10.0
# 14799                     Почуття будівництва присутній.          7.5
# 14800  знижки Genius- її не було, підозрюю персонал п...         10.0
# 14801                                                Nan          9.2
# 14802   Небезпечний для життя стелю в номері. Неприємно.          7.1
# 14803  Гаряча вода з перервами. Ціна на травневі свят...          8.3
# 14804  У номері було сиро до такої міри, що навіть вз...          7.5
# 14805     В готелі зробили недавно ремонт. Пахне фарбою.          6.3
# 14806   Відсутня рушник для підлоги у ванній, краю ліжка          9.2
# 14807           Відмінний готель, в самому центрі Львова         10.0
# 14808  Чи не попередили, що вночі закривають ворота і...          8.8
# 14809                         Але дуже велика вологість.          8.8
# 14810                                                Nan         10.0
# 14811                                       Вид з вікна.         10.0
# 14812                                                Nan          7.5
# 14813                            мінус - немає сніданків          8.3
#
#        bestRating         hotel  rating
# 12696        10.0  blum.uk.html       2
# 12697        10.0  blum.uk.html       4
# 12698        10.0  blum.uk.html       5
# 12699        10.0  blum.uk.html       5
# 12700        10.0  blum.uk.html       5
# 12701        10.0  blum.uk.html       5
# 12702        10.0  blum.uk.html       4
# 12703        10.0  blum.uk.html       4
# 12704        10.0  blum.uk.html       5
# 12705        10.0  blum.uk.html       3
# 12706        10.0  blum.uk.html       5
# 12707        10.0  blum.uk.html       5
# 12708        10.0  blum.uk.html       4
# 12709        10.0  blum.uk.html       5
# 12710        10.0  blum.uk.html       2
# 12711        10.0  blum.uk.html       4
# 12712        10.0  blum.uk.html       5
# 12713        10.0  blum.uk.html       5
# 12714        10.0  blum.uk.html       5
# 12715        10.0  blum.uk.html       5
# 12716        10.0  blum.uk.html       4
# 12717        10.0  blum.uk.html       5
# 12718        10.0  blum.uk.html       3
# 12719        10.0  blum.uk.html       4
# 12720        10.0  blum.uk.html       5
# 12721        10.0  blum.uk.html       3
# 12722        10.0  blum.uk.html       5
# 12723        10.0  blum.uk.html       5
# 12724        10.0  blum.uk.html       5
# 12725        10.0  blum.uk.html       5
# ...           ...           ...     ...
# 14784        10.0  blum.uk.html       4
# 14785        10.0  blum.uk.html       4
# 14786        10.0  blum.uk.html       5
# 14787        10.0  blum.uk.html       4
# 14788        10.0  blum.uk.html       5
# 14789        10.0  blum.uk.html       5
# 14790        10.0  blum.uk.html       5
# 14791        10.0  blum.uk.html       5
# 14792        10.0  blum.uk.html       5
# 14793        10.0  blum.uk.html       4
# 14794        10.0  blum.uk.html       4
# 14795        10.0  blum.uk.html       5
# 14796        10.0  blum.uk.html       5
# 14797        10.0  blum.uk.html       3
# 14798        10.0  blum.uk.html       5
# 14799        10.0  blum.uk.html       4
# 14800        10.0  blum.uk.html       5
# 14801        10.0  blum.uk.html       5
# 14802        10.0  blum.uk.html       4
# 14803        10.0  blum.uk.html       4
# 14804        10.0  blum.uk.html       4
# 14805        10.0  blum.uk.html       3
# 14806        10.0  blum.uk.html       5
# 14807        10.0  blum.uk.html       5
# 14808        10.0  blum.uk.html       4
# 14809        10.0  blum.uk.html       4
# 14810        10.0  blum.uk.html       5
# 14811        10.0  blum.uk.html       5
# 14812        10.0  blum.uk.html       4
# 14813        10.0  blum.uk.html       4
#
# [379 rows x 7 columns]

# %%
pos_texts = [text for text in blum_df['neg_text'].values if type(text) is str and text != 'Nan' and len(text) > 0]

# %%
pos_texts
# Out:
# ['Брудні і обшарпані стіни номеру Дуже жарко в номері Відсутність ліфту Слабий напору води Сейф який нам так і не відкрили, т . б . скористатися ним ми не мали змоги',
#  'Одну з ночей хтось постійно ходив по коридору і ми не могли нормально спати через дзвінкий стукіт підборів об плитку . З Комаровим покриттям в коридорі було б комфортніше . Меблі в номері вже трохи втомлені',
#  'Було б непогано мати чайник в номері, чай та каву, як це часто буває.',
#  'Запах в номері, якійсь був солодкий, напевно від ароматизатор.',
#  'шумоізоляція, та досить велика щілина внизу дверей на коридор, коли хтось ходить заважає.. невеликий поріг би виправив це!',
#  'звукоізоляція могла б бути і кращою . Не зайвим був би косметичний ремонт номера.',
#  "Сніданок в ціні номеру міг бути більшим, до кав'ярні треба йти через вулицю. Надзвичайно тонкі стіни в номерах - чути кожне слово",
#  'Сніданок: хотілося б шведський стіл, а не кілька страв на вибір. Дивний душ у номері: важко регулювати температуру води, незручно стояти.',
#  'один маленький мінус, але нам це не завдало незручність - в душовій кабіні було не пілотне прилягання двері',
#  'Сам готель усередині нагадує гуртожиток чи хостел. Душова кабіна не зачинається, відповідно вся підлога залита водою.',
#  "сантехніку (труби, стоки) необхідно перевірити та відремонтувати, оскільки в деяких місцях на стіні біля санвузли з'являються вологі плями . Бажано розширити меню кафе.",
#  "начебто новий ремонт - а велика тріщина над дверима, двері в туалет заїдають, вибір сніданків великий, але на тост з яйцем Ашот чекав 15 хв (може тому перший раз в житті їв Ашот зварений круту) )) дуже незручні ліжка - матраци класні - а рама ліжка широка і дерев'яна - поки звикнеш, заробиш кілька синяків) ) )",
#  'Дуже круті сходи. Складно знайти поруч місце для паркування. Скупий сніданок. Маленький телевізор. В погану погоду навряд зручно виходити на сніданок у сусідню будівлю в кафе.',
#  'Дуже душно, номер з вікном на стелі, дотягнутись до вікна не можливо. Запах цигарок в номері при поселенні. Не дуже чисто. Навіть було чуже волосся на білизні. Зупиняюсь не перший раз в цьому готелі, але зараз дуже погано',
#  '- Дуже круті сходи між поверхами і відсутність ліфта . - У бронюванні було вказано, що сніданок включено у вартість, проте насправді за нього потрібно доплатити 75 грн . Дуже скупе сніданком меню (при тому, що половини вказаного там, не виявилося у наявності). - Джуел погана шумоізоляція - будьте готовими чути усіх гостей, що піднімаються сходами, чи увімкнені будильники у сусідніх номерах.',
#  'Не було полиці в ванній кімнаті. Цього дуже не вистачає дівчаткам 😁😉',
#  'Тонкі стіни, чути, що робить персонал . Але це ок, не занадто заважало',
#  'Тонкі стіни, дуже чути сусідів, особливо шум з душу.',
#  'Двері у душ погано закриваються і трохи відтікає вода . У ванній нема Молочки для зберігання мила, зубної щітки . Але стіл у кімнаті з радістю сприйняв всі Самчики, а стакан з кімнати переїхав у ванну для зручності )',
#  'На першому поверсі неможливо спати через відсутність шумоізоляції . Вночі було дуже чутно ВС розмови з коридору біля рецепції . несправний злив в унітазі.',
#  'Нема сніданків. Душова кабінка щільно не закривається, тому після душу вся підлога мокра, можна послизнутися.',
#  'звукоізоляція просто жах, ще гіршої я не бачила!!! Посилили нас в номер прям біля рецепція (в 2-х метрах) так вранці було чутно всі розмови, всі заселення і виселення! Навіть шум кавової машини було чути наче як під вухом! Такі номера не мають право на життя і перекреслюють абсолютно всі плюси готелю!!! Більше не бронювати!',
#  'Так чисто, що аж око ріже 🙃!!!',
#  'Відсутність ліфту (в готелі 4 поверхи), для тих хто з авто немає парковки.',
#  "Єдиний мінус: коржик в туалеті був м'яко кажучи в поганому стані",
#  'Немає ресторану та сервісу обслуговування в кімнатах. Тому за сніданком треба іти в кафе, ресторан.',
#  'Єдиний маленький мінус, який не зіпсував мій відпочинок - слабка шумоізоляція. Чула весь діалог сусідів за стіною )',
#  'Готель не надає можливості поснідати. Але вони працюють над цим)',
#  'Чув, що сусіди з інших поверхів скаржились на погану шумоізоляцію . Думаю так воно і є, однак мені пощастило жити на останньому поверсі та, напевно, не було сусідів . Крім годинникового бою з сусідньої веж ні чого не чув) хоча якусь поличку у ванній . Треба поміняти праску . Ну дуже нещасна . можна зіпсувати одяг.',
#  'Погана звукоізоляція між кімнатами, якщо попадуться шумні сусіди (як мені) – спати неможливо . Пропоную роздавати гостям Белуші.',
#  'Трішки тонкі стіни, було чути розмови за дверима, але зовсім тихо - спати це не заважало.',
#  'З відчиненим вікном вранці не виспалися, адже в дворику під вікнами було трохи шумно. Постійно замикалися двері у ванній кімнаті, тому доводилося їх просто прикривати, а не закривати.',
#  'Жахливо смерділо лаком чи новим ремонтом . Вікно в стелі, яке неможливо відкрити, бо дуже високо . Дихати нема чим . В середині ночі була змушена відкрити двері в коридор, бо думала, що задихнувся . щілина між дверима і підлогою така велика, що коли ти лягає в ліжко, то з коридору б ‘ є холодне біле світло прямо в очі . Жахлива видалася ніч!',
#  "На жаль, відсутня опція сніданку . Але поблизу готелю розташовані декілька кав'ярень і ресторацій, це вирішує проблему.",
#  'Конкретно для мене це не була проблема, що нема сніданку, але якщо скеровувати інших, то це може бути пересторогою. Мені було достатньо смачної кави у холі біля рецепції. Великий попит на заселення у цей готель, тому, на жаль, мені не вдалося домовитися ні про ранній заїзд, ні про пізній виїзд. Проте, якщо хтось буде планувати заздалегідь поїздку, то раджу врахувати всі деталі, і все ж обрати Блюм.',
#  'Єдиний мінус - це звукоізоляція . Але нас з подругою це навіть повеселили: )',
#  'Малий по площі номер за таку вартість',
#  "Не раджу номер біля сходів. Було шумно в першу ніч, пів ночі не спали.  Взагалі сильно чутно рух людей по сходах. Немає зв'язку з адміністратором з номеру.",
#  'Кава - автомат не працював вранці, коли конче потрібна була кава) І ще - поставте москітну сітки на вікна, будь Ласточка.',
#  "Поганий зв'язок в номерах (це не відноситься до Wi-Fi), немає сніданків",
#  'намагалась щось знайти, але нічого не знайшла) все дуже круто!',
#  'Звукоізоляція дійсно погана.',
#  'Була літня вода.(не зверталася до персоналу, бо була лише на одну добу і немала часу).\nНе сподобалася якість рушників.',
#  'шумно зранку. погана звукоізоляція.',
#  'Дуже тонкі стіни, чути як хтось відкриває воду у сусідньому номері.',
#  'Душова кімната брудна',
#  'Протікає душова кабіна.',
#  'Варто вивісити вказівники для полегшення пошуку готелю',
#  'Напевно, вже час на певний ремонт',
#  'Вночі (12 год) була тільки холодна вода в душі, але в цю спеку це був, скоріше, плюс :-))',
#  'Відсутня парковка.',
#  'Такого не виявлено',
#  'Жила на першому поверсі і практично 3 дні було відсутнє опалення, а на дворі було досить холодно',
#  'Не працював ресторан, тому на жаль не було сніданках',
#  'Гарний готель, все чисто, персонал дуже привітний!  Перебуванням залишились задоволені!',
#  'Занадто гучні гості та  жодної реакції персоналу на це.',
#  'Звукоізоляція відсутня',
#  'Так як це центральна частина міста - проблема з парковкою авто',
#  'В туалеті мало світла',
#  'Відсутність власної парковки.',
#  'Прохолодно',
#  'Звукоізоляція.',
#  'Все сподобалось',
#  'Відсутні сніданки',
#  "Хтось п'яний майже всю ніч голосив польською😐",
#  'Світло з під дверей... 😀',
#  'Шумоізоляція',
#  'Вхід на поверхи тільки сходами',
#  'Мансардний поверх.',
#  'необхідно додати припинений Коврига на підлогу в данный кімнаті',
#  'Звукоізоляція.',
#  'У приміщенні відчувається запах сирості, особливо на першому поверсі',
#  'Неможливість потрапити в номер після 2:00 у звязку з зачиненою брамою. Ще залишився "запах ремонту"',
#  'Абсолютно ніде припаркувати машину . Вночі знайшли вільне місце біля готелю і перерветься автомобіль, а на ранок ззаду отримали подряпину на бампері . враховуйте це, вибираючи готель . Очікування - реальність не співпали абсолютно . Прочитала багато позитивних відгуків і дуже розладналися, коли поселилася туди . У коридорах є відчуття, ніби ти потрапив в гуртожиток . шумоізоляція немає . Чути як люди йдуть по сходах, відкривають двері, розмовляють, найменший шум буде чутно у вас в номері . прокидалася цілу ніч від шуму . Телевізор - не працювали канали . Дуже смерділо з приймалень, саме каналізацією . Запах від туди йшов в кімнату . І на завершення, на жаль готель розчарував.',
#  'Як зазвичай буває, хто-то додумався голосно розмовляти рано вранці в коридорі, а ми знаємо, що звукоізоляція дверей рідко буває хорошою)',
#  'Є кілька, ймовірно, не важливих, але які впливають на відчуття повного комфорту, моментів. Звукоізоляцію хотілося б краще. Для готелю такого цінового рівня, використовувати в душовій кабіні правило для притвору дверцята вважаю неприпустимим ... Естетика пропадає, враження меркнуть, підлогу залитий водою ... Адміністрація, це просто НЕОБХІДНО виправити. Ще раз про сніданки. Так, смачно, але меню дуже просте і убоге. Для вашого рівня необхідний значно більший вибір в меню.',
#  'Відсутність парковки, але місце до вечора можна знайти. У нашому номері не щільно закривалася дверцята душа. Погана шумоізоляція. В цілому залишилися дуже задоволені, рекомендую!',
#  'Сніданок на вибір по меню, але не всі позиції є в наявності. Готель виглядає якось обшарпані і убого (пора робити ремонт), фіранки зірвані з кріплень і нормально закрити їх неможливо. Замок на вхідних дверях в номер трохи заїдає.',
#  'V menu Vapiano, Show Sandwich Budget 2 a ya Postal Tiki 1: (',
#  'Номер маленький, в тому числі ванна . Для однієї людини більш - менш, для двох - напружено.',
#  'Не було в наявності лопатки для взуття)',
#  'Батареї не були включені . Але питання обігріву легко вирішувалося кондиціонер',
#  'Погана звукоізоляція. Вночі чутно, як хропуть сусіди і ходять до вбиральні, дуже не комфортно через це.',
#  'У ванній був специфічний запах, і підшукала душова кабіна, сходинки високі, складно буде підніматися якщо ви з багажем . На сніданку якщо багато людей потрібно чекати, так як сніданок не шведський стіл, а по меню . Але це дрібниці, в цілому враження від готелю позитивне!',
#  'З мінусів: дуже дешева сантехніка в санвузлі. На сніданок можна вибрати тільки одне блюдо, нам було незручно.',
#  'Номер потребує ремонту (штукатурка відлітає, дзеркало у ванній бите, слив в унітазі заїдає). І дуже погана звукоізоляція між номерами. Чути як сусіди миються і ходять в туалет.',
#  'Були у відрядженні, заселилися пізно, оплатили вранці, але адміністратори до виїзду так і не змогли правильно оформити необхідні документи!',
#  'Відсутня ліфт, не зручно тягнути валізи на 4 ет Номер в мансардному поверсі, скошена стеля & quota; з & #39; їдає & quota; площа З гостьової косметики: мило і шампунь . Чи не поповнюється.',
#  'Якість взагалі не соответствует ціною! Дуже велика сутність, чистота на 2 . Ремонт Решевський . неврегульована температура води в душі: то окріп, то Холодная (по всій видимості, якщо сусіди включили воду - чекайте сюрприз) Сніданок взагалі окрема історія - вівсяну кашу несли годину!!',
#  'Зручне місце розташування, до центру 10 хвилин, а так поруч величезна кількість кафе і ресторанів, сам готель новий, нові меблі, в номері тихо, чисто і затишно, є кондиціонер, в номері штори щільні, до літака спокійно спала і відмінно відпочила) персонал говорить на всіх мовах світу, допомогли валізу підняти в номер) рекомендую)',
#  'Чи не закривалася дверцята душа і вода лилася на підлогу, текло з змішувача. Звернулася на ресепшн - обіцяли все виправити. У номері на двох було одне ковдру-потрібно просити друге на ресепшн.',
#  'Двері в душову не прилягає щільно, тому доводилося трохи акуратно митися щоб не забризкали підлогу.',
#  'єдине-ліжко не зручна дошкою для вставання',
#  'Невеликий вибір сніданків . сніданки порційні, а не & quota; шведський стіл & quota ;.',
#  'Була погана звукоізоляція. Номер на першому поверсі і чути все. І як розмовляють мешканці на ресепшені і як спускаються сходами.',
#  'Сходи і поверхи дуже нагадують шкільні коридори. Номер не затишний - стіни пофарбовані в блакитний і фіолетовий з геометричними фігурами. Склалося враження, що ліжко поставили в кабінеті геометрії. Умивальник дуже маленький і душова кабінка протікає.',
#  'Двері в душі не закривається . налив води на підлогу ..... після зайшла дочка в туалет і послизнулася (упала), в результаті сльози, соплі .... телевізор занадто маленький, канали - & quota; фу & quota;, дивитися нема чого (але ми не телевізор приїхали дивитися до Львова). Коротше все це дрібниці, в цілому готель нормальний.',
#  'У ванній кімнаті не було полички, незручно Гель та шматочок мила були видані один раз за 5 днів Чому то було дуже волого в кімнаті Сніданок хотілося б доповнити: якщо береш сік, то кава вже не належить ?!',
#  'Трохи заплуталися з пошуком готелю, так-як він у дворі.',
#  'У номері економ на 2-му поверсі вікно в стелі, через дощ не могли відкрити вікно і вночі було дуже душно, в душі погано працює злив, трохи тіснувато, але в цілому нормально, авто практично ніде припаркувати, дуже не зручний матрац',
#  'Неможливо відпочити через чутності. І всередині і зовні готелю',
#  'шкода, що у дворик готелю вранці курить персонал. відкрити вікно неможливо, тому що дим від сигарет повністю в кімнаті. при збирання не оновлювали мило, шампунь.',
#  'Немає такого',
#  'Пара мінусів була несуттєвих: відсутній заявлений праска і ліжко незручною конструкції з високими виступами по периметру.',
#  'Матрац поганий. Для ліжка з бортиком просто дуже незручний - низький і дуже м&#39;який.',
#  'Готель у приватному будинку. Вулиця вузька, складно паркуватися.',
#  'Занадто слизька плитка в туалеті.',
#  'відсутність парковки і слабкий напір води, ліжка з виступаючим дерев & #39; яним бильце - дуже не зручно . відсутність додаткових спальних приладдя (ковдру), вночі було холодно.',
#  'У мене був нюанс в туалетній кімнаті . Там відверто протікала каналізаційна труба . Тому наступает « рідина » і був соответствующих запах . Швидко Дубровін на моє прохання, проте до ранку було те ж саме . Це питання не персоналу, а ремонту.',
#  'У всьому можна знайти мінуси, якщо придивитися ... Зрозуміло - це не 5 *. Для свого рівня - все нормально.',
#  'Просіть документи по відрядження в перший же день . А - то може вийти як у мене . Мені не встигли підготувати вчасно документи на моє відрядженні, пояснили тим, що в принтері закінчився картридж (а я виїжджала в вихідний день) не було кому його поміняти . Загалом документи по приїзду додому я отримала на Московскую пошту на 5 й день . Сподіваюся що оригінали дійдуть швидко . Не знаю як у кого, а у нас в компанії бухгалтерія до цього ставитися дуже строго . Тому в цьому плані готелю ставлю жирний мінус.',
#  'Номер розташовувався на 4 поверсі (останній), було дурнувато, навіть при відкритому вікні . Доводилося користуватися кондиціонером . Можливо, на нижніх поверхах такої проблеми не існує.',
#  'Звукоізоляція трохи кульгає.',
#  'Дверцята в душовій дуже нещільно прилягає, тому, як би не старався митися акуратно, вода у великій кількості все одно виявляється на підлозі у ванній кімнаті . На рушник висів чийсь довгий чорний волосся . Не дуже приємно було його виявити . сутність дуже хороша . прям ду-у-уже все чутно.',
#  'Сніданок у вартість номера Більше напору води в душі',
#  'Ліжко в номері з дерев & #39; яною рамкою по периметру . матрац просідає нижче рівня каркаса і весь час чимось вдаряється (то ногою, то ліктем).',
#  'погана шумоізоляція, особливо чутно, коли ходять на підборах по коридору вночі: D',
#  'На момент проживання не було сніданків, ресторан був на етапі закінчення ремонту або будівництва. Обіцяли найближчим часом (після закінчення ремонту ресторану) надати сніданки. Звукоізоляція викликала у мене сумніви - були дуже чутні всі дії і розмови в коридорі, але ніч пройшла спокійно.',
#  'Єдиний значущий для нас мінус - відсутність ліфта, довелося тягнути велику сумку на 3й поверх по сходах.',
#  'Шкода немає чайника.',
#  'Шкода була їдальня на ремонті, але не впевнений була потреба, Пузата хата 2 хвилини (за кутом), провулок кривої липи з 10 закладами в 4 хвилинах . І ще кав & #39; ярні.',
#  'Ні паркування. Машину подряпали на вулиці, поруч з входом в готель. Поїхали на день раніше, гроші повертали кілька днів.',
#  'Все було чудово.',
#  'звукоізоляція в готелі так собі, були чутні розмови на вулиці (мій номер був на 1-му поверсі) і в коридорі, але їх було небагато, і в цілому мене це не дуже турбувало . Кому принципова повна тиша, запасіться Белуші.',
#  'У готелю немає своєї парковки як заявлено. Машину можна припаркувати в дворі біля тротуару і на тротуарі якщо пощастить. Мешканці не задоволені і категорично проти. Коли ми припаркували машину на тротуарі, жінка зробила нам зауваження і сказала прибрати її.',
#  'Погана шумоізоляція . Наш номер розташовувався поруч з ресепшені . Чули все і всіх . З дванадцятої ночі і до третьої ранку п & #39; яні польські туристи голосно кричали, співали пісні під вікном і в самому готелі . Незрозуміло, чому не викликали поліцію за порушення громадського порядку . Цей інцидент змазав все враження від поїздки.',
#  'шумоізоляція відсутня геть! Було багато поляків, які 24 години на добу поводяться як свині! соответственно все це чути і спати вночі не можливо! Я тепер їх ненавиджу!!!!',
#  'Двері у ванній відки / Закр насилу, заїдає замок.',
#  'Шумоізоляція, чутно все переміщення і розмови з сусідніх номерів і коридору, але це проблема більшості готелів',
#  'підшукала вода в унітазі',
#  'Шумоізоляція. Коли сусіди в 5 ранку йдуть в туалет, приймають душ, вмиваються, сушать волосся феном, і з ще там двоє, і це на хвилин 40. І ви не спите, тому що чутно все так ніби це відбувається у вас в кімнаті. Це жахливо. І ще. Коли приймаєте душ, вода знизу дверцята буде потрапляти на підлогу. І як би ви не старалися, буде мокро.',
#  'звукоізоляція відсутня . Чути, як по сходах в коридорі ходять . Як включають воду сусіди . Раковина для вмивання маленька, вмиватися неможливо - вода розливається на підлогу . Немає ущільнювачі між дверима душової кабіни і стіною - вода ллється на підлогу і в кімнаті в результаті на стіні сире пляму . парковки немає, що в центрі міста незручно . WiFi дохлий - в будь - якому кафе - ресторані літає.',
#  'Сподобалось все !!! Це тільки побажання !!!! Вішалка для курток, поличка над раковиною у ванній і трохи більше світла біля дзеркала ..',
#  'Звукоізоляція. Якби по готелю бродили галасливі п&#39;яні люди, було б сумно. Але постояльці відповідали готелю. Все дуже культурно.',
#  'Взагалі відсутня звукоізоляція! Чути навіть шепіт з сусіднього номера . Якщо поруч живуть діти, можна попрощатися зі сном . При цьому прибирання починається щодня з 9 ранку, і перше, що включають - пилосос! З урахуванням чутності, відчуття, що пилосос прямо біля вуха . Навіть за законом у вихідні можна шуміти раніше 10 ранку . Чому ж треба щодня катувати ваших постояльців ранковим пилососом?! Все - таки готель для відпочинку і тасують до ранку молоді',
#  'Трохи протікала дверцята душа, що не дуже сильний напір води (жили на останньому 4 поверсі), але це не критично.',
#  'Співвідношення розміщення 4 го поверху та кавоварки (підніматися з гарячим напоєм незручно, та й на виході в холод похапцем пити). За водою з кулер доводилося спускатися поверхом нижче . сутність сильна через тонких стін (коли по - сусідству чутно все що відбувається у ванній кімнаті).',
#  'Не зовсім сучасний стиль і ремонт . Вікна кімнати виходять у внутрішній двір іншого будинку . Місце для однієї ночівлі більше, ніж насолоди містом і рефлексом.',
#  'Ціна відповідає якості. Хороший готель.',
#  'Висока сутність всього, що відбувається навколо, тонкі вхідні двері . Бракує халатів для ванної . Наш номер був маленький (заходиш в номер і впораєшся в ліжко), вікно було маленьке в стелі . У наших друзів за ту ж ціну був номер набагато просторіше.',
#  'Верхнє, оглядове вікно постійно запитувало і з нього вночі капав конденсат (вода) на ковдру . Чи не справлялася витяжка у ванній кімнаті!',
#  'Немає опції вибору проживання зі сніданком - на сніданок потрібно йти в ближайшее кафе, яких благо багато в крокової доступності.',
#  'сутність Стан меблів (у ванній була зламана поличка) Вцілому мало місця для розташування косметичних засобів У батареї працював тільки один відсік (грілася кондиціонером )',
#  'У кімнаті на першому поверсі досить хороша сутність всього, що происходит у дворі . І не дуже комфортно, що кондиціонер прямо над вікном (( ((',
#  'бронювали стандарт підвищеної комфортності, по приїзду хотіли поселити в звичайний стандарт (скошена дах і низькі стелі) стверджували, що обидва види номерів стандарт, але при бронюванні на Букін це були номери різної категорії і з різниці в ціні 200 грн за ніч',
#  'Чи не поповнювали в номері шампунь, поки не попросиш . Упаковка шампуню маленька . Не було гелю для душу (було холодно в номері, Конде не допомагав.',
#  'Тонкі стіни, відповідно дуже чутно все що відбувається в сусідських номерах',
#  'отсутствие вікно - не пам & #39; ятаю, що б про це говорили при booking . Світло в загальному холі через дверну щілину висвітлював кімнату - довелося змушувати валізами - маски нічний не було, інакше спати неможливо ....',
#  '-',
#  'Ні. Одні позитивні емоції.',
#  'Ванна простувати в порівнянні з кімнатою, але улучшить це можна тільки таким ремонтом.',
#  'Ванна кімната схожа на лікарняну. Під вхідними дверима немає порогу, чутно як хто спускається по сходах, що говорять і взагалі шумоізоляції немає. Чути як купаються сусіди)) Телевізор міг би бути і більше)',
#  'Все настільки було добре, що я не знайшов ніяких недоліків',
#  'Не вистачало світла в номері, душова через двери протікала трохи, номери в мансарді не зовсім підходять людям з ростом вище 1,80 доводилося нагинати щоб відкрити вікно',
#  'Буде ще краще коли в об&#39;єкті розміщення з&#39;явиться своє місце харчування і сніданки, що було б супер для ранніх виїздів і пізніх так само :)',
#  'незручні краю ліжка: вузькі чотиригранні деревянные борту, оздоблюють матрац виходять за його розмір і неприємно тиснуть при спробі лягти або піднятися.',
#  'Єдина рекомендація з мого боку для готелю - це наявність харчування (сніданок)',
#  'Чи не сподобалося тільки пару речей, але претензії більше до проектувальників . Споруда нова, відповідно, як і в багатьох нових будинках, сутність за стінами дуже хороша . Чули і душ і розмови . І з душем щось: начебто милуєшся з зачиненими дверима, а вода все одно зовні на підлозі . Потім в стіну вбирається і патьоки . Я бігав ганчірочку шукала, щоб витерти.',
#  'Матрац був занадто м&#39;яким, хворіли спини вже на третій день. І не закривалася дверцята душа.',
#  'Мінусів просто немає',
#  'Поставити б їм в холі біля ресепшені і автомата з кавою ще пару канапок!) ) )',
#  'Відсутність парковки, маленький сан вузол, дешева сантехніка, галасливий зовнішній блок кондиціонера.',
#  'Такого не виявлено',
#  'Тонкі стіни) коли в сусідньому номері приймали душ було чутно ... точно так само були чутні розмови.',
#  'мінусів немає',
#  'Вид з четвертого поверху на будівлі на даху і ходіння там якихось людей ...',
#  'Немає розпізнавальних знаків готелі, немає вивіски, важко в перший раз знайти вхід.',
#  'Мало днів відпочинку :)',
#  'Хороший новий готель, але: Кондиціонер прямо в обличчя дме. У деяких номерах на фото це видно. Потрібні штори! Щільні, на ніч! Ну новий же готель, невже не можна подивитися, що і як у хороших готелів, і зробити так само? !! Світло в вікно в 6 ранку! У ванній 1 лампочка! Чи не поголитися нормально. Взяв номер з двома ліжками - ліжка дуже вузькі! Навіть мені, що не широкому, там було вузько!',
#  'З засобів особистої гігієни: зубна щітка + паста, маленька баночка шампуню, який слабо піниться і маленьке мило. Т.ч. шампунь і гель для душу краще брати з собою. (3 рушники на людину 👍)',
#  'Сніданок з 8 : 30 (а й цю проблему вирішили під нас і накривали стіл до 8 : 00) У номері замість холодильника, морозильник . (У нас все успішно заморозило )',
#  'За столом у номері незручно працювати. Стілець під столом поміщається, а ось ноги вже немає. І душ не закривається повністю, так що після його використання - мокра підлога.',
#  'На вікнах немає Москвітіної сітки (вікно було відкрито до нас і налетіло купа комарів). Нема рушники для підлоги у ванній . У ванній на дзеркалі немає полички . У номері на першому поверсі відчувається підвищена вологість . Не дуже гарна шумоізоляція.',
#  'У кулуарах на поверхах не було підігріву води.',
#  'У номері на першому поверсі дуже сиро, речі просочилися вологою . шумом ізоляції нуль, чутно все . Чути як ходять, розмовляють, тягають речі і тд.',
#  'немає можливості набрати окропу що б хоча б чайку заварити',
#  'У номері на першому поверсі дуже велика вологість, швидше за все через відсутність прямих сонячних променів, але зробили знижку на проживання так як кондиціонер не справлявся з даної проблемою.',
#  'Ми були навесні і в номері було дуже волого . Одна стіна була мокра . Ще при заїзді нам назвали ціну вище, ніж була вказана при броні . Після обязательств номер нам здали за ціною вказаної з booking',
#  'Ні вивіски, навіть таксист не відразу знайшов вуличку, прохід до готелю через темну арку . Дуже чутно всіх сусідів.',
#  'Маленький номер, постійно вдаряється об усе кути. Краї ліжка дуже незручні, синці забезпечені всім',
#  'У душовій нещільно закриваються двері. Як наслідок, вода на підлозі',
#  'все прорвалось',
#  'Шумоізоляція, галасливий душ, маленький натиск, коли приймають душ в сусідньому номері ви більше не спите)',
#  'Не вистачило гелю і шампуню, просили ще. Пізніше додали)',
#  'Ні.',
#  'Потягати сантехніка, дверцята в душ не закривається, іржаві полички в душі.',
#  'своєрідний внутрішня планування готелю',
#  'Немає ліфта, при бронюванні я цього не знала, і довелося тягнути важкий чемодан на 2 поверх',
#  'Сніданки проходять в кафе поряд і персонал явно не справляється. Ти змушений чекати поки приймуть замовлення, потім ще довго поки його винесуть.',
#  'При бронюванні 2 + 1, сніданок для дитини виявився платним',
#  'важко знайти',
#  'Готель свіжий, є запахи вогкості, кафе і сніданок не дуже',
#  'Все відмінно',
#  'Ні паркування, і припаркувати авто немає шансів',
#  'Не дуже зручні меблі. Маленький вибір сніданків',
#  'Дверцята душової кабінки прилягає нещільно, після душу в санвузлі калюжа на підлозі, не завадив би килимок.',
#  'Дверцята в душі не предлагает повністю, у зв & #39; язку з цим вода на підлозі.',
#  'Вид з вікна так собі, але це не сильно важливо',
#  'Все сподобалося',
#  'Крихітний номер з дуже низькою стелею (скошений від 2 м до 1,5 м, і це в номері)',
#  'Постільна білизна була не чисте. Наволочки були в волоссі і брудні.',
#  'Шумоізоляція не дуже. Відсутність ліфта і дуже круті сходи.',
#  'скромний сніданок',
#  'Вода з душа потрапляє на підлогу у ванній',
#  'Ні паркування.',
#  'Все нормально, але сутність в номері підвищена',
#  'сутність сусідів дуже сильна',
#  'Сніданок смачний, але слабенький за обсягом.',
#  'Незручності в ванній кімнаті. Ніде розмістити свої особисті речі. Скрізь витікає вода.',
#  'Круті сходи.',
#  'Абсолютно відсутня шумоізоляція номерів',
#  'Гучний внутрішній дворик',
#  'Дуже погана шумоізоляція, чутно кожен крок і звук в коридорі ... цей мінус затьмарює всі плюси',
#  'обслуживание . із через раннього виїзду залишився без сніданку',
#  'Не сподобався сніданок',
#  'Холодно, запах в душі, звукоізоляція',
#  'Дуже тонкі стіни, чути сусідів дуже, як ніби в вашому номері кажуть, слова все розбірливо зрозумілі',
#  'Світло з коридору світить в кімнату через щілину між підлогою і дверима. Заважає спати.',
#  'звукоізоляція на 0!!!! все чути! спав в біржах ....',
#  'Вибрав найдешевший номер, але в ньому не було вікна',
#  'У ванній трохи провисіла двері і підшукала вода на підлогу . Телевізор трохи вайлуватий',
#  'відсутня звукоізоляція',
#  'Шумоізоляції нуль, чутно навіть як включається вода в сусідньому номері.',
#  'Немає сніданків.',
#  'Тонкі стіни, не вистачало предметів гігієни',
#  'погана звукоізоляція',
#  'Ні паркування. Номери маленькі. Ліжка поодинокі не зручно.',
#  'звукоізоляцію',
#  'хотілося б кращу звукоізоляцію',
#  'Недостатня шумоізоляція))',
#  'Дуже тонкі стіни, чути сусідів, були помічені таргани в номері',
#  'Спека! Потрібно автоматизувати опалення.',
#  'Немає такого',
#  'Шумоізоляції зовсім немає!',
#  'відсутність звукоізоляції',
#  'Приймати більш радикальні заходи до гостей, які вночі поводяться неадекватно.',
#  'Взимку дуже холодно в сан . зле',
#  'Дуже тонкі стіни, чути сусідів',
#  'Слабка шумоізоляція.',
#  'Номер на першому поверсі, немає звукоізоляції, немає снеків, якщо приїжджаєш пізно ввечері, то перекусити не зможеш.',
#  'Немає претензій.',
#  'Дуже тонке ковдру. У номері було досить холодно',
#  'погана звукоізоляція',
#  'Якість ремонту, погана шумоізоляція',
#  'Все було добре',
#  'немає сніданків',
#  'Парковка могла б бити краще ...',
#  'Хотілося, щоб б був все таки сніданок готелі',
#  'Ліжко: матрац трохи менше, ніж ліжко',
#  'Відсутність у ванній кімнаті полички для туалетного приладдя',
#  'Напір води в душі слабенький (',
#  'Сподобалось все',
#  'Не знаю.',
#  'Розмір подушки виявився для мене великий',
#  'Сподобалось все.',
#  'Все добре',
#  'Дуже шумно. Чути шум мотора.',
#  'Дуже тонкі стіни і висока сутність з інших кімнат.',
#  'Мінусів немає)))))',
#  'Єдине що було б не зайвим зробити безшумні двері, чути що відбувається в коридорі',
#  'У дощовий дні хотілося снідати в готелі. Але ресторану немає.',
#  'відсутність сніданку',
#  'Погано ловив wi-fi в номері (потрібно гуляти, а не сидіти в номері;))',
#  'Відсутність ліфта, паркування, завищена вартість, слабка звукоізоляція',
#  'Був неприємний запах у ванній.',
#  'Сподобалось все!',
#  'Сиро в номері. Запах нового ремонту.',
#  'Почуття будівництва присутній.',
#  'знижки Genius- її не було, підозрюю персонал про цю програму не знає',
#  'Небезпечний для життя стелю в номері. Неприємно.',
#  'Гаряча вода з перервами. Ціна на травневі свята була досить висока.',
#  'У номері було сиро до такої міри, що навіть взуття була волога, коли її взуває )',
#  'В готелі зробили недавно ремонт. Пахне фарбою.',
#  'Відсутня рушник для підлоги у ванній, краю ліжка',
#  'Відмінний готель, в самому центрі Львова',
#  'Чи не попередили, що вночі закривають ворота і там потрібно знати код.',
#  'Але дуже велика вологість.',
#  'Вид з вікна.',
#  'мінус - немає сніданків']

# %%
import tokenize_uk

# %%
pos_sentences = []
for text in pos_texts:
    pos_sentences += tokenize_uk.tokenize_sents(text)

# %%
pos_sentences
# Out:
# ['Брудні і обшарпані стіни номеру Дуже жарко в номері Відсутність ліфту Слабий напору води Сейф який нам так і не відкрили, т . б . скористатися ним ми не мали змоги',
#  'Одну з ночей хтось постійно ходив по коридору і ми не могли нормально спати через дзвінкий стукіт підборів об плитку .',
#  'З Комаровим покриттям в коридорі було б комфортніше .',
#  'Меблі в номері вже трохи втомлені',
#  'Було б непогано мати чайник в номері, чай та каву, як це часто буває.',
#  'Запах в номері, якійсь був солодкий, напевно від ароматизатор.',
#  'шумоізоляція, та досить велика щілина внизу дверей на коридор, коли хтось ходить заважає.. невеликий поріг би виправив це!',
#  'звукоізоляція могла б бути і кращою .',
#  'Не зайвим був би косметичний ремонт номера.',
#  "Сніданок в ціні номеру міг бути більшим, до кав'ярні треба йти через вулицю.",
#  'Надзвичайно тонкі стіни в номерах - чути кожне слово',
#  'Сніданок: хотілося б шведський стіл, а не кілька страв на вибір.',
#  'Дивний душ у номері: важко регулювати температуру води, незручно стояти.',
#  'один маленький мінус, але нам це не завдало незручність - в душовій кабіні було не пілотне прилягання двері',
#  'Сам готель усередині нагадує гуртожиток чи хостел.',
#  'Душова кабіна не зачинається, відповідно вся підлога залита водою.',
#  "сантехніку (труби, стоки) необхідно перевірити та відремонтувати, оскільки в деяких місцях на стіні біля санвузли з'являються вологі плями .",
#  'Бажано розширити меню кафе.',
#  "начебто новий ремонт - а велика тріщина над дверима, двері в туалет заїдають, вибір сніданків великий, але на тост з яйцем Ашот чекав 15 хв (може тому перший раз в житті їв Ашот зварений круту) )) дуже незручні ліжка - матраци класні - а рама ліжка широка і дерев'яна - поки звикнеш, заробиш кілька синяків) ) )",
#  'Дуже круті сходи.',
#  'Складно знайти поруч місце для паркування.',
#  'Скупий сніданок.',
#  'Маленький телевізор.',
#  'В погану погоду навряд зручно виходити на сніданок у сусідню будівлю в кафе.',
#  'Дуже душно, номер з вікном на стелі, дотягнутись до вікна не можливо.',
#  'Запах цигарок в номері при поселенні.',
#  'Не дуже чисто.',
#  'Навіть було чуже волосся на білизні.',
#  'Зупиняюсь не перший раз в цьому готелі, але зараз дуже погано',
#  '- Дуже круті сходи між поверхами і відсутність ліфта . - У бронюванні було вказано, що сніданок включено у вартість, проте насправді за нього потрібно доплатити 75 грн .',
#  'Дуже скупе сніданком меню (при тому, що половини вказаного там, не виявилося у наявності). - Джуел погана шумоізоляція - будьте готовими чути усіх гостей, що піднімаються сходами, чи увімкнені будильники у сусідніх номерах.',
#  'Не було полиці в ванній кімнаті.',
#  'Цього дуже не вистачає дівчаткам 😁😉',
#  'Тонкі стіни, чути, що робить персонал .',
#  'Але це ок, не занадто заважало',
#  'Тонкі стіни, дуже чути сусідів, особливо шум з душу.',
#  'Двері у душ погано закриваються і трохи відтікає вода .',
#  'У ванній нема Молочки для зберігання мила, зубної щітки .',
#  'Але стіл у кімнаті з радістю сприйняв всі Самчики, а стакан з кімнати переїхав у ванну для зручності )',
#  'На першому поверсі неможливо спати через відсутність шумоізоляції .',
#  'Вночі було дуже чутно ВС розмови з коридору біля рецепції . несправний злив в унітазі.',
#  'Нема сніданків.',
#  'Душова кабінка щільно не закривається, тому після душу вся підлога мокра, можна послизнутися.',
#  'звукоізоляція просто жах, ще гіршої я не бачила!!! Посилили нас в номер прям біля рецепція (в 2-х метрах) так вранці було чутно всі розмови, всі заселення і виселення! Навіть шум кавової машини було чути наче як під вухом! Такі номера не мають право на життя і перекреслюють абсолютно всі плюси готелю!!! Більше не бронювати!',
#  'Так чисто, що аж око ріже 🙃!!!',
#  'Відсутність ліфту (в готелі 4 поверхи), для тих хто з авто немає парковки.',
#  "Єдиний мінус: коржик в туалеті був м'яко кажучи в поганому стані",
#  'Немає ресторану та сервісу обслуговування в кімнатах.',
#  'Тому за сніданком треба іти в кафе, ресторан.',
#  'Єдиний маленький мінус, який не зіпсував мій відпочинок - слабка шумоізоляція.',
#  'Чула весь діалог сусідів за стіною )',
#  'Готель не надає можливості поснідати.',
#  'Але вони працюють над цим)',
#  'Чув, що сусіди з інших поверхів скаржились на погану шумоізоляцію .',
#  'Думаю так воно і є, однак мені пощастило жити на останньому поверсі та, напевно, не було сусідів .',
#  'Крім годинникового бою з сусідньої веж ні чого не чув) хоча якусь поличку у ванній .',
#  'Треба поміняти праску .',
#  'Ну дуже нещасна . можна зіпсувати одяг.',
#  'Погана звукоізоляція між кімнатами, якщо попадуться шумні сусіди (як мені) – спати неможливо .',
#  'Пропоную роздавати гостям Белуші.',
#  'Трішки тонкі стіни, було чути розмови за дверима, але зовсім тихо - спати це не заважало.',
#  'З відчиненим вікном вранці не виспалися, адже в дворику під вікнами було трохи шумно.',
#  'Постійно замикалися двері у ванній кімнаті, тому доводилося їх просто прикривати, а не закривати.',
#  'Жахливо смерділо лаком чи новим ремонтом .',
#  'Вікно в стелі, яке неможливо відкрити, бо дуже високо .',
#  'Дихати нема чим .',
#  'В середині ночі була змушена відкрити двері в коридор, бо думала, що задихнувся . щілина між дверима і підлогою така велика, що коли ти лягає в ліжко, то з коридору б ‘ є холодне біле світло прямо в очі .',
#  'Жахлива видалася ніч!',
#  'На жаль, відсутня опція сніданку .',
#  "Але поблизу готелю розташовані декілька кав'ярень і ресторацій, це вирішує проблему.",
#  'Конкретно для мене це не була проблема, що нема сніданку, але якщо скеровувати інших, то це може бути пересторогою.',
#  'Мені було достатньо смачної кави у холі біля рецепції.',
#  'Великий попит на заселення у цей готель, тому, на жаль, мені не вдалося домовитися ні про ранній заїзд, ні про пізній виїзд.',
#  'Проте, якщо хтось буде планувати заздалегідь поїздку, то раджу врахувати всі деталі, і все ж обрати Блюм.',
#  'Єдиний мінус - це звукоізоляція .',
#  'Але нас з подругою це навіть повеселили: )',
#  'Малий по площі номер за таку вартість',
#  'Не раджу номер біля сходів.',
#  'Було шумно в першу ніч, пів ночі не спали.',
#  'Взагалі сильно чутно рух людей по сходах.',
#  "Немає зв'язку з адміністратором з номеру.",
#  'Кава - автомат не працював вранці, коли конче потрібна була кава) І ще - поставте москітну сітки на вікна, будь Ласточка.',
#  "Поганий зв'язок в номерах (це не відноситься до Wi-Fi), немає сніданків",
#  'намагалась щось знайти, але нічого не знайшла) все дуже круто!',
#  'Звукоізоляція дійсно погана.',
#  'Була літня вода.(не зверталася до персоналу, бо була лише на одну добу і немала часу).',
#  'Не сподобалася якість рушників.',
#  'шумно зранку. погана звукоізоляція.',
#  'Дуже тонкі стіни, чути як хтось відкриває воду у сусідньому номері.',
#  'Душова кімната брудна',
#  'Протікає душова кабіна.',
#  'Варто вивісити вказівники для полегшення пошуку готелю',
#  'Напевно, вже час на певний ремонт',
#  'Вночі (12 год) була тільки холодна вода в душі, але в цю спеку це був, скоріше, плюс :-))',
#  'Відсутня парковка.',
#  'Такого не виявлено',
#  'Жила на першому поверсі і практично 3 дні було відсутнє опалення, а на дворі було досить холодно',
#  'Не працював ресторан, тому на жаль не було сніданках',
#  'Гарний готель, все чисто, персонал дуже привітний!  Перебуванням залишились задоволені!',
#  'Занадто гучні гості та  жодної реакції персоналу на це.',
#  'Звукоізоляція відсутня',
#  'Так як це центральна частина міста - проблема з парковкою авто',
#  'В туалеті мало світла',
#  'Відсутність власної парковки.',
#  'Прохолодно',
#  'Звукоізоляція.',
#  'Все сподобалось',
#  'Відсутні сніданки',
#  "Хтось п'яний майже всю ніч голосив польською😐",
#  'Світло з під дверей... 😀',
#  'Шумоізоляція',
#  'Вхід на поверхи тільки сходами',
#  'Мансардний поверх.',
#  'необхідно додати припинений Коврига на підлогу в данный кімнаті',
#  'Звукоізоляція.',
#  'У приміщенні відчувається запах сирості, особливо на першому поверсі',
#  'Неможливість потрапити в номер після 2:00 у звязку з зачиненою брамою.',
#  'Ще залишився "запах ремонту"',
#  'Абсолютно ніде припаркувати машину .',
#  'Вночі знайшли вільне місце біля готелю і перерветься автомобіль, а на ранок ззаду отримали подряпину на бампері . враховуйте це, вибираючи готель .',
#  'Очікування - реальність не співпали абсолютно .',
#  'Прочитала багато позитивних відгуків і дуже розладналися, коли поселилася туди .',
#  'У коридорах є відчуття, ніби ти потрапив в гуртожиток . шумоізоляція немає .',
#  'Чути як люди йдуть по сходах, відкривають двері, розмовляють, найменший шум буде чутно у вас в номері . прокидалася цілу ніч від шуму .',
#  'Телевізор - не працювали канали .',
#  'Дуже смерділо з приймалень, саме каналізацією .',
#  'Запах від туди йшов в кімнату .',
#  'І на завершення, на жаль готель розчарував.',
#  'Як зазвичай буває, хто-то додумався голосно розмовляти рано вранці в коридорі, а ми знаємо, що звукоізоляція дверей рідко буває хорошою)',
#  'Є кілька, ймовірно, не важливих, але які впливають на відчуття повного комфорту, моментів.',
#  'Звукоізоляцію хотілося б краще.',
#  'Для готелю такого цінового рівня, використовувати в душовій кабіні правило для притвору дверцята вважаю неприпустимим ...',
#  'Естетика пропадає, враження меркнуть, підлогу залитий водою ...',
#  'Адміністрація, це просто НЕОБХІДНО виправити.',
#  'Ще раз про сніданки.',
#  'Так, смачно, але меню дуже просте і убоге.',
#  'Для вашого рівня необхідний значно більший вибір в меню.',
#  'Відсутність парковки, але місце до вечора можна знайти.',
#  'У нашому номері не щільно закривалася дверцята душа.',
#  'Погана шумоізоляція.',
#  'В цілому залишилися дуже задоволені, рекомендую!',
#  'Сніданок на вибір по меню, але не всі позиції є в наявності.',
#  'Готель виглядає якось обшарпані і убого (пора робити ремонт), фіранки зірвані з кріплень і нормально закрити їх неможливо.',
#  'Замок на вхідних дверях в номер трохи заїдає.',
#  'V menu Vapiano, Show Sandwich Budget 2 a ya Postal Tiki 1: (',
#  'Номер маленький, в тому числі ванна .',
#  'Для однієї людини більш - менш, для двох - напружено.',
#  'Не було в наявності лопатки для взуття)',
#  'Батареї не були включені .',
#  'Але питання обігріву легко вирішувалося кондиціонер',
#  'Погана звукоізоляція.',
#  'Вночі чутно, як хропуть сусіди і ходять до вбиральні, дуже не комфортно через це.',
#  'У ванній був специфічний запах, і підшукала душова кабіна, сходинки високі, складно буде підніматися якщо ви з багажем .',
#  'На сніданку якщо багато людей потрібно чекати, так як сніданок не шведський стіл, а по меню .',
#  'Але це дрібниці, в цілому враження від готелю позитивне!',
#  'З мінусів: дуже дешева сантехніка в санвузлі.',
#  'На сніданок можна вибрати тільки одне блюдо, нам було незручно.',
#  'Номер потребує ремонту (штукатурка відлітає, дзеркало у ванній бите, слив в унітазі заїдає).',
#  'І дуже погана звукоізоляція між номерами.',
#  'Чути як сусіди миються і ходять в туалет.',
#  'Були у відрядженні, заселилися пізно, оплатили вранці, але адміністратори до виїзду так і не змогли правильно оформити необхідні документи!',
#  'Відсутня ліфт, не зручно тягнути валізи на 4 ет Номер в мансардному поверсі, скошена стеля & quota; з & #39; їдає & quota; площа З гостьової косметики: мило і шампунь .',
#  'Чи не поповнюється.',
#  'Якість взагалі не соответствует ціною! Дуже велика сутність, чистота на 2 .',
#  'Ремонт Решевський . неврегульована температура води в душі: то окріп, то Холодная (по всій видимості, якщо сусіди включили воду - чекайте сюрприз) Сніданок взагалі окрема історія - вівсяну кашу несли годину!!',
#  'Зручне місце розташування, до центру 10 хвилин, а так поруч величезна кількість кафе і ресторанів, сам готель новий, нові меблі, в номері тихо, чисто і затишно, є кондиціонер, в номері штори щільні, до літака спокійно спала і відмінно відпочила) персонал говорить на всіх мовах світу, допомогли валізу підняти в номер) рекомендую)',
#  'Чи не закривалася дверцята душа і вода лилася на підлогу, текло з змішувача.',
#  'Звернулася на ресепшн - обіцяли все виправити.',
#  'У номері на двох було одне ковдру-потрібно просити друге на ресепшн.',
#  'Двері в душову не прилягає щільно, тому доводилося трохи акуратно митися щоб не забризкали підлогу.',
#  'єдине-ліжко не зручна дошкою для вставання',
#  'Невеликий вибір сніданків . сніданки порційні, а не & quota; шведський стіл & quota ;.',
#  'Була погана звукоізоляція.',
#  'Номер на першому поверсі і чути все.',
#  'І як розмовляють мешканці на ресепшені і як спускаються сходами.',
#  'Сходи і поверхи дуже нагадують шкільні коридори.',
#  'Номер не затишний - стіни пофарбовані в блакитний і фіолетовий з геометричними фігурами.',
#  'Склалося враження, що ліжко поставили в кабінеті геометрії.',
#  'Умивальник дуже маленький і душова кабінка протікає.',
#  'Двері в душі не закривається . налив води на підлогу ..... після зайшла дочка в туалет і послизнулася (упала), в результаті сльози, соплі .... телевізор занадто маленький, канали - & quota; фу & quota;, дивитися нема чого (але ми не телевізор приїхали дивитися до Львова).',
#  'Коротше все це дрібниці, в цілому готель нормальний.',
#  'У ванній кімнаті не було полички, незручно Гель та шматочок мила були видані один раз за 5 днів Чому то було дуже волого в кімнаті Сніданок хотілося б доповнити: якщо береш сік, то кава вже не належить ?!',
#  'Трохи заплуталися з пошуком готелю, так-як він у дворі.',
#  'У номері економ на 2-му поверсі вікно в стелі, через дощ не могли відкрити вікно і вночі було дуже душно, в душі погано працює злив, трохи тіснувато, але в цілому нормально, авто практично ніде припаркувати, дуже не зручний матрац',
#  'Неможливо відпочити через чутності.',
#  'І всередині і зовні готелю',
#  'шкода, що у дворик готелю вранці курить персонал. відкрити вікно неможливо, тому що дим від сигарет повністю в кімнаті. при збирання не оновлювали мило, шампунь.',
#  'Немає такого',
#  'Пара мінусів була несуттєвих: відсутній заявлений праска і ліжко незручною конструкції з високими виступами по периметру.',
#  'Матрац поганий.',
#  'Для ліжка з бортиком просто дуже незручний - низький і дуже м&#39;який.',
#  'Готель у приватному будинку.',
#  'Вулиця вузька, складно паркуватися.',
#  'Занадто слизька плитка в туалеті.',
#  'відсутність парковки і слабкий напір води, ліжка з виступаючим дерев & #39; яним бильце - дуже не зручно . відсутність додаткових спальних приладдя (ковдру), вночі було холодно.',
#  'У мене був нюанс в туалетній кімнаті .',
#  'Там відверто протікала каналізаційна труба .',
#  'Тому наступает « рідина » і був соответствующих запах .',
#  'Швидко Дубровін на моє прохання, проте до ранку було те ж саме .',
#  'Це питання не персоналу, а ремонту.',
#  'У всьому можна знайти мінуси, якщо придивитися ...',
#  'Зрозуміло - це не 5 *.',
#  'Для свого рівня - все нормально.',
#  'Просіть документи по відрядження в перший же день .',
#  'А - то може вийти як у мене .',
#  'Мені не встигли підготувати вчасно документи на моє відрядженні, пояснили тим, що в принтері закінчився картридж (а я виїжджала в вихідний день) не було кому його поміняти .',
#  'Загалом документи по приїзду додому я отримала на Московскую пошту на 5 й день .',
#  'Сподіваюся що оригінали дійдуть швидко .',
#  'Не знаю як у кого, а у нас в компанії бухгалтерія до цього ставитися дуже строго .',
#  'Тому в цьому плані готелю ставлю жирний мінус.',
#  'Номер розташовувався на 4 поверсі (останній), було дурнувато, навіть при відкритому вікні .',
#  'Доводилося користуватися кондиціонером .',
#  'Можливо, на нижніх поверхах такої проблеми не існує.',
#  'Звукоізоляція трохи кульгає.',
#  'Дверцята в душовій дуже нещільно прилягає, тому, як би не старався митися акуратно, вода у великій кількості все одно виявляється на підлозі у ванній кімнаті .',
#  'На рушник висів чийсь довгий чорний волосся .',
#  'Не дуже приємно було його виявити . сутність дуже хороша . прям ду-у-уже все чутно.',
#  'Сніданок у вартість номера Більше напору води в душі',
#  'Ліжко в номері з дерев & #39; яною рамкою по периметру . матрац просідає нижче рівня каркаса і весь час чимось вдаряється (то ногою, то ліктем).',
#  'погана шумоізоляція, особливо чутно, коли ходять на підборах по коридору вночі: D',
#  'На момент проживання не було сніданків, ресторан був на етапі закінчення ремонту або будівництва.',
#  'Обіцяли найближчим часом (після закінчення ремонту ресторану) надати сніданки.',
#  'Звукоізоляція викликала у мене сумніви - були дуже чутні всі дії і розмови в коридорі, але ніч пройшла спокійно.',
#  'Єдиний значущий для нас мінус - відсутність ліфта, довелося тягнути велику сумку на 3й поверх по сходах.',
#  'Шкода немає чайника.',
#  'Шкода була їдальня на ремонті, але не впевнений була потреба, Пузата хата 2 хвилини (за кутом), провулок кривої липи з 10 закладами в 4 хвилинах .',
#  'І ще кав & #39; ярні.',
#  'Ні паркування.',
#  'Машину подряпали на вулиці, поруч з входом в готель.',
#  'Поїхали на день раніше, гроші повертали кілька днів.',
#  'Все було чудово.',
#  'звукоізоляція в готелі так собі, були чутні розмови на вулиці (мій номер був на 1-му поверсі) і в коридорі, але їх було небагато, і в цілому мене це не дуже турбувало .',
#  'Кому принципова повна тиша, запасіться Белуші.',
#  'У готелю немає своєї парковки як заявлено.',
#  'Машину можна припаркувати в дворі біля тротуару і на тротуарі якщо пощастить.',
#  'Мешканці не задоволені і категорично проти.',
#  'Коли ми припаркували машину на тротуарі, жінка зробила нам зауваження і сказала прибрати її.',
#  'Погана шумоізоляція .',
#  'Наш номер розташовувався поруч з ресепшені .',
#  'Чули все і всіх .',
#  'З дванадцятої ночі і до третьої ранку п & #39; яні польські туристи голосно кричали, співали пісні під вікном і в самому готелі .',
#  'Незрозуміло, чому не викликали поліцію за порушення громадського порядку .',
#  'Цей інцидент змазав все враження від поїздки.',
#  'шумоізоляція відсутня геть! Було багато поляків, які 24 години на добу поводяться як свині! соответственно все це чути і спати вночі не можливо! Я тепер їх ненавиджу!!!!',
#  'Двері у ванній відки / Закр насилу, заїдає замок.',
#  'Шумоізоляція, чутно все переміщення і розмови з сусідніх номерів і коридору, але це проблема більшості готелів',
#  'підшукала вода в унітазі',
#  'Шумоізоляція.',
#  'Коли сусіди в 5 ранку йдуть в туалет, приймають душ, вмиваються, сушать волосся феном, і з ще там двоє, і це на хвилин 40.',
#  'І ви не спите, тому що чутно все так ніби це відбувається у вас в кімнаті.',
#  'Це жахливо.',
#  'І ще.',
#  'Коли приймаєте душ, вода знизу дверцята буде потрапляти на підлогу.',
#  'І як би ви не старалися, буде мокро.',
#  'звукоізоляція відсутня .',
#  'Чути, як по сходах в коридорі ходять .',
#  'Як включають воду сусіди .',
#  'Раковина для вмивання маленька, вмиватися неможливо - вода розливається на підлогу .',
#  'Немає ущільнювачі між дверима душової кабіни і стіною - вода ллється на підлогу і в кімнаті в результаті на стіні сире пляму . парковки немає, що в центрі міста незручно .',
#  'WiFi дохлий - в будь - якому кафе - ресторані літає.',
#  'Сподобалось все !!! Це тільки побажання !!!! Вішалка для курток, поличка над раковиною у ванній і трохи більше світла біля дзеркала ..',
#  'Звукоізоляція.',
#  'Якби по готелю бродили галасливі п&#39;яні люди, було б сумно.',
#  'Але постояльці відповідали готелю.',
#  'Все дуже культурно.',
#  'Взагалі відсутня звукоізоляція! Чути навіть шепіт з сусіднього номера .',
#  'Якщо поруч живуть діти, можна попрощатися зі сном .',
#  'При цьому прибирання починається щодня з 9 ранку, і перше, що включають - пилосос! З урахуванням чутності, відчуття, що пилосос прямо біля вуха .',
#  'Навіть за законом у вихідні можна шуміти раніше 10 ранку .',
#  'Чому ж треба щодня катувати ваших постояльців ранковим пилососом?! Все - таки готель для відпочинку і тасують до ранку молоді',
#  'Трохи протікала дверцята душа, що не дуже сильний напір води (жили на останньому 4 поверсі), але це не критично.',
#  'Співвідношення розміщення 4 го поверху та кавоварки (підніматися з гарячим напоєм незручно, та й на виході в холод похапцем пити).',
#  'За водою з кулер доводилося спускатися поверхом нижче . сутність сильна через тонких стін (коли по - сусідству чутно все що відбувається у ванній кімнаті).',
#  'Не зовсім сучасний стиль і ремонт .',
#  'Вікна кімнати виходять у внутрішній двір іншого будинку .',
#  'Місце для однієї ночівлі більше, ніж насолоди містом і рефлексом.',
#  'Ціна відповідає якості.',
#  'Хороший готель.',
#  'Висока сутність всього, що відбувається навколо, тонкі вхідні двері .',
#  'Бракує халатів для ванної .',
#  'Наш номер був маленький (заходиш в номер і впораєшся в ліжко), вікно було маленьке в стелі .',
#  'У наших друзів за ту ж ціну був номер набагато просторіше.',
#  'Верхнє, оглядове вікно постійно запитувало і з нього вночі капав конденсат (вода) на ковдру .',
#  'Чи не справлялася витяжка у ванній кімнаті!',
#  'Немає опції вибору проживання зі сніданком - на сніданок потрібно йти в ближайшее кафе, яких благо багато в крокової доступності.',
#  'сутність Стан меблів (у ванній була зламана поличка) Вцілому мало місця для розташування косметичних засобів У батареї працював тільки один відсік (грілася кондиціонером )',
#  'У кімнаті на першому поверсі досить хороша сутність всього, що происходит у дворі .',
#  'І не дуже комфортно, що кондиціонер прямо над вікном (( ((',
#  'бронювали стандарт підвищеної комфортності, по приїзду хотіли поселити в звичайний стандарт (скошена дах і низькі стелі) стверджували, що обидва види номерів стандарт, але при бронюванні на Букін це були номери різної категорії і з різниці в ціні 200 грн за ніч',
#  'Чи не поповнювали в номері шампунь, поки не попросиш .',
#  'Упаковка шампуню маленька .',
#  'Не було гелю для душу (було холодно в номері, Конде не допомагав.',
#  'Тонкі стіни, відповідно дуже чутно все що відбувається в сусідських номерах',
#  'отсутствие вікно - не пам & #39; ятаю, що б про це говорили при booking .',
#  'Світло в загальному холі через дверну щілину висвітлював кімнату - довелося змушувати валізами - маски нічний не було, інакше спати неможливо ....',
#  '-',
#  'Ні.',
#  'Одні позитивні емоції.',
#  'Ванна простувати в порівнянні з кімнатою, але улучшить це можна тільки таким ремонтом.',
#  'Ванна кімната схожа на лікарняну.',
#  'Під вхідними дверима немає порогу, чутно як хто спускається по сходах, що говорять і взагалі шумоізоляції немає.',
#  'Чути як купаються сусіди)) Телевізор міг би бути і більше)',
#  'Все настільки було добре, що я не знайшов ніяких недоліків',
#  'Не вистачало світла в номері, душова через двери протікала трохи, номери в мансарді не зовсім підходять людям з ростом вище 1,80 доводилося нагинати щоб відкрити вікно',
#  'Буде ще краще коли в об&#39;єкті розміщення з&#39;явиться своє місце харчування і сніданки, що було б супер для ранніх виїздів і пізніх так само :)',
#  'незручні краю ліжка: вузькі чотиригранні деревянные борту, оздоблюють матрац виходять за його розмір і неприємно тиснуть при спробі лягти або піднятися.',
#  'Єдина рекомендація з мого боку для готелю - це наявність харчування (сніданок)',
#  'Чи не сподобалося тільки пару речей, але претензії більше до проектувальників .',
#  'Споруда нова, відповідно, як і в багатьох нових будинках, сутність за стінами дуже хороша .',
#  'Чули і душ і розмови .',
#  'І з душем щось: начебто милуєшся з зачиненими дверима, а вода все одно зовні на підлозі .',
#  'Потім в стіну вбирається і патьоки .',
#  'Я бігав ганчірочку шукала, щоб витерти.',
#  'Матрац був занадто м&#39;яким, хворіли спини вже на третій день.',
#  'І не закривалася дверцята душа.',
#  'Мінусів просто немає',
#  'Поставити б їм в холі біля ресепшені і автомата з кавою ще пару канапок!) ) )',
#  'Відсутність парковки, маленький сан вузол, дешева сантехніка, галасливий зовнішній блок кондиціонера.',
#  'Такого не виявлено',
#  'Тонкі стіни) коли в сусідньому номері приймали душ було чутно ... точно так само були чутні розмови.',
#  'мінусів немає',
#  'Вид з четвертого поверху на будівлі на даху і ходіння там якихось людей ...',
#  'Немає розпізнавальних знаків готелі, немає вивіски, важко в перший раз знайти вхід.',
#  'Мало днів відпочинку :)',
#  'Хороший новий готель, але: Кондиціонер прямо в обличчя дме.',
#  'У деяких номерах на фото це видно.',
#  'Потрібні штори! Щільні, на ніч! Ну новий же готель, невже не можна подивитися, що і як у хороших готелів, і зробити так само? !! Світло в вікно в 6 ранку! У ванній 1 лампочка! Чи не поголитися нормально.',
#  'Взяв номер з двома ліжками - ліжка дуже вузькі! Навіть мені, що не широкому, там було вузько!',
#  'З засобів особистої гігієни: зубна щітка + паста, маленька баночка шампуню, який слабо піниться і маленьке мило.',
#  'Т.ч. шампунь і гель для душу краще брати з собою. (3 рушники на людину 👍)',
#  'Сніданок з 8 : 30 (а й цю проблему вирішили під нас і накривали стіл до 8 : 00) У номері замість холодильника, морозильник . (У нас все успішно заморозило )',
#  'За столом у номері незручно працювати.',
#  'Стілець під столом поміщається, а ось ноги вже немає.',
#  'І душ не закривається повністю, так що після його використання - мокра підлога.',
#  'На вікнах немає Москвітіної сітки (вікно було відкрито до нас і налетіло купа комарів).',
#  'Нема рушники для підлоги у ванній .',
#  'У ванній на дзеркалі немає полички .',
#  'У номері на першому поверсі відчувається підвищена вологість .',
#  'Не дуже гарна шумоізоляція.',
#  'У кулуарах на поверхах не було підігріву води.',
#  'У номері на першому поверсі дуже сиро, речі просочилися вологою . шумом ізоляції нуль, чутно все .',
#  'Чути як ходять, розмовляють, тягають речі і тд.',
#  'немає можливості набрати окропу що б хоча б чайку заварити',
#  'У номері на першому поверсі дуже велика вологість, швидше за все через відсутність прямих сонячних променів, але зробили знижку на проживання так як кондиціонер не справлявся з даної проблемою.',
#  'Ми були навесні і в номері було дуже волого .',
#  'Одна стіна була мокра .',
#  'Ще при заїзді нам назвали ціну вище, ніж була вказана при броні .',
#  'Після обязательств номер нам здали за ціною вказаної з booking',
#  'Ні вивіски, навіть таксист не відразу знайшов вуличку, прохід до готелю через темну арку .',
#  'Дуже чутно всіх сусідів.',
#  'Маленький номер, постійно вдаряється об усе кути.',
#  'Краї ліжка дуже незручні, синці забезпечені всім',
#  'У душовій нещільно закриваються двері.',
#  'Як наслідок, вода на підлозі',
#  'все прорвалось',
#  'Шумоізоляція, галасливий душ, маленький натиск, коли приймають душ в сусідньому номері ви більше не спите)',
#  'Не вистачило гелю і шампуню, просили ще.',
#  'Пізніше додали)',
#  'Ні.',
#  'Потягати сантехніка, дверцята в душ не закривається, іржаві полички в душі.',
#  'своєрідний внутрішня планування готелю',
#  'Немає ліфта, при бронюванні я цього не знала, і довелося тягнути важкий чемодан на 2 поверх',
#  'Сніданки проходять в кафе поряд і персонал явно не справляється.',
#  'Ти змушений чекати поки приймуть замовлення, потім ще довго поки його винесуть.',
#  'При бронюванні 2 + 1, сніданок для дитини виявився платним',
#  'важко знайти',
#  'Готель свіжий, є запахи вогкості, кафе і сніданок не дуже',
#  'Все відмінно',
#  'Ні паркування, і припаркувати авто немає шансів',
#  'Не дуже зручні меблі.',
#  'Маленький вибір сніданків',
#  'Дверцята душової кабінки прилягає нещільно, після душу в санвузлі калюжа на підлозі, не завадив би килимок.',
#  'Дверцята в душі не предлагает повністю, у зв & #39; язку з цим вода на підлозі.',
#  'Вид з вікна так собі, але це не сильно важливо',
#  'Все сподобалося',
#  'Крихітний номер з дуже низькою стелею (скошений від 2 м до 1,5 м, і це в номері)',
#  'Постільна білизна була не чисте.',
#  'Наволочки були в волоссі і брудні.',
#  'Шумоізоляція не дуже.',
#  'Відсутність ліфта і дуже круті сходи.',
#  'скромний сніданок',
#  'Вода з душа потрапляє на підлогу у ванній',
#  'Ні паркування.',
#  'Все нормально, але сутність в номері підвищена',
#  'сутність сусідів дуже сильна',
#  'Сніданок смачний, але слабенький за обсягом.',
#  'Незручності в ванній кімнаті.',
#  'Ніде розмістити свої особисті речі.',
#  'Скрізь витікає вода.',
#  'Круті сходи.',
#  'Абсолютно відсутня шумоізоляція номерів',
#  'Гучний внутрішній дворик',
#  'Дуже погана шумоізоляція, чутно кожен крок і звук в коридорі ... цей мінус затьмарює всі плюси',
#  'обслуживание . із через раннього виїзду залишився без сніданку',
#  'Не сподобався сніданок',
#  'Холодно, запах в душі, звукоізоляція',
#  'Дуже тонкі стіни, чути сусідів дуже, як ніби в вашому номері кажуть, слова все розбірливо зрозумілі',
#  'Світло з коридору світить в кімнату через щілину між підлогою і дверима.',
#  'Заважає спати.',
#  'звукоізоляція на 0!!!! все чути! спав в біржах ....',
#  'Вибрав найдешевший номер, але в ньому не було вікна',
#  'У ванній трохи провисіла двері і підшукала вода на підлогу .',
#  'Телевізор трохи вайлуватий',
#  'відсутня звукоізоляція',
#  'Шумоізоляції нуль, чутно навіть як включається вода в сусідньому номері.',
#  'Немає сніданків.',
#  'Тонкі стіни, не вистачало предметів гігієни',
#  'погана звукоізоляція',
#  'Ні паркування.',
#  'Номери маленькі.',
#  'Ліжка поодинокі не зручно.',
#  'звукоізоляцію',
#  'хотілося б кращу звукоізоляцію',
#  'Недостатня шумоізоляція))',
#  'Дуже тонкі стіни, чути сусідів, були помічені таргани в номері',
#  'Спека! Потрібно автоматизувати опалення.',
#  'Немає такого',
#  'Шумоізоляції зовсім немає!',
#  'відсутність звукоізоляції',
#  'Приймати більш радикальні заходи до гостей, які вночі поводяться неадекватно.',
#  'Взимку дуже холодно в сан . зле',
#  'Дуже тонкі стіни, чути сусідів',
#  'Слабка шумоізоляція.',
#  'Номер на першому поверсі, немає звукоізоляції, немає снеків, якщо приїжджаєш пізно ввечері, то перекусити не зможеш.',
#  'Немає претензій.',
#  'Дуже тонке ковдру.',
#  'У номері було досить холодно',
#  'погана звукоізоляція',
#  'Якість ремонту, погана шумоізоляція',
#  'Все було добре',
#  'немає сніданків',
#  'Парковка могла б бити краще ...',
#  'Хотілося, щоб б був все таки сніданок готелі',
#  'Ліжко: матрац трохи менше, ніж ліжко',
#  'Відсутність у ванній кімнаті полички для туалетного приладдя',
#  'Напір води в душі слабенький (',
#  'Сподобалось все',
#  'Не знаю.',
#  'Розмір подушки виявився для мене великий',
#  'Сподобалось все.',
#  'Все добре',
#  'Дуже шумно.',
#  'Чути шум мотора.',
#  'Дуже тонкі стіни і висока сутність з інших кімнат.',
#  'Мінусів немає)))))',
#  'Єдине що було б не зайвим зробити безшумні двері, чути що відбувається в коридорі',
#  'У дощовий дні хотілося снідати в готелі.',
#  'Але ресторану немає.',
#  'відсутність сніданку',
#  'Погано ловив wi-fi в номері (потрібно гуляти, а не сидіти в номері;))',
#  'Відсутність ліфта, паркування, завищена вартість, слабка звукоізоляція',
#  'Був неприємний запах у ванній.',
#  'Сподобалось все!',
#  'Сиро в номері.',
#  'Запах нового ремонту.',
#  'Почуття будівництва присутній.',
#  'знижки Genius- її не було, підозрюю персонал про цю програму не знає',
#  'Небезпечний для життя стелю в номері.',
#  'Неприємно.',
#  'Гаряча вода з перервами.',
#  'Ціна на травневі свята була досить висока.',
#  'У номері було сиро до такої міри, що навіть взуття була волога, коли її взуває )',
#  'В готелі зробили недавно ремонт.',
#  'Пахне фарбою.',
#  'Відсутня рушник для підлоги у ванній, краю ліжка',
#  'Відмінний готель, в самому центрі Львова',
#  'Чи не попередили, що вночі закривають ворота і там потрібно знати код.',
#  'Але дуже велика вологість.',
#  'Вид з вікна.',
#  'мінус - немає сніданків']

# %%
pos_bigrams = []
for sent in pos_sentences:
    pos_bigrams += neg_ngram_mng.find_important_bigrams(sent)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words
# empty vocabulary; perhaps the documents only contain stop words

# %%
len(pos_bigrams)
# Out:
# 184

# %%
pos_bigrams2 = [bigram[0] for bigram in pos_bigrams if ]

# %%
pos_bigrams2 = []
for bigram in pos_bigrams:
    words = tokenize_uk.tokenize_words(bigram[0])
    should_continue = False
    for word in words:
        if word not in word2vec:
            should_continue = True
            break
        if should_continue:
            continue
        pos_bigrams2.append(bigram[0])

# %%
pos_bigrams2
# Out:
# ['персонал привітний',
#  'персонал привітний',
#  'номері тепло',
#  'номері тепло',
#  'ліжко зручне',
#  'ліжко зручне',
#  'чудове розташування',
#  'чудове розташування',
#  'розташування співвідношення',
#  'розташування співвідношення',
#  'сучасний інтер',
#  'сучасний інтер',
#  'співвідношення ціни',
#  'співвідношення ціни',
#  'ціни якості',
#  'ціни якості',
#  'інтер єр',
#  'інтер єр',
#  'шампунь мило',
#  'шампунь мило',
#  'кондиціонер холодильник',
#  'кондиціонер холодильник',
#  'обов язково',
#  'обов язково',
#  'практично центрі',
#  'практично центрі',
#  'хороший готель',
#  'хороший готель',
#  'затишне місце',
#  'затишне місце',
#  'гарний дизайн',
#  'гарний дизайн',
#  'персонал чистота',
#  'персонал чистота',
#  'привітний персонал',
#  'привітний персонал',
#  'розташування привітний',
#  'розташування привітний',
#  'чудове розташування',
#  'чудове розташування',
#  'дизайн готелю',
#  'дизайн готелю',
#  'затишний готель',
#  'затишний готель',
#  'тихе місце',
#  'тихе місце',
#  'відмінне розташування',
#  'відмінне розташування',
#  'розташування готелю',
#  'розташування готелю',
#  'центра міста',
#  'центра міста',
#  'привітний персонал',
#  'привітний персонал',
#  'номері чисто',
#  'номері чисто',
#  'приємно здивовані',
#  'приємно здивовані',
#  'номері тихо',
#  'номері тихо',
#  'центр міста',
#  'центр міста',
#  'тихо затишно',
#  'тихо затишно',
#  'зручне розташування',
#  'зручне розташування',
#  'розташування готелю',
#  'розташування готелю',
#  'смачні сніданки',
#  'смачні сніданки',
#  'чудовий персонал',
#  'чудовий персонал',
#  'номер повністю',
#  'номер повністю',
#  'центрі міста',
#  'центрі міста',
#  'знаходиться центрі',
#  'знаходиться центрі',
#  'дівчата рецепції',
#  'дівчата рецепції',
#  'кожному поверсі',
#  'кожному поверсі',
#  'приємний персонал',
#  'приємний персонал',
#  'ввічливий приємний',
#  'ввічливий приємний',
#  'центрі міста',
#  'центрі міста',
#  'цікавий інтер',
#  'цікавий інтер',
#  'інтер єр',
#  'інтер єр',
#  'кулер водою',
#  'кулер водою',
#  'кожному поверсі',
#  'кожному поверсі',
#  'гарне розташування',
#  'гарне розташування',
#  'міста привітний',
#  'міста привітний',
#  'привітний персонал',
#  'привітний персонал',
#  'чудове розташування',
#  'чудове розташування',
#  'центрі міста',
#  'центрі міста',
#  'чисто необхідне',
#  'чисто необхідне',
#  'зручне розташування',
#  'зручне розташування',
#  'номері чисто',
#  'номері чисто',
#  'розташування номері',
#  'розташування номері',
#  'зубна щітка',
#  'зубна щітка',
#  'шампунь мило',
#  'шампунь мило',
#  'сніданок смачний',
#  'сніданок смачний',
#  'приємний персонал',
#  'приємний персонал',
#  'кава чай',
#  'кава чай',
#  'гарний чистий',
#  'гарний чистий',
#  'чистий номер',
#  'чистий номер',
#  'міняли рушники',
#  'міняли рушники',
#  'рушники постіль',
#  'рушники постіль',
#  'вода цілодобово',
#  'вода цілодобово',
#  'розташування супер',
#  'розташування супер',
#  'персонал привітний',
#  'персонал привітний',
#  'відмінне розташування',
#  'відмінне розташування',
#  'чисто комфортно',
#  'чисто комфортно',
#  'номерах чисто',
#  'номерах чисто',
#  'сучасний ремонт',
#  'сучасний ремонт',
#  'готелю центрі',
#  'готелю центрі',
#  'розташування готелю',
#  'розташування готелю',
#  'центрі львова',
#  'телевізор кондиціонер',
#  'телевізор кондиціонер',
#  'тихе місце',
#  'тихе місце',
#  'хороше розташування',
#  'хороше розташування',
#  'персонал привітний',
#  'персонал привітний',
#  'кава чай',
#  'кава чай',
#  'сподобалося чисто',
#  'сподобалося чисто',
#  'номері чисто',
#  'номері чисто',
#  'центрі міста',
#  'центрі міста',
#  'розташування готелю',
#  'розташування готелю',
#  'готелю зручне',
#  'готелю зручне',
#  'розташування готелю',
#  'розташування готелю',
#  'ввічливий уважний',
#  'ввічливий уважний',
#  'повністю відповідають',
#  'повністю відповідають',
#  'номері необхідне',
#  'номері необхідне',
#  'чисто охайно',
#  'чисто охайно',
#  'гарний затишний',
#  'гарний затишний',
#  'затишний готель',
#  'затишний готель',
#  'готель центрі',
#  'готель центрі',
#  'центрі львова',
#  'персонал привітний',
#  'персонал привітний',
#  'своїм друзям',
#  'своїм друзям',
#  'обов язково',
#  'обов язково',
#  'персонал чисто',
#  'персонал чисто',
#  'привабливий персонал',
#  'привабливий персонал',
#  'чисто тепло',
#  'чисто тепло',
#  'позитивні враження',
#  'позитивні враження',
#  'чисто свіжий',
#  'чисто свіжий',
#  'номери чисто',
#  'номери чисто',
#  'свіжий ремонт',
#  'свіжий ремонт',
#  'центр міста',
#  'центр міста',
#  'яке ліжко',
#  'яке ліжко',
#  'зубні щітки',
#  'зубні щітки',
#  'готелю привітний',
#  'готелю привітний',
#  'привітний персонал',
#  'привітний персонал',
#  'всі побажання',
#  'всі побажання',
#  'плюс готелю',
#  'плюс готелю',
#  'зручне ліжко',
#  'зручне ліжко',
#  'центрі міста',
#  'центрі міста',
#  'знаходиться центрі',
#  'знаходиться центрі',
#  'інтер єр',
#  'інтер єр',
#  'телевізор кондиціонер',
#  'телевізор кондиціонер',
#  'розташування готель',
#  'розташування готель',
#  'зубні щітки',
#  'зубні щітки',
#  'гарний дизайн',
#  'гарний дизайн',
#  'привітний персонал',
#  'привітний персонал',
#  'персонал люб',
#  'персонал люб',
#  'залишити речі',
#  'залишити речі',
#  'кава чай',
#  'кава чай',
#  'персонал привітний',
#  'персонал привітний',
#  'кава чай',
#  'кава чай',
#  'ввічливий персонал',
#  'ввічливий персонал',
#  'тихо спокійно',
#  'тихо спокійно',
#  'наступного разу',
#  'наступного разу',
#  'тихий дворик',
#  'тихий дворик',
#  'відмінне розташування',
#  'відмінне розташування',
#  'гарний інтер',
#  'гарний інтер',
#  'персонал гарний',
#  'персонал гарний',
#  'розташування тихий',
#  'розташування тихий',
#  'чудовий персонал',
#  'чудовий персонал',
#  'інтер єр',
#  'інтер єр',
#  'зручне розташування',
#  'зручне розташування',
#  'оперного театру',
#  'оперного театру',
#  'розташування готелю',
#  'розташування готелю',
#  'знаходиться центрі',
#  'знаходиться центрі',
#  'шуму вулиці',
#  'шуму вулиці',
#  'внутрішній дворик',
#  'внутрішній дворик',
#  'привітний персонал',
#  'привітний персонал',
#  'кожного дня',
#  'кожного дня',
#  'сучасний дизайн',
#  'сучасний дизайн',
#  'залишилася задоволена',
#  'залишилася задоволена',
#  'рекомендую готель',
#  'рекомендую готель',
#  'зручне розташування',
#  'зручне розташування',
#  'розташування 10',
#  'розташування 10',
#  'смачно поїсти',
#  'смачно поїсти',
#  'хвилин центру',
#  'хвилин центру',
#  '10 хвилин',
#  '10 хвилин',
#  'комфортне ліжко',
#  'комфортне ліжко',
#  'хороший персонал',
#  'хороший персонал',
#  'розташування готелю',
#  'розташування готелю',
#  'загалом сподобалося',
#  'загалом сподобалося',
#  'привітний персонал',
#  'привітний персонал',
#  'персонал затишний',
#  'персонал затишний',
#  'тихий дворик',
#  'тихий дворик',
#  'ввічливий уважний',
#  'ввічливий уважний',
#  'затишний номер',
#  'затишний номер',
#  'уважний персонал',
#  'уважний персонал',
#  'номер зручностями',
#  'номер зручностями',
#  'доброзичливий персонал',
#  'доброзичливий персонал',
#  'номері чисто',
#  'номері чисто',
#  'тихий дворик',
#  'тихий дворик',
#  'прекрасне розташування',
#  'прекрасне розташування',
#  'розташування тихий',
#  'розташування тихий',
#  'зубна щітка',
#  'зубна щітка',
#  'новий чистий',
#  'новий чистий',
#  'чистий готель',
#  'чистий готель',
#  'ціна якість',
#  'ціна якість',
#  'привітний персонал',
#  'привітний персонал',
#  'персонал смачна',
#  'персонал смачна',
#  'смачна кава',
#  'смачна кава',
#  'затишні номери',
#  'затишні номери',
#  'чисто комфортно',
#  'чисто комфортно',
#  'чисто затишно',
#  'чисто затишно',
#  'приємний персонал',
#  'приємний персонал',
#  'ніяких проблем',
#  'ніяких проблем',
#  'чисто охайно',
#  'чисто охайно',
#  'білизна рушники',
#  'білизна рушники',
#  'простора ванна',
#  'простора ванна',
#  'розташування чудове',
#  'розташування чудове',
#  'гарний дизайн',
#  'гарний дизайн',
#  'чисто гарний',
#  'чисто гарний',
#  'зубна щітка',
#  'зубна щітка',
#  'приємний персонал',
#  'приємний персонал',
#  'персонал рекомендую',
#  'персонал рекомендую',
#  'чудовий готель',
#  'чудовий готель',
#  'готель приємний',
#  'готель приємний',
#  'смачний сніданок',
#  'смачний сніданок',
#  'затишний дворик',
#  'затишний дворик',
#  'зручне розташування',
#  'зручне розташування',
#  'відношення персоналу',
#  'відношення персоналу',
#  'тепло комфортно',
#  'тепло комфортно',
#  'сніданок смачний',
#  'сніданок смачний',
#  'відмінний номер',
#  'відмінний номер',
#  'чудовий персонал',
#  'чудовий персонал',
#  'номер чудовий',
#  'номер чудовий',
#  'відмінне розташування',
#  'відмінне розташування',
#  'розташування привітний',
#  'розташування привітний',
#  'персонал смачна',
#  'персонал смачна',
#  'смачна кухня',
#  'смачна кухня',
#  'смачний сніданок',
#  'смачний сніданок',
#  'зручне розташування',
#  'зручне розташування',
#  'розташування смачний',
#  'розташування смачний',
#  'смачні сніданки',
#  'смачні сніданки',
#  'велике ліжко',
#  'велике ліжко',
#  'холодильник кондиціонер',
#  'холодильник кондиціонер',
#  'номері холодильник',
#  'номері холодильник',
#  'ціна якість',
#  'ціна якість',
#  'чисто комфортно',
#  'чисто комфортно',
#  'красивий інтер',
#  'красивий інтер',
#  'інтер єр',
#  'інтер єр',
#  'сніданок смачний',
#  'сніданок смачний',
#  'зручне розташування',
#  'зручне розташування',
#  'хв центру',
#  'хв центру',
#  'сніданок смачний',
#  'сніданок смачний',
#  '15 хв',
#  '15 хв',
#  '10 15',
#  '10 15',
#  'готелю зручне',
#  'готелю зручне',
#  'місце розташування',
#  'місце розташування',
#  'розташування готелю',
#  'розташування готелю',
#  'привітним персоналом',
#  'привітним персоналом',
#  'готель центрі',
#  'готель центрі',
#  'центрі міста',
#  'центрі міста',
#  'привітний персонал',
#  'привітний персонал',
#  'чистота привітний',
#  'чистота привітний',
#  'якість супер',
#  'якість супер',
#  'ціна якість',
#  'ціна якість',
#  'комфортне ліжко',
#  'комфортне ліжко',
#  'нові номери',
#  'нові номери',
#  'привітний персонал',
#  'привітний персонал',
#  'розташування персонал',
#  'розташування персонал',
#  'персонал привітний',
#  'персонал привітний',
#  'зручне розташування',
#  'зручне розташування',
#  'привітний персонал',
#  'привітний персонал',
#  'чудовий персонал',
#  'чудовий персонал',
#  'чисто приємно',
#  'чисто приємно',
#  'персонал привітний',
#  'персонал привітний',
#  'готель новий',
#  'готель новий',
#  'місце розташування',
#  'місце розташування',
#  'привабливий персонал',
#  'привабливий персонал',
#  'привітний персонал',
#  'привітний персонал',
#  'чисто тихо',
#  'чисто тихо',
#  'чисто охайно',
#  'чисто охайно',
#  'розташування чистота',
#  'розташування чистота',
#  'високому рівні',
#  'високому рівні',
#  'великий плюс',
#  'великий плюс',
#  'персонал ввічливий',
#  'персонал ввічливий',
#  'сподобалося розташування',
#  'сподобалося розташування',
#  'ввічливий привітний',
#  'ввічливий привітний',
#  'привітний персонал',
#  'привітний персонал',
#  'привабливий персонал',
#  'привабливий персонал',
#  'персонал хороше',
#  'персонал хороше',
#  'готель чисто',
#  'готель чисто',
#  'хороше розташування',
#  'хороше розташування',
#  'новий готель',
#  'новий готель',
#  'чудовий персонал',
#  'чудовий персонал',
#  'вищому рівні',
#  'вищому рівні',
#  'центрі міста',
#  'центрі міста',
#  'тихо чисто',
#  'тихо чисто',
#  'чисто зручне',
#  'чисто зручне',
#  'зручне ліжко',
#  'зручне ліжко',
#  'приємний персонал',
#  'приємний персонал',
#  'розташування приємний',
#  'розташування приємний',
#  'привітний персонал',
#  'привітний персонал',
#  'розташування привітний',
#  'розташування привітний',
#  'чудове місце',
#  'чудове місце',
#  'місце розташування',
#  'місце розташування',
#  'місцезнаходження відмінне',
#  'місцезнаходження відмінне',
#  'центр міста',
#  'центр міста',
#  'привітний персонал',
#  'привітний персонал',
#  'площі ринок',
#  'площі ринок',
#  'персонал привітний',
#  'персонал привітний',
#  'розташування зручне',
#  'розташування зручне',
#  'сніданки смачні',
#  'сніданки смачні',
#  'привітний чуйний',
#  'привітний чуйний',
#  'чуйний персонал',
#  'чуйний персонал',
#  'номери чисті',
#  'номери чисті',
#  'гарне місце',
#  'гарне місце',
#  'номері тепло',
#  'номері тепло',
#  'місце розташування',
#  'місце розташування',
#  'розташування номері',
#  'розташування номері',
#  'сніданки смачні',
#  'сніданки смачні',
#  'ліжко зручна',
#  'ліжко зручна',
#  'розташування зручне',
#  'розташування зручне',
#  'зубна щітка',
#  'зубна щітка',
#  'визначних пам',
#  'визначних пам',
#  '39 яток',
#  '39 яток',
#  'основних визначних',
#  'основних визначних',
#  'хв пішки',
#  'хв пішки',
#  'пам 39',
#  'пам 39',
#  '15 хв',
#  '15 хв',
#  '10 15',
#  '10 15',
#  'ввічливий персонал',
#  'ввічливий персонал',
#  'персонал прибирання',
#  'персонал прибирання',
#  'центру львова',
#  'дівчата ресепшені',
#  'дівчата ресепшені',
#  'поряд готелем',
#  'поряд готелем',
#  'готель розташований',
#  'готель розташований',
#  'крокової доступності',
#  'крокової доступності',
#  'транспортна розв',
#  'транспортна розв',
#  '39 язка',
#  '39 язка',
#  'розв 39',
#  'розв 39',
#  'прямо центрі',
#  'прямо центрі',
#  'хороший готель',
#  'хороший готель',
#  'готель гроші',
#  'готель гроші',
#  'історичного центру',
#  'історичного центру',
#  'чисто приємний',
#  'чисто приємний',
#  'ввічливий персонал',
#  'ввічливий персонал',
#  'приємний ввічливий',
#  'приємний ввічливий',
#  'центру чисто',
#  'центру чисто',
#  'персонал готелі',
#  'персонал готелі',
#  'історичного центру',
#  'історичного центру',
#  'шикарне розташування',
#  'шикарне розташування',
#  'розташування центр',
#  'розташування центр',
#  'хвилинах ходьби',
#  'хвилинах ходьби',
#  'номери просторі',
#  'номери просторі',
#  'зубні щітки',
#  'зубні щітки',
#  'ланч бокс',
#  'ланч бокс',
#  'сніданки смачні',
#  'сніданки смачні',
#  'місцезнаходження супер',
#  'місцезнаходження супер',
#  'непоганий сніданок',
#  'непоганий сніданок',
#  'шикарне місце',
#  'шикарне місце',
#  'сніданок чисто',
#  'сніданок чисто',
#  'місце розташування',
#  'місце розташування',
#  'питна вода',
#  'питна вода',
#  'місцезнаходження готелю',
#  'місцезнаходження готелю',
#  'зручне місце',
#  'зручне місце',
#  'місце розташування',
#  'місце розташування',
#  'привітний персонал',
#  'привітний персонал',
#  'супер сніданок',
#  'супер сніданок',
#  'площі ринок',
#  'площі ринок',
#  'розташування центр',
#  'розташування центр',
#  'номер хороший',
#  'номер хороший',
#  'люб 39',
#  'люб 39',
#  'затишний чистий',
#  'затишний чистий',
#  'чистий готель',
#  'чистий готель',
#  'привітним персоналом',
#  'привітним персоналом',
#  'номери чисті',
#  'номери чисті',
#  'хвилин ходьби',
#  'хвилин ходьби',
#  'стійка реєстрації',
#  'стійка реєстрації',
#  'працює цілодобово',
#  'працює цілодобово',
#  'відмінне розташування',
#  'відмінне розташування',
#  'персонал супер',
#  'персонал супер',
#  'хороший персонал',
#  'хороший персонал',
#  'сніданок хороший',
#  'сніданок хороший',
#  'розташування хороше',
#  'розташування хороше',
#  'сніданки хороші',
#  'сніданки хороші',
#  'площі ринок',
#  'площі ринок',
#  'кондиціонер телевізор',
#  'кондиціонер телевізор',
#  'холодильник кондиціонер',
#  'холодильник кондиціонер',
#  'гарне місце',
#  'гарне місце',
#  'розташування центрі',
#  'розташування центрі',
#  'місце розташування',
#  'місце розташування',
#  'центрі міста',
#  'центрі міста',
#  'чистий персонал',
#  'чистий персонал',
#  'готель чистий',
#  'готель чистий',
#  'персонал привітний',
#  'персонал привітний',
#  'номері чисто',
#  'номері чисто',
#  'готель приємний',
#  'готель приємний',
#  'приємний персонал',
#  'приємний персонал',
#  'хвилин центру',
#  'хвилин центру',
#  'центрі міста',
#  'центрі міста',
#  'співвідношення ціни',
#  'співвідношення ціни',
#  'ціни якості',
#  'ціни якості',
#  'кожному поверсі',
#  'кожному поверсі',
#  'інтер 39',
#  'інтер 39',
#  '39 єром',
#  '39 єром',
#  'кондиціонер телевізор',
#  'кондиціонер телевізор',
#  'приємне враження',
#  'приємне враження',
#  'сніданок вибір',
#  'сніданок вибір',
#  'цілому готель',
#  'цілому готель',
#  'розташування прекрасне',
#  'розташування прекрасне',
#  'сніданки хороші',
#  'сніданки хороші',
#  'сніданок вибір',
#  'сніданок вибір',
#  'гарне розташування',
#  'гарне розташування',
#  'новий чистий',
#  'новий чистий',
#  'чистий готель',
#  'чистий готель',
#  'готель ввічливий',
#  'готель ввічливий',
#  'співвідношення ціна',
#  'співвідношення ціна',
#  'ціна якість',
#  'ціна якість',
#  'співвідношення ціна',
#  'співвідношення ціна',
#  'ціна якість',
#  'ціна якість',
#  'чисті затишні',
#  'чисті затишні',
#  'крокової доступності',
#  'крокової доступності',
#  'кулер водою',
#  'кулер водою',
#  'кожному поверсі',
#  'кожному поверсі',
#  'плюс готелю',
#  'плюс готелю',
#  'практично центрі',
#  'практично центрі',
#  'дійти пішки',
#  'дійти пішки',
#  'зручне розташування',
#  'зручне розташування',
#  'оперного театру',
#  'оперного театру',
#  'центрі міста',
#  'центрі міста',
#  '10 хвилин',
#  '10 хвилин',
#  'кафе ресторани',
#  'кафе ресторани',
#  'чистий номер',
#  'чистий номер',
#  'можливість замовити',
#  'можливість замовити',
#  'сніданок номер',
#  'сніданок номер',
#  'ланч бокс',
#  'ланч бокс',
#  'прекрасне розташування',
#  'прекрасне розташування',
#  'визначних пам',
#  'визначних пам',
#  '39 яток',
#  '39 яток',
#  'основних визначних',
#  'основних визначних',
#  'пам 39',
#  'пам 39',
#  'центру міста',
#  'центру міста',
#  'тихо комфортно',
#  'тихо комфортно',
#  'внутрішній дворик',
#  'внутрішній дворик',
#  'усім необхідним',
#  'усім необхідним',
#  'велика ванна',
#  'велика ванна',
#  'зручне ліжко',
#  'зручне ліжко',
#  'ліжко велика',
#  'ліжко велика',
#  'питна вода',
#  'питна вода',
#  'каву чай',
#  'каву чай',
#  'розташування готелю',
#  'розташування готелю',
#  'тихий дворик',
#  'тихий дворик',
#  'розташування прекрасне',
#  'розташування прекрасне',
#  'визначних пам',
#  'визначних пам',
#  '39 яток',
#  '39 яток',
#  'хвилинах ходьби',
#  'хвилинах ходьби',
#  'пам 39',
#  'пам 39',
#  '39 яти',
#  '39 яти',
#  'доброзичливий персонал',
#  'доброзичливий персонал',
#  'затишний номер',
#  'затишний номер',
#  'тихий двір',
#  'тихий двір',
#  'рекомендую готель',
#  'рекомендую готель',
#  'прекрасне розташування',
#  'прекрасне розташування',
#  'історичного центру',
#  'історичного центру',
#  'центру міста',
#  'центру міста',
#  'готель розташований',
#  'готель розташований',
#  'смачна кава',
#  'смачна кава',
#  'зубна щітка',
#  'зубна щітка',
#  'шампунь мило',
#  'шампунь мило',
#  'кулер водою',
#  'кулер водою',
#  'кожному поверсі',
#  'кожному поверсі',
#  'сподобався готель',
#  'сподобався готель',
#  'відмінне розташування',
#  'відмінне розташування',
#  'безкоштовний чай',
#  'безкоштовний чай',
#  'кулер водою',
#  'кулер водою',
#  'кожному поверсі',
#  'кожному поверсі',
#  'чай каву',
#  'чай каву',
#  'зубні щітки',
#  'зубні щітки',
#  'відмінний персонал',
#  'відмінний персонал',
#  'шикарне місце',
#  'шикарне місце',
#  'розташування центрі',
#  'розташування центрі',
#  'місце розташування',
#  'місце розташування',
#  'залишити речі',
#  'залишити речі',
#  'ліжко хороший',
#  'ліжко хороший',
#  'номер зручне',
#  'номер зручне',
#  'великий номер',
#  'великий номер',
#  'зручне ліжко',
#  'зручне ліжко',
#  'розташування готелю',
#  'розташування готелю',
#  'готель новий',
#  'готель новий',
#  'пішій доступності',
#  'пішій доступності',
#  'відмінний варіант',
#  'відмінний варіант',
#  'привітний персонал',
#  'привітний персонал',
#  'красиво затишно',
#  'красиво затишно',
#  'номері необхідне',
#  'номері необхідне',
#  'безкоштовний чай',
#  'безкоштовний чай',
#  'чай кава',
#  'чай кава',
#  'гарне місце',
#  'гарне місце',
#  'крокової доступності',
#  'крокової доступності',
#  'розташування всі',
#  'розташування всі',
#  'місце розташування',
#  'місце розташування',
#  'кімната простора',
#  'кімната простора',
#  'можливість залишити',
#  'можливість залишити',
#  'залишити багаж',
#  'залишити багаж',
#  'зубні щітки',
#  'зубні щітки',
#  'персонал привітний',
#  'персонал привітний',
#  'зубні щітки',
#  'зубні щітки',
#  'гарне розташування',
#  'гарне розташування',
#  'готель зручно',
#  'готель зручно',
#  'зручно розташований',
#  'зручно розташований',
#  'безкоштовний чай',
#  'безкоштовний чай',
#  'чай кава',
#  'чай кава',
#  'персонал хороший',
#  'персонал хороший',
#  'хороший привітний',
#  'хороший привітний',
#  'номер готель',
#  'номер готель',
#  'номері необхідне',
#  'номері необхідне',
#  'хвилин ходьби',
#  'хвилин ходьби',
#  'сподобалося готель',
#  'сподобалося готель',
#  '10 хвилин',
#  '10 хвилин',
#  'персонал привітний',
#  'персонал привітний',
#  'чисто затишно',
#  'чисто затишно',
#  'номері чисто',
#  'номері чисто',
#  'чисто тепло',
#  'чисто тепло',
#  'розташування 10',
#  'розташування 10',
#  '10 хвилин',
#  '10 хвилин',
#  'прогулянковий кроком',
#  'прогулянковий кроком',
#  'зручне місце',
#  'зручне місце',
#  'місце розташування',
#  'місце розташування',
#  'розташування центру',
#  'розташування центру',
#  'центру пішки',
#  'центру пішки',
#  'номери чисті',
#  'номери чисті',
#  'кожному поверсі',
#  'кожному поверсі',
#  'чай кава',
#  'чай кава',
#  'затишне місце',
#  'затишне місце',
#  'персонал намагається',
#  'персонал намагається',
#  'готель новий',
#  'готель новий',
#  'відмінний сервіс',
#  ...]

# %%
pos_bigrams = [
    'привітний персонал',
    'зручне розташування',
    'співвідношення ціни',
    'тихе місце',
    'смачні сніданки'
]

# %%
neg_bigrams = [
    'погана шумоізоляція',
    'тонкі стіни',
    'душова кабіна',
    'відсутність ліфта'
    'запах в номері',
]

# %%
print("\n=====Positive summary=====\n")
print(pos_bigrams)

print("\n=====Negative summary=====\n")
print(neg_bigrams)
# Out:
# =====Positive summary=====
#
# ['привітний персонал', 'зручне розташування', 'співвідношення ціни', 'тихе місце', 'смачні сніданки']
#
# =====Negative summary=====
#
# ['погана шумоізоляція', 'тонкі стіни', 'душова кабіна', 'відсутність ліфтазапах в номері']

# %%
word2vec['fi']
# Out:
# array([-1.028050e-01, -1.591530e-01, -2.412480e-01,  4.364560e-01,
#         3.575730e-01, -1.874190e-01,  3.456460e-01, -4.303950e-01,
#         3.117160e-01, -8.955420e-01, -5.964100e-02, -5.574710e-01,
#         2.586510e-01,  4.790900e-01, -1.647780e-01,  1.155010e-01,
#        -3.938200e-02,  5.782900e-02, -9.754500e-02,  5.326610e-01,
#        -2.315590e-01, -3.967740e-01,  5.405780e-01,  9.064900e-02,
#        -4.191140e-01,  4.798320e-01, -6.149540e-01, -9.752500e-02,
#        -2.174550e-01,  3.611180e-01, -4.281760e-01, -4.842980e-01,
#        -7.256300e-02, -1.807850e-01, -5.743710e-01, -3.599580e-01,
#         2.177310e-01,  1.632070e-01, -4.802830e-01, -4.459480e-01,
#        -1.990400e-02,  1.715170e-01, -4.212980e-01, -5.607610e-01,
#        -4.884900e-01,  5.132700e-01, -1.517100e-01,  9.203550e-01,
#        -1.549420e-01,  5.068400e-01, -3.403370e-01, -6.550000e-03,
#        -3.348540e-01,  1.614330e-01,  5.414750e-01,  6.156000e-03,
#         4.932680e-01,  5.309000e-03, -1.995460e-01, -1.417990e-01,
#         4.840000e-04, -2.454730e-01, -5.370790e-01, -3.370740e-01,
#         5.617500e-02,  8.270310e-01,  3.417740e-01,  1.724960e-01,
#        -4.290270e-01,  6.073520e-01,  7.969600e-01, -4.636960e-01,
#        -1.095880e-01, -3.066800e-01,  1.479250e-01, -4.446040e-01,
#        -1.772930e-01,  1.120050e-01, -5.149500e-02,  1.136490e-01,
#        -5.229310e-01, -3.283430e-01,  7.865500e-02, -4.312040e-01,
#        -2.241660e-01,  2.129650e-01,  4.214300e-02, -3.434520e-01,
#         2.491420e-01, -1.046920e-01, -4.697270e-01, -3.939220e-01,
#         7.343710e-01, -6.185380e-01, -9.821400e-02,  5.105450e-01,
#         2.399800e-02,  2.476360e-01,  2.004270e-01, -7.958500e-02,
#        -1.360780e-01,  1.971870e-01, -1.210260e-01, -5.281800e-01,
#         4.620660e-01, -2.169600e-02, -4.140430e-01,  4.075260e-01,
#        -6.290900e-02, -1.813490e-01, -6.850480e-01, -3.430410e-01,
#         2.179890e-01, -2.633160e-01,  3.829240e-01,  1.574900e-01,
#         3.074810e-01,  9.117300e-02, -2.736680e-01, -5.639790e-01,
#        -2.714250e-01,  6.360190e-01, -1.317070e-01,  2.081080e-01,
#         1.810790e-01,  3.551620e-01, -2.614060e-01,  5.259400e-01,
#         7.246090e-01, -1.724350e-01, -9.974700e-02,  4.437530e-01,
#        -9.294630e-01, -1.912100e-01, -8.790900e-02, -3.462870e-01,
#        -1.732510e-01,  7.888700e-02,  5.022730e-01,  2.714970e-01,
#         1.422690e-01,  1.513780e-01, -7.046400e-02, -5.197900e-01,
#        -3.029790e-01,  4.347140e-01, -2.155180e-01, -4.514490e-01,
#        -1.086530e-01, -2.259460e-01,  2.117680e-01, -3.827600e-01,
#         1.171700e-01,  1.049610e-01, -2.108970e-01,  2.699290e-01,
#         2.139750e-01,  4.262890e-01,  1.465420e-01, -1.600340e-01,
#         2.998320e-01,  2.672620e-01,  2.283470e-01, -3.286450e-01,
#        -1.204220e-01,  3.645690e-01,  1.561100e-01, -2.921940e-01,
#        -3.097780e-01, -6.821290e-01,  7.541620e-01,  2.365480e-01,
#         2.398630e-01, -5.245230e-01, -1.573280e-01,  1.619690e-01,
#         6.663070e-01,  1.312670e-01,  5.078880e-01, -3.943950e-01,
#         4.579600e-01, -5.397880e-01, -3.889990e-01, -3.633890e-01,
#        -9.874000e-03, -5.486850e-01, -1.261630e-01, -3.887310e-01,
#        -7.399220e-01, -1.222620e-01, -1.946420e-01, -3.307710e-01,
#        -9.563200e-02, -1.367890e-01,  4.928650e-01,  1.414420e-01,
#         2.267400e-01, -1.125320e+00,  5.036550e-01,  6.388040e-01,
#        -4.271510e-01, -2.460300e-02,  3.173490e-01, -1.687040e-01,
#        -1.261300e-02, -8.782570e-01, -1.015181e+00,  4.731250e-01,
#        -3.304260e-01,  4.381030e-01,  1.021140e-01,  1.866320e-01,
#         7.724660e-01,  3.985500e-02, -3.647430e-01,  2.341040e-01,
#        -3.478050e-01, -1.545880e-01, -2.435910e-01, -8.780040e-01,
#        -5.877760e-01,  3.519980e-01, -3.233000e-02,  2.590930e-01,
#         4.630430e-01, -1.086430e-01,  1.286890e-01,  5.363790e-01,
#        -2.103970e-01, -6.683650e-01,  3.747100e-02, -4.967610e-01,
#        -2.401150e-01,  2.710150e-01, -2.022330e-01,  1.837730e-01,
#        -2.513610e-01, -1.622850e-01,  3.820020e-01, -2.937310e-01,
#         1.212670e-01,  2.734880e-01,  5.435610e-01,  3.828210e-01,
#         5.206340e-01, -5.635030e-01, -1.105933e+00, -6.523470e-01,
#         2.895840e-01, -1.813140e-01, -2.415200e-01,  4.117500e-02,
#         1.875170e-01,  3.339180e-01, -3.109740e-01,  2.761880e-01,
#         1.336880e-01,  2.412800e-01,  1.088390e-01, -6.803000e-03,
#        -3.073300e-01,  6.522800e-01,  1.679190e-01,  4.044550e-01,
#        -1.471350e-01, -2.365730e-01,  2.122290e-01,  3.523880e-01,
#         1.000812e+00, -3.113560e-01,  1.183070e-01,  2.561700e-02,
#         3.430190e-01,  4.077400e-02,  1.662680e-01, -3.336030e-01,
#        -1.762630e-01, -2.467210e-01, -3.201500e-02, -9.158000e-01,
#        -1.316321e+00,  4.738450e-01, -2.874580e-01,  1.568990e-01,
#         6.846500e-02, -6.679350e-01, -2.936820e-01, -7.436750e-01,
#         1.317810e-01, -2.468260e-01,  3.198550e-01, -4.744680e-01,
#        -2.489600e-01, -8.818100e-02,  9.281900e-02,  1.641420e-01,
#         6.008500e-02,  1.790560e-01,  3.170920e-01, -2.406100e-01],
#       dtype=float32)

# %%
pos_bigrams
# Out:
# [('номері відсутність', 0.34),
#  ('запах номері', 0.33),
#  ('косметичний ремонт', 0.31),
#  ('тонкі стіни', 0.34),
#  ('душ номері', 0.1),
#  ('душовій кабіні', 0.33),
#  ('душова кабіна', 0.23),
#  ('деяких місцях', 0.32),
#  ('двері туалет', 0.35),
#  ('круті сходи', 0.3),
#  ('складно знайти', 0.32),
#  ('знайти місце', 0.2),
#  ('маленький телевізор', 0.29),
#  ('номер вікном', 0.18),
#  ('відсутність ліфта', 0.34),
#  ('круті сходи', 0.3),
#  ('погана шумоізоляція', 0.35),
#  ('сусідніх номерах', 0.34),
#  ('ванній кімнаті', 0.26),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('чути сусідів', 0.3),
#  ('зубної щітки', 0.25),
#  ('відсутність шумоізоляції', 0.35),
#  ('неможливо спати', 0.34),
#  ('душова кабінка', 0.24),
#  ('поганому стані', 0.35),
#  ('яко кажучи', 0.33),
#  ('єдиний мінус', 0.27),
#  ('слабка шумоізоляція', 0.35),
#  ('останньому поверсі', 0.14),
#  ('погана звукоізоляція', 0.35),
#  ('спати неможливо', 0.34),
#  ('чути розмови', 0.35),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('ванній кімнаті', 0.26),
#  ('вікно стелі', 0.2),
#  ('єдиний мінус', 0.27),
#  ('таку вартість', 0.13),
#  ('пів ночі', 0.34),
#  ('першу ніч', 0.33),
#  ('москітну сітки', 0.22),
#  ('звукоізоляція погана', 0.34),
#  ('погана звукоізоляція', 0.35),
#  ('стіни чути', 0.34),
#  ('сусідньому номері', 0.34),
#  ('тонкі стіни', 0.34),
#  ('душова кабіна', 0.23),
#  ('вода душі', 0.26),
#  ('холодна вода', 0.18),
#  ('звукоізоляція відсутня', 0.35),
#  ('цілу ніч', 0.34),
#  ('душовій кабіні', 0.33),
#  ('готелю такого', 0.22),
#  ('відсутність парковки', 0.34),
#  ('нашому номері', 0.25),
#  ('погана шумоізоляція', 0.35),
#  ('номер маленький', 0.19),
#  ('погана звукоізоляція', 0.35),
#  ('душова кабіна', 0.23),
#  ('враження готелю', 0.12),
#  ('потребує ремонту', 0.34),
#  ('погана звукоізоляція', 0.35),
#  ('звукоізоляція номерами', 0.29),
#  ('велика сутність', 0.33),
#  ('води душі', 0.28),
#  ('сніданок взагалі', 0.13),
#  ('погана звукоізоляція', 0.35),
#  ('номер першому', 0.24),
#  ('склалося враження', 0.29),
#  ('душова кабінка', 0.24),
#  ('ванній кімнаті', 0.26),
#  ('погано працює', 0.33),
#  ('відкрити вікно', 0.32),
#  ('вікно стелі', 0.2),
#  ('му поверсі', 0.14),
#  ('відкрити вікно', 0.32),
#  ('відсутність парковки', 0.34),
#  ('слабкий напір', 0.34),
#  ('напір води', 0.28),
#  ('дерев 39', 0.18),
#  ('відкритому вікні', 0.3),
#  ('ванній кімнаті', 0.26),
#  ('ду уже', 0.11),
#  ('води душі', 0.28),
#  ('дерев 39', 0.18),
#  ('погана шумоізоляція', 0.35),
#  ('шумоізоляція чутно', 0.34),
#  ('відсутність ліфта', 0.34),
#  ('му поверсі', 0.14),
#  ('погана шумоізоляція', 0.35),
#  ('39 яні', 0.28),
#  ('шумоізоляція відсутня', 0.34),
#  ('шумоізоляція чутно', 0.34),
#  ('сусідніх номерів', 0.31),
#  ('чутно відбувається', 0.33),
#  ('звукоізоляція відсутня', 0.35),
#  ('душової кабіни', 0.31),
#  ('39 яні', 0.28),
#  ('відсутня звукоізоляція', 0.35),
#  ('звукоізоляція чути', 0.34),
#  ('сусіднього номера', 0.34),
#  ('10 ранку', 0.18),
#  ('напір води', 0.28),
#  ('останньому поверсі', 0.14),
#  ('чутно відбувається', 0.33),
#  ('ванній кімнаті', 0.26),
#  ('висока сутність', 0.34),
#  ('вхідні двері', 0.33),
#  ('номер маленький', 0.19),
#  ('ванній кімнаті', 0.26),
#  ('хороша сутність', 0.33),
#  ('200 грн', 0.26),
#  ('грн ніч', 0.26),
#  ('холодно номері', 0.33),
#  ('гелю душу', 0.3),
#  ('тонкі стіни', 0.34),
#  ('чутно відбувається', 0.33),
#  ('спати неможливо', 0.34),
#  ('відкрити вікно', 0.32),
#  ('відсутність парковки', 0.34),
#  ('сусідньому номері', 0.34),
#  ('тонкі стіни', 0.34),
#  ('знайти вхід', 0.32),
#  ('важко знайти', 0.31),
#  ('деяких номерах', 0.3),
#  ('номер двома', 0.21),
#  ('москвітіної сітки', 0.33),
#  ('чутно сусідів', 0.32),
#  ('маленький номер', 0.31),
#  ('сусідньому номері', 0.34),
#  ('важко знайти', 0.31),
#  ('завадив би', 0.34),
#  ('душової кабінки', 0.32),
#  ('зв 39', 0.16),
#  ('39 язку', 0.15),
#  ('відсутність ліфта', 0.34),
#  ('круті сходи', 0.3),
#  ('ванній кімнаті', 0.26),
#  ('круті сходи', 0.3),
#  ('шумоізоляція номерів', 0.28),
#  ('погана шумоізоляція', 0.35),
#  ('шумоізоляція чутно', 0.34),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('чути сусідів', 0.3),
#  ('заважає спати', 0.31),
#  ('звукоізоляція чути', 0.34),
#  ('відсутня звукоізоляція', 0.35),
#  ('сусідньому номері', 0.34),
#  ('тонкі стіни', 0.34),
#  ('погана звукоізоляція', 0.35),
#  ('номери маленькі', 0.18),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('чути сусідів', 0.3),
#  ('відсутність звукоізоляції', 0.34),
#  ('стіни чути', 0.34),
#  ('тонкі стіни', 0.34),
#  ('чути сусідів', 0.3),
#  ('слабка шумоізоляція', 0.35),
#  ('номер першому', 0.24),
#  ('пізно ввечері', 0.12),
#  ('номері холодно', 0.33),
#  ('погана звукоізоляція', 0.35),
#  ('погана шумоізоляція', 0.35),
#  ('ванній кімнаті', 0.26),
#  ('туалетного приладдя', 0.21),
#  ('води душі', 0.28),
#  ('напір води', 0.28),
#  ('чути шум', 0.3),
#  ('висока сутність', 0.34),
#  ('тонкі стіни', 0.34),
#  ('відбувається коридорі', 0.34),
#  ('чути відбувається', 0.34),
#  ('відсутність сніданку', 0.31),
#  ('fi номері', 0.19),
#  ('слабка звукоізоляція', 0.35),
#  ('відсутність ліфта', 0.34),
#  ('запах ванній', 0.35),
#  ('неприємний запах', 0.34)]

# %%
neg_ngram_mng.find_important_bigrams(ne)

# %%
# %time result = cluster_ngram.cluster_n_grams(pos_bigrams2, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-124-dace131cb729> in cluster_n_grams(self, ngrams, num_cluster)
#      11                                      repeats=100,
#      12                                      avoid_empty_clusters=True)
# ---> 13         y = kclusterer.cluster(X, assign_clusters=True)
#      14
#      15         top_indices = self.__find_top_n_gram_indices(X, y, kclusterer.means())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/util.py in cluster(self, vectors, assign_clusters, trace)
#      59
#      60         # call abstract method to cluster the vectors
# ---> 61         self.cluster_vectorspace(vectors, trace)
#      62
#      63         # assign the vectors to clusters
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/kmeans.py in cluster_vectorspace(self, vectors, trace)
#      83             if not self._means or trial > 1:
#      84                 self._means = self._rng.sample(list(vectors), self._num_means)
# ---> 85             self._cluster_vectorspace(vectors, trace)
#      86             meanss.append(self._means)
#      87
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/kmeans.py in _cluster_vectorspace(self, vectors, trace)
#     114                 clusters = [[] for m in range(self._num_means)]
#     115                 for vector in vectors:
# --> 116                     index = self.classify_vectorspace(vector)
#     117                     clusters[index].append(vector)
#     118
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/kmeans.py in classify_vectorspace(self, vector)
#     136         # returns that cluster's index
#     137         best_distance = best_index = None
# --> 138         for index in range(len(self._means)):
#     139             mean = self._means[index]
#     140             dist = self._distance(vector, mean)
#
# KeyboardInterrupt:

# %%
tokenize_uk.tokenize_sents(pos_texts[1])
# Out:
# ['Персонал привітний, швидко вирішує усі питання.',
#  'В номері тепло, ліжко зручне, чисто.',
#  'Є необхідна кількість рушників, їх регулярно змінюють.',
#  'Є капці.',
#  'На столі по пляшці газованої і негазованої води.',
#  'Чудове розташування в затишному дворі, повністю відсутній шум з вулиці.']

# %%
text = "Готель дуже чудовий, персонал привітний, попросили зробити ранній заїзд з 8 до 9 і нас без питань заселили. При виселенні залишили валізи в кімнаті зберігання. Невеликий мінус це звукоізоляція готелю. Наступний раз виберемо цей готель."

# %%
print(text)
# Out:
# Готель дуже чудовий, персонал привітний, попросили зробити ранній заїзд з 8 до 9 і нас без питань заселили. При виселенні залишили валізи в кімнаті зберігання. Невеликий мінус це звукоізоляція готелю. Наступний раз виберемо цей готель.

# %%
import tokenize_uk

# %%
sentes = tokenize_uk.tokenize_sents(text)

# %%
pos_ngram_mng.find_important_bigrams(text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# [('чудовий персонал', 0.25),
#  ('готель чудовий', 0.23),
#  ('персонал привітний', 0.23)]

# %%
neg_ngram_mng.find_important_bigrams(text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# []

# %%
pos_sents = [sentes[0], sentes[3]]

# %%
neg_sents = [sentes[2]]

# %%
pos_sents
# Out:
# ['Готель дуже чудовий, персонал привітний, попросили зробити ранній заїзд з 8 до 9 і нас без питань заселили.',
#  'Наступний раз виберемо цей готель.']

# %%
print("====Positive sentences====")
print(pos_sents)
print("====Negative sentences====")
print(neg_sents)
# Out:
# ====Positive sentences====
# ['Готель дуже чудовий, персонал привітний, попросили зробити ранній заїзд з 8 до 9 і нас без питань заселили.', 'Наступний раз виберемо цей готель.']
# ====Negative sentences====
# ['Невеликий мінус це звукоізоляція готелю.']

# %%
print("====Positive n-gram====")
print(['готель чудовий', 'персонал привітний'])
print("====Negative n-grams====")
print(['звукоізоляція'])
# Out:
# ====Positive n-gram====
# ['готель чудовий', 'персонал привітний']
# ====Negative n-grams====
# ['звукоізоляція']

# %%
pos_ngram_mng.find_important_bigrams(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-f0907f83d95e> in <module>
# ----> 1 pos_ngram_mng.find_important_bigrams(text)[0,:]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
print("====Positive n-gram====")
print(['персонал привітний', 'зручне розташування', 'співвідношення ціни', 'тихе місце', 'смачні сніданки'])
print("====Negative n-grams====")
print(['погана шумоізоляція', 'тонкі стіни', 'душова кабіна', 'відсутність ліфта', 'запах номері'])
# Out:
# ====Positive n-gram====
# ['персонал привітний', 'зручне розташування', 'співвідношення ціни', 'тихе місце', 'смачні сніданки']
# ====Negative n-grams====
# ['погана шумоізоляція', 'тонкі стіни', 'душова кабіна', 'відсутність ліфта', 'запах номері']

# %%
neg_text = "Одну з ночей хтось постійно ходив по коридору і ми не могли нормально спати через дзвінкий стукіт підборів об плитку. З ковровим покриттям в коридорі було б комфортніше. Меблі в номері вже трохи втомлені"

# %%
neg_ngram_mng.find_important_unigrams(neg_text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# [('коридору', 0.31),
#  ('хтось', 0.31),
#  ('могли', 0.28),
#  ('спати', 0.28),
#  ('коридорі', 0.27),
#  ('постійно', 0.25),
#  ('нормально', 0.16),
#  ('номері', 0.11)]
